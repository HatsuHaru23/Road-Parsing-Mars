# %%
# !mkdir 256_patches

# %%
cd '/content/256_patches'
# Out:
# /content/256_patches

# %%
# !mkdir images

# %%
# !mkdir masks

# %%
# !mkdir images_with_useful_info

# %%
cd '/content/256_patches/images_with_useful_info'
# Out:
# /content/256_patches/images_with_useful_info

# %%
# !mkdir images

# %%
# !mkdir masks

# %%
pip install patchify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.9/dist-packages (from patchify) (1.22.4)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
import os
import cv2
import numpy as np
import glob

import numpy as np
from matplotlib import pyplot as plt
from patchify import patchify
import tifffile as tiff
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.metrics import MeanIoU
import random

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
root_directory = '/content/'

# %%
patch_size = 256

# %%
cd "/content"
# Out:
# /content

# %%
# !pip install gdown -U --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (4.6.6)
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown) (3.10.7)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed gdown-4.7.1

# %%
import gdown
url ='https://drive.google.com/uc?id=1xxMw2gM48JxftZEuLvHMuU_5ibIITEP0'
gdown.download(url)
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1xxMw2gM48JxftZEuLvHMuU_5ibIITEP0
# From (redirected): https://drive.google.com/uc?id=1xxMw2gM48JxftZEuLvHMuU_5ibIITEP0&confirm=t&uuid=d2808172-1ed2-4e59-8b36-afe93ebd4c1e
# To: /content/archive.zip
# 100%|██████████| 4.07G/4.07G [00:48<00:00, 84.0MB/s]
# 'archive.zip'

# %%
# !unzip archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/723199_sat.jpg
#   inflating: train/723226_mask.png
#   inflating: train/723226_sat.jpg
#   inflating: train/723436_mask.png
#   inflating: train/723436_sat.jpg
#   inflating: train/723483_mask.png
#   inflating: train/723483_sat.jpg
#   inflating: train/723622_mask.png
#   inflating: train/723622_sat.jpg
#   inflating: train/723722_mask.png
#   inflating: train/723722_sat.jpg
#   inflating: train/723970_mask.png
#   inflating: train/723970_sat.jpg
#   inflating: train/723990_mask.png
#   inflating: train/723990_sat.jpg
#   inflating: train/724095_mask.png
#   inflating: train/724095_sat.jpg
#   inflating: train/724431_mask.png
#   inflating: train/724431_sat.jpg
#   inflating: train/724485_mask.png
#   inflating: train/724485_sat.jpg
#   inflating: train/724705_mask.png
#   inflating: train/724705_sat.jpg
#   inflating: train/724870_mask.png
#   inflating: train/724870_sat.jpg
#   inflating: train/724941_mask.png
#   inflating: train/724941_sat.jpg
#   inflating: train/724993_mask.png
#   inflating: train/724993_sat.jpg
#   inflating: train/725014_mask.png
#   inflating: train/725014_sat.jpg
#   inflating: train/725115_mask.png
#   inflating: train/725115_sat.jpg
#   inflating: train/725183_mask.png
#   inflating: train/725183_sat.jpg
#   inflating: train/725239_mask.png
#   inflating: train/725239_sat.jpg
#   inflating: train/725249_mask.png
#   inflating: train/725249_sat.jpg
#   inflating: train/725359_mask.png
#   inflating: train/725359_sat.jpg
#   inflating: train/725392_mask.png
#   inflating: train/725392_sat.jpg
#   inflating: train/725472_mask.png
#   inflating: train/725472_sat.jpg
#   inflating: train/725747_mask.png
#   inflating: train/725747_sat.jpg
#   inflating: train/725833_mask.png
#   inflating: train/725833_sat.jpg
#   inflating: train/725843_mask.png
#   inflating: train/725843_sat.jpg
#   inflating: valid/972010_sat.jpg
#   inflating: valid/972123_sat.jpg
#   inflating: valid/974127_sat.jpg
#   inflating: valid/97434_sat.jpg
#   inflating: valid/974785_sat.jpg
#   inflating: valid/974960_sat.jpg
#   inflating: valid/97598_sat.jpg
#   inflating: valid/976443_sat.jpg
#   inflating: valid/979591_sat.jpg
#   inflating: valid/979651_sat.jpg
#   inflating: valid/979824_sat.jpg
#   inflating: valid/981739_sat.jpg
#   inflating: valid/981785_sat.jpg
#   inflating: valid/9821_sat.jpg
#   inflating: valid/982728_sat.jpg
#   inflating: valid/983142_sat.jpg
#   inflating: valid/983867_sat.jpg
#   inflating: valid/983896_sat.jpg
#   inflating: valid/983911_sat.jpg
#   inflating: valid/984577_sat.jpg
#   inflating: valid/984706_sat.jpg
#   inflating: valid/985641_sat.jpg
#   inflating: valid/985869_sat.jpg
#   inflating: valid/986231_sat.jpg
#   inflating: valid/986696_sat.jpg
#   inflating: valid/988215_sat.jpg
#   inflating: valid/98828_sat.jpg
#   inflating: valid/988686_sat.jpg
#   inflating: valid/9893_sat.jpg
#   inflating: valid/990104_sat.jpg
#   inflating: valid/99032_sat.jpg
#   inflating: valid/990888_sat.jpg
#   inflating: valid/991366_sat.jpg
#   inflating: valid/991606_sat.jpg
#   inflating: valid/991978_sat.jpg
#   inflating: valid/992520_sat.jpg
#   inflating: valid/993282_sat.jpg
#   inflating: valid/993402_sat.jpg
#   inflating: valid/993408_sat.jpg
#   inflating: valid/993415_sat.jpg
#   inflating: valid/994006_sat.jpg
#   inflating: valid/994111_sat.jpg
#   inflating: valid/994141_sat.jpg
#   inflating: valid/994375_sat.jpg
#   inflating: valid/994998_sat.jpg
#   inflating: valid/995317_sat.jpg
#   inflating: valid/995370_sat.jpg
#   inflating: valid/995930_sat.jpg
#   inflating: valid/997473_sat.jpg
#   inflating: valid/998148_sat.jpg
#   inflating: valid/999753_sat.jpg

# %%
img_dir=root_directory+"train/"

# %%
cd '/content/256_patches/images'
# Out:
# /content/256_patches/images

# %%
for path, subdirs, files in os.walk(img_dir):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    #print(dirname)
    images = os.listdir(path)  #List of all image names in this subdirectory
    #print(images)
    for i, image_name in enumerate(sorted(images)):  
        if image_name.endswith(".jpg"):
            #print(image_name)
            image = cv2.imread(path+"/"+image_name, 1)  #Read each image as BGR
            SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
            SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
            image = Image.fromarray(image)
            image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
            #image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
            image = np.array(image)             
   
            #Extract patches from each image
            print("Now patchifying image:", path+"/"+image_name)
            patches_img = patchify(image, (256, 256, 3), step=256)  #Step=256 for 256 patches means no overlap
    
            for i in range(patches_img.shape[0]):
                for j in range(patches_img.shape[1]):
                    
                    single_patch_img = patches_img[i,j,:,:]
                    #single_patch_img = (single_patch_img.astype('float32')) / 255. #We will preprocess using one of the backbones
                    single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.                               
                    
                    cv2.imwrite(image_name+"patch_"+str(i)+str(j)+".jpg", single_patch_img)
                    #image_dataset.append(single_patch_img)
# Out:
# Streaming output truncated to the last 5000 lines.
# Now patchifying image: /content/train//279367_sat.jpg
# Now patchifying image: /content/train//279620_sat.jpg
# Now patchifying image: /content/train//279807_sat.jpg
# Now patchifying image: /content/train//279862_sat.jpg
# Now patchifying image: /content/train//279971_sat.jpg
# Now patchifying image: /content/train//280022_sat.jpg
# Now patchifying image: /content/train//280425_sat.jpg
# Now patchifying image: /content/train//280509_sat.jpg
# Now patchifying image: /content/train//280694_sat.jpg
# Now patchifying image: /content/train//280955_sat.jpg
# Now patchifying image: /content/train//281008_sat.jpg
# Now patchifying image: /content/train//281122_sat.jpg
# Now patchifying image: /content/train//281208_sat.jpg
# Now patchifying image: /content/train//281344_sat.jpg
# Now patchifying image: /content/train//281355_sat.jpg
# Now patchifying image: /content/train//281530_sat.jpg
# Now patchifying image: /content/train//282201_sat.jpg
# Now patchifying image: /content/train//282386_sat.jpg
# Now patchifying image: /content/train//282426_sat.jpg
# Now patchifying image: /content/train//282861_sat.jpg
# Now patchifying image: /content/train//282949_sat.jpg
# Now patchifying image: /content/train//282956_sat.jpg
# Now patchifying image: /content/train//282986_sat.jpg
# Now patchifying image: /content/train//282992_sat.jpg
# Now patchifying image: /content/train//283097_sat.jpg
# Now patchifying image: /content/train//283125_sat.jpg
# Now patchifying image: /content/train//283271_sat.jpg
# Now patchifying image: /content/train//28332_sat.jpg
# Now patchifying image: /content/train//283392_sat.jpg
# Now patchifying image: /content/train//283581_sat.jpg
# Now patchifying image: /content/train//283650_sat.jpg
# Now patchifying image: /content/train//284083_sat.jpg
# Now patchifying image: /content/train//284094_sat.jpg
# Now patchifying image: /content/train//284571_sat.jpg
# Now patchifying image: /content/train//284729_sat.jpg
# Now patchifying image: /content/train//284874_sat.jpg
# Now patchifying image: /content/train//285121_sat.jpg
# Now patchifying image: /content/train//285170_sat.jpg
# Now patchifying image: /content/train//285194_sat.jpg
# Now patchifying image: /content/train//285214_sat.jpg
# Now patchifying image: /content/train//285361_sat.jpg
# Now patchifying image: /content/train//285518_sat.jpg
# Now patchifying image: /content/train//285535_sat.jpg
# Now patchifying image: /content/train//285789_sat.jpg
# Now patchifying image: /content/train//285810_sat.jpg
# Now patchifying image: /content/train//285997_sat.jpg
# Now patchifying image: /content/train//286013_sat.jpg
# Now patchifying image: /content/train//286038_sat.jpg
# Now patchifying image: /content/train//28606_sat.jpg
# Now patchifying image: /content/train//286172_sat.jpg
# Now patchifying image: /content/train//286300_sat.jpg
# Now patchifying image: /content/train//286322_sat.jpg
# Now patchifying image: /content/train//286360_sat.jpg
# Now patchifying image: /content/train//286361_sat.jpg
# Now patchifying image: /content/train//286522_sat.jpg
# Now patchifying image: /content/train//286534_sat.jpg
# Now patchifying image: /content/train//286647_sat.jpg
# Now patchifying image: /content/train//286902_sat.jpg
# Now patchifying image: /content/train//287058_sat.jpg
# Now patchifying image: /content/train//28727_sat.jpg
# Now patchifying image: /content/train//287479_sat.jpg
# Now patchifying image: /content/train//287575_sat.jpg
# Now patchifying image: /content/train//287766_sat.jpg
# Now patchifying image: /content/train//287837_sat.jpg
# Now patchifying image: /content/train//287902_sat.jpg
# Now patchifying image: /content/train//288328_sat.jpg
# Now patchifying image: /content/train//288500_sat.jpg
# Now patchifying image: /content/train//28863_sat.jpg
# Now patchifying image: /content/train//288657_sat.jpg
# Now patchifying image: /content/train//288725_sat.jpg
# Now patchifying image: /content/train//288746_sat.jpg
# Now patchifying image: /content/train//289032_sat.jpg
# Now patchifying image: /content/train//28905_sat.jpg
# Now patchifying image: /content/train//289200_sat.jpg
# Now patchifying image: /content/train//289212_sat.jpg
# Now patchifying image: /content/train//289483_sat.jpg
# Now patchifying image: /content/train//289537_sat.jpg
# Now patchifying image: /content/train//289571_sat.jpg
# Now patchifying image: /content/train//289584_sat.jpg
# Now patchifying image: /content/train//289816_sat.jpg
# Now patchifying image: /content/train//289860_sat.jpg
# Now patchifying image: /content/train//289959_sat.jpg
# Now patchifying image: /content/train//290194_sat.jpg
# Now patchifying image: /content/train//29019_sat.jpg
# Now patchifying image: /content/train//290274_sat.jpg
# Now patchifying image: /content/train//290295_sat.jpg
# Now patchifying image: /content/train//290444_sat.jpg
# Now patchifying image: /content/train//290587_sat.jpg
# Now patchifying image: /content/train//290735_sat.jpg
# Now patchifying image: /content/train//290907_sat.jpg
# Now patchifying image: /content/train//291105_sat.jpg
# Now patchifying image: /content/train//291185_sat.jpg
# Now patchifying image: /content/train//291379_sat.jpg
# Now patchifying image: /content/train//291574_sat.jpg
# Now patchifying image: /content/train//291592_sat.jpg
# Now patchifying image: /content/train//291871_sat.jpg
# Now patchifying image: /content/train//29198_sat.jpg
# Now patchifying image: /content/train//292384_sat.jpg
# Now patchifying image: /content/train//292623_sat.jpg
# Now patchifying image: /content/train//292753_sat.jpg
# Now patchifying image: /content/train//292761_sat.jpg
# Now patchifying image: /content/train//292950_sat.jpg
# Now patchifying image: /content/train//293084_sat.jpg
# Now patchifying image: /content/train//293186_sat.jpg
# Now patchifying image: /content/train//293544_sat.jpg
# Now patchifying image: /content/train//293592_sat.jpg
# Now patchifying image: /content/train//293742_sat.jpg
# Now patchifying image: /content/train//294143_sat.jpg
# Now patchifying image: /content/train//294187_sat.jpg
# Now patchifying image: /content/train//294502_sat.jpg
# Now patchifying image: /content/train//294701_sat.jpg
# Now patchifying image: /content/train//294813_sat.jpg
# Now patchifying image: /content/train//295004_sat.jpg
# Now patchifying image: /content/train//295066_sat.jpg
# Now patchifying image: /content/train//295092_sat.jpg
# Now patchifying image: /content/train//29509_sat.jpg
# Now patchifying image: /content/train//295135_sat.jpg
# Now patchifying image: /content/train//295155_sat.jpg
# Now patchifying image: /content/train//295328_sat.jpg
# Now patchifying image: /content/train//295372_sat.jpg
# Now patchifying image: /content/train//295393_sat.jpg
# Now patchifying image: /content/train//295447_sat.jpg
# Now patchifying image: /content/train//295482_sat.jpg
# Now patchifying image: /content/train//295973_sat.jpg
# Now patchifying image: /content/train//296095_sat.jpg
# Now patchifying image: /content/train//296271_sat.jpg
# Now patchifying image: /content/train//296505_sat.jpg
# Now patchifying image: /content/train//296546_sat.jpg
# Now patchifying image: /content/train//296629_sat.jpg
# Now patchifying image: /content/train//296658_sat.jpg
# Now patchifying image: /content/train//296759_sat.jpg
# Now patchifying image: /content/train//296866_sat.jpg
# Now patchifying image: /content/train//296918_sat.jpg
# Now patchifying image: /content/train//297007_sat.jpg
# Now patchifying image: /content/train//297017_sat.jpg
# Now patchifying image: /content/train//297062_sat.jpg
# Now patchifying image: /content/train//297152_sat.jpg
# Now patchifying image: /content/train//297409_sat.jpg
# Now patchifying image: /content/train//297515_sat.jpg
# Now patchifying image: /content/train//297633_sat.jpg
# Now patchifying image: /content/train//297834_sat.jpg
# Now patchifying image: /content/train//297846_sat.jpg
# Now patchifying image: /content/train//297868_sat.jpg
# Now patchifying image: /content/train//297896_sat.jpg
# Now patchifying image: /content/train//297932_sat.jpg
# Now patchifying image: /content/train//297975_sat.jpg
# Now patchifying image: /content/train//298351_sat.jpg
# Now patchifying image: /content/train//298428_sat.jpg
# Now patchifying image: /content/train//298463_sat.jpg
# Now patchifying image: /content/train//29846_sat.jpg
# Now patchifying image: /content/train//298555_sat.jpg
# Now patchifying image: /content/train//298588_sat.jpg
# Now patchifying image: /content/train//298613_sat.jpg
# Now patchifying image: /content/train//29889_sat.jpg
# Now patchifying image: /content/train//298975_sat.jpg
# Now patchifying image: /content/train//298999_sat.jpg
# Now patchifying image: /content/train//299005_sat.jpg
# Now patchifying image: /content/train//299015_sat.jpg
# Now patchifying image: /content/train//299051_sat.jpg
# Now patchifying image: /content/train//299066_sat.jpg
# Now patchifying image: /content/train//299115_sat.jpg
# Now patchifying image: /content/train//299142_sat.jpg
# Now patchifying image: /content/train//299227_sat.jpg
# Now patchifying image: /content/train//299284_sat.jpg
# Now patchifying image: /content/train//299410_sat.jpg
# Now patchifying image: /content/train//299484_sat.jpg
# Now patchifying image: /content/train//299504_sat.jpg
# Now patchifying image: /content/train//29952_sat.jpg
# Now patchifying image: /content/train//299564_sat.jpg
# Now patchifying image: /content/train//299811_sat.jpg
# Now patchifying image: /content/train//299828_sat.jpg
# Now patchifying image: /content/train//299851_sat.jpg
# Now patchifying image: /content/train//299854_sat.jpg
# Now patchifying image: /content/train//300246_sat.jpg
# Now patchifying image: /content/train//300398_sat.jpg
# Now patchifying image: /content/train//300458_sat.jpg
# Now patchifying image: /content/train//300560_sat.jpg
# Now patchifying image: /content/train//300567_sat.jpg
# Now patchifying image: /content/train//300633_sat.jpg
# Now patchifying image: /content/train//300643_sat.jpg
# Now patchifying image: /content/train//30072_sat.jpg
# Now patchifying image: /content/train//300773_sat.jpg
# Now patchifying image: /content/train//300983_sat.jpg
# Now patchifying image: /content/train//301056_sat.jpg
# Now patchifying image: /content/train//301319_sat.jpg
# Now patchifying image: /content/train//301373_sat.jpg
# Now patchifying image: /content/train//30137_sat.jpg
# Now patchifying image: /content/train//301397_sat.jpg
# Now patchifying image: /content/train//301468_sat.jpg
# Now patchifying image: /content/train//301490_sat.jpg
# Now patchifying image: /content/train//301560_sat.jpg
# Now patchifying image: /content/train//301568_sat.jpg
# Now patchifying image: /content/train//301591_sat.jpg
# Now patchifying image: /content/train//301641_sat.jpg
# Now patchifying image: /content/train//301644_sat.jpg
# Now patchifying image: /content/train//302077_sat.jpg
# Now patchifying image: /content/train//30207_sat.jpg
# Now patchifying image: /content/train//302342_sat.jpg
# Now patchifying image: /content/train//302422_sat.jpg
# Now patchifying image: /content/train//302597_sat.jpg
# Now patchifying image: /content/train//302663_sat.jpg
# Now patchifying image: /content/train//302836_sat.jpg
# Now patchifying image: /content/train//302926_sat.jpg
# Now patchifying image: /content/train//302976_sat.jpg
# Now patchifying image: /content/train//303084_sat.jpg
# Now patchifying image: /content/train//303109_sat.jpg
# Now patchifying image: /content/train//303190_sat.jpg
# Now patchifying image: /content/train//303200_sat.jpg
# Now patchifying image: /content/train//303232_sat.jpg
# Now patchifying image: /content/train//303268_sat.jpg
# Now patchifying image: /content/train//303362_sat.jpg
# Now patchifying image: /content/train//303816_sat.jpg
# Now patchifying image: /content/train//303879_sat.jpg
# Now patchifying image: /content/train//303966_sat.jpg
# Now patchifying image: /content/train//304241_sat.jpg
# Now patchifying image: /content/train//304480_sat.jpg
# Now patchifying image: /content/train//304690_sat.jpg
# Now patchifying image: /content/train//304720_sat.jpg
# Now patchifying image: /content/train//304805_sat.jpg
# Now patchifying image: /content/train//304861_sat.jpg
# Now patchifying image: /content/train//304923_sat.jpg
# Now patchifying image: /content/train//305094_sat.jpg
# Now patchifying image: /content/train//305427_sat.jpg
# Now patchifying image: /content/train//305439_sat.jpg
# Now patchifying image: /content/train//305441_sat.jpg
# Now patchifying image: /content/train//305454_sat.jpg
# Now patchifying image: /content/train//305621_sat.jpg
# Now patchifying image: /content/train//305664_sat.jpg
# Now patchifying image: /content/train//305788_sat.jpg
# Now patchifying image: /content/train//306070_sat.jpg
# Now patchifying image: /content/train//30635_sat.jpg
# Now patchifying image: /content/train//306455_sat.jpg
# Now patchifying image: /content/train//306622_sat.jpg
# Now patchifying image: /content/train//306632_sat.jpg
# Now patchifying image: /content/train//306760_sat.jpg
# Now patchifying image: /content/train//30689_sat.jpg
# Now patchifying image: /content/train//306987_sat.jpg
# Now patchifying image: /content/train//307151_sat.jpg
# Now patchifying image: /content/train//307216_sat.jpg
# Now patchifying image: /content/train//307293_sat.jpg
# Now patchifying image: /content/train//307492_sat.jpg
# Now patchifying image: /content/train//307752_sat.jpg
# Now patchifying image: /content/train//307908_sat.jpg
# Now patchifying image: /content/train//308466_sat.jpg
# Now patchifying image: /content/train//308576_sat.jpg
# Now patchifying image: /content/train//308581_sat.jpg
# Now patchifying image: /content/train//308632_sat.jpg
# Now patchifying image: /content/train//308726_sat.jpg
# Now patchifying image: /content/train//308856_sat.jpg
# Now patchifying image: /content/train//308872_sat.jpg
# Now patchifying image: /content/train//308946_sat.jpg
# Now patchifying image: /content/train//309222_sat.jpg
# Now patchifying image: /content/train//30940_sat.jpg
# Now patchifying image: /content/train//309834_sat.jpg
# Now patchifying image: /content/train//309959_sat.jpg
# Now patchifying image: /content/train//309974_sat.jpg
# Now patchifying image: /content/train//310096_sat.jpg
# Now patchifying image: /content/train//310260_sat.jpg
# Now patchifying image: /content/train//310283_sat.jpg
# Now patchifying image: /content/train//310520_sat.jpg
# Now patchifying image: /content/train//310668_sat.jpg
# Now patchifying image: /content/train//310692_sat.jpg
# Now patchifying image: /content/train//310793_sat.jpg
# Now patchifying image: /content/train//310935_sat.jpg
# Now patchifying image: /content/train//311078_sat.jpg
# Now patchifying image: /content/train//311321_sat.jpg
# Now patchifying image: /content/train//311390_sat.jpg
# Now patchifying image: /content/train//311509_sat.jpg
# Now patchifying image: /content/train//311544_sat.jpg
# Now patchifying image: /content/train//311644_sat.jpg
# Now patchifying image: /content/train//312040_sat.jpg
# Now patchifying image: /content/train//312064_sat.jpg
# Now patchifying image: /content/train//312192_sat.jpg
# Now patchifying image: /content/train//312261_sat.jpg
# Now patchifying image: /content/train//312322_sat.jpg
# Now patchifying image: /content/train//312407_sat.jpg
# Now patchifying image: /content/train//312663_sat.jpg
# Now patchifying image: /content/train//31268_sat.jpg
# Now patchifying image: /content/train//312784_sat.jpg
# Now patchifying image: /content/train//31278_sat.jpg
# Now patchifying image: /content/train//313083_sat.jpg
# Now patchifying image: /content/train//313113_sat.jpg
# Now patchifying image: /content/train//313276_sat.jpg
# Now patchifying image: /content/train//31332_sat.jpg
# Now patchifying image: /content/train//313498_sat.jpg
# Now patchifying image: /content/train//314066_sat.jpg
# Now patchifying image: /content/train//314088_sat.jpg
# Now patchifying image: /content/train//314129_sat.jpg
# Now patchifying image: /content/train//314550_sat.jpg
# Now patchifying image: /content/train//314575_sat.jpg
# Now patchifying image: /content/train//314867_sat.jpg
# Now patchifying image: /content/train//315051_sat.jpg
# Now patchifying image: /content/train//315115_sat.jpg
# Now patchifying image: /content/train//315179_sat.jpg
# Now patchifying image: /content/train//315262_sat.jpg
# Now patchifying image: /content/train//315665_sat.jpg
# Now patchifying image: /content/train//31578_sat.jpg
# Now patchifying image: /content/train//31582_sat.jpg
# Now patchifying image: /content/train//316216_sat.jpg
# Now patchifying image: /content/train//316248_sat.jpg
# Now patchifying image: /content/train//316440_sat.jpg
# Now patchifying image: /content/train//316574_sat.jpg
# Now patchifying image: /content/train//316677_sat.jpg
# Now patchifying image: /content/train//316887_sat.jpg
# Now patchifying image: /content/train//316904_sat.jpg
# Now patchifying image: /content/train//317060_sat.jpg
# Now patchifying image: /content/train//317075_sat.jpg
# Now patchifying image: /content/train//317292_sat.jpg
# Now patchifying image: /content/train//317514_sat.jpg
# Now patchifying image: /content/train//317678_sat.jpg
# Now patchifying image: /content/train//317756_sat.jpg
# Now patchifying image: /content/train//317824_sat.jpg
# Now patchifying image: /content/train//317880_sat.jpg
# Now patchifying image: /content/train//318030_sat.jpg
# Now patchifying image: /content/train//318304_sat.jpg
# Now patchifying image: /content/train//318320_sat.jpg
# Now patchifying image: /content/train//318385_sat.jpg
# Now patchifying image: /content/train//318395_sat.jpg
# Now patchifying image: /content/train//318586_sat.jpg
# Now patchifying image: /content/train//318661_sat.jpg
# Now patchifying image: /content/train//318886_sat.jpg
# Now patchifying image: /content/train//318912_sat.jpg
# Now patchifying image: /content/train//31900_sat.jpg
# Now patchifying image: /content/train//319229_sat.jpg
# Now patchifying image: /content/train//319322_sat.jpg
# Now patchifying image: /content/train//319353_sat.jpg
# Now patchifying image: /content/train//319391_sat.jpg
# Now patchifying image: /content/train//319547_sat.jpg
# Now patchifying image: /content/train//319779_sat.jpg
# Now patchifying image: /content/train//320163_sat.jpg
# Now patchifying image: /content/train//320459_sat.jpg
# Now patchifying image: /content/train//320466_sat.jpg
# Now patchifying image: /content/train//320503_sat.jpg
# Now patchifying image: /content/train//320533_sat.jpg
# Now patchifying image: /content/train//32058_sat.jpg
# Now patchifying image: /content/train//32073_sat.jpg
# Now patchifying image: /content/train//321747_sat.jpg
# Now patchifying image: /content/train//321959_sat.jpg
# Now patchifying image: /content/train//321997_sat.jpg
# Now patchifying image: /content/train//322316_sat.jpg
# Now patchifying image: /content/train//322403_sat.jpg
# Now patchifying image: /content/train//322428_sat.jpg
# Now patchifying image: /content/train//322536_sat.jpg
# Now patchifying image: /content/train//322561_sat.jpg
# Now patchifying image: /content/train//322654_sat.jpg
# Now patchifying image: /content/train//322684_sat.jpg
# Now patchifying image: /content/train//322697_sat.jpg
# Now patchifying image: /content/train//322781_sat.jpg
# Now patchifying image: /content/train//323177_sat.jpg
# Now patchifying image: /content/train//323533_sat.jpg
# Now patchifying image: /content/train//323579_sat.jpg
# Now patchifying image: /content/train//323729_sat.jpg
# Now patchifying image: /content/train//323782_sat.jpg
# Now patchifying image: /content/train//323909_sat.jpg
# Now patchifying image: /content/train//323958_sat.jpg
# Now patchifying image: /content/train//32472_sat.jpg
# Now patchifying image: /content/train//32501_sat.jpg
# Now patchifying image: /content/train//325090_sat.jpg
# Now patchifying image: /content/train//325166_sat.jpg
# Now patchifying image: /content/train//325242_sat.jpg
# Now patchifying image: /content/train//325490_sat.jpg
# Now patchifying image: /content/train//32578_sat.jpg
# Now patchifying image: /content/train//325890_sat.jpg
# Now patchifying image: /content/train//325929_sat.jpg
# Now patchifying image: /content/train//32593_sat.jpg
# Now patchifying image: /content/train//326742_sat.jpg
# Now patchifying image: /content/train//327052_sat.jpg
# Now patchifying image: /content/train//327075_sat.jpg
# Now patchifying image: /content/train//327244_sat.jpg
# Now patchifying image: /content/train//327279_sat.jpg
# Now patchifying image: /content/train//327487_sat.jpg
# Now patchifying image: /content/train//327652_sat.jpg
# Now patchifying image: /content/train//327894_sat.jpg
# Now patchifying image: /content/train//327909_sat.jpg
# Now patchifying image: /content/train//3280_sat.jpg
# Now patchifying image: /content/train//328239_sat.jpg
# Now patchifying image: /content/train//328335_sat.jpg
# Now patchifying image: /content/train//328350_sat.jpg
# Now patchifying image: /content/train//328712_sat.jpg
# Now patchifying image: /content/train//328902_sat.jpg
# Now patchifying image: /content/train//329147_sat.jpg
# Now patchifying image: /content/train//329219_sat.jpg
# Now patchifying image: /content/train//329237_sat.jpg
# Now patchifying image: /content/train//329397_sat.jpg
# Now patchifying image: /content/train//329556_sat.jpg
# Now patchifying image: /content/train//329670_sat.jpg
# Now patchifying image: /content/train//32972_sat.jpg
# Now patchifying image: /content/train//329889_sat.jpg
# Now patchifying image: /content/train//329892_sat.jpg
# Now patchifying image: /content/train//330017_sat.jpg
# Now patchifying image: /content/train//330027_sat.jpg
# Now patchifying image: /content/train//330241_sat.jpg
# Now patchifying image: /content/train//330562_sat.jpg
# Now patchifying image: /content/train//330700_sat.jpg
# Now patchifying image: /content/train//33070_sat.jpg
# Now patchifying image: /content/train//330776_sat.jpg
# Now patchifying image: /content/train//331119_sat.jpg
# Now patchifying image: /content/train//331137_sat.jpg
# Now patchifying image: /content/train//331266_sat.jpg
# Now patchifying image: /content/train//331305_sat.jpg
# Now patchifying image: /content/train//331632_sat.jpg
# Now patchifying image: /content/train//331675_sat.jpg
# Now patchifying image: /content/train//332370_sat.jpg
# Now patchifying image: /content/train//332374_sat.jpg
# Now patchifying image: /content/train//332482_sat.jpg
# Now patchifying image: /content/train//332524_sat.jpg
# Now patchifying image: /content/train//333000_sat.jpg
# Now patchifying image: /content/train//33305_sat.jpg
# Now patchifying image: /content/train//33340_sat.jpg
# Now patchifying image: /content/train//333785_sat.jpg
# Now patchifying image: /content/train//333857_sat.jpg
# Now patchifying image: /content/train//33389_sat.jpg
# Now patchifying image: /content/train//334513_sat.jpg
# Now patchifying image: /content/train//33463_sat.jpg
# Now patchifying image: /content/train//334697_sat.jpg
# Now patchifying image: /content/train//334723_sat.jpg
# Now patchifying image: /content/train//334908_sat.jpg
# Now patchifying image: /content/train//335016_sat.jpg
# Now patchifying image: /content/train//33507_sat.jpg
# Now patchifying image: /content/train//335112_sat.jpg
# Now patchifying image: /content/train//335329_sat.jpg
# Now patchifying image: /content/train//335330_sat.jpg
# Now patchifying image: /content/train//335445_sat.jpg
# Now patchifying image: /content/train//335613_sat.jpg
# Now patchifying image: /content/train//335644_sat.jpg
# Now patchifying image: /content/train//335676_sat.jpg
# Now patchifying image: /content/train//336111_sat.jpg
# Now patchifying image: /content/train//336261_sat.jpg
# Now patchifying image: /content/train//336420_sat.jpg
# Now patchifying image: /content/train//336648_sat.jpg
# Now patchifying image: /content/train//337004_sat.jpg
# Now patchifying image: /content/train//337231_sat.jpg
# Now patchifying image: /content/train//337255_sat.jpg
# Now patchifying image: /content/train//33736_sat.jpg
# Now patchifying image: /content/train//337461_sat.jpg
# Now patchifying image: /content/train//337490_sat.jpg
# Now patchifying image: /content/train//337912_sat.jpg
# Now patchifying image: /content/train//338002_sat.jpg
# Now patchifying image: /content/train//338104_sat.jpg
# Now patchifying image: /content/train//338671_sat.jpg
# Now patchifying image: /content/train//339034_sat.jpg
# Now patchifying image: /content/train//339359_sat.jpg
# Now patchifying image: /content/train//339471_sat.jpg
# Now patchifying image: /content/train//339741_sat.jpg
# Now patchifying image: /content/train//339797_sat.jpg
# Now patchifying image: /content/train//33983_sat.jpg
# Now patchifying image: /content/train//340116_sat.jpg
# Now patchifying image: /content/train//340126_sat.jpg
# Now patchifying image: /content/train//340335_sat.jpg
# Now patchifying image: /content/train//340354_sat.jpg
# Now patchifying image: /content/train//340497_sat.jpg
# Now patchifying image: /content/train//340502_sat.jpg
# Now patchifying image: /content/train//340732_sat.jpg
# Now patchifying image: /content/train//340962_sat.jpg
# Now patchifying image: /content/train//340985_sat.jpg
# Now patchifying image: /content/train//34100_sat.jpg
# Now patchifying image: /content/train//341131_sat.jpg
# Now patchifying image: /content/train//341300_sat.jpg
# Now patchifying image: /content/train//341439_sat.jpg
# Now patchifying image: /content/train//341469_sat.jpg
# Now patchifying image: /content/train//341612_sat.jpg
# Now patchifying image: /content/train//34170_sat.jpg
# Now patchifying image: /content/train//341944_sat.jpg
# Now patchifying image: /content/train//34194_sat.jpg
# Now patchifying image: /content/train//342201_sat.jpg
# Now patchifying image: /content/train//34236_sat.jpg
# Now patchifying image: /content/train//342627_sat.jpg
# Now patchifying image: /content/train//342960_sat.jpg
# Now patchifying image: /content/train//343000_sat.jpg
# Now patchifying image: /content/train//343062_sat.jpg
# Now patchifying image: /content/train//343286_sat.jpg
# Now patchifying image: /content/train//34368_sat.jpg
# Now patchifying image: /content/train//343801_sat.jpg
# Now patchifying image: /content/train//343850_sat.jpg
# Now patchifying image: /content/train//343_sat.jpg
# Now patchifying image: /content/train//344028_sat.jpg
# Now patchifying image: /content/train//344056_sat.jpg
# Now patchifying image: /content/train//344123_sat.jpg
# Now patchifying image: /content/train//344133_sat.jpg
# Now patchifying image: /content/train//344218_sat.jpg
# Now patchifying image: /content/train//344261_sat.jpg
# Now patchifying image: /content/train//344522_sat.jpg
# Now patchifying image: /content/train//344565_sat.jpg
# Now patchifying image: /content/train//344627_sat.jpg
# Now patchifying image: /content/train//345150_sat.jpg
# Now patchifying image: /content/train//34520_sat.jpg
# Now patchifying image: /content/train//34523_sat.jpg
# Now patchifying image: /content/train//34524_sat.jpg
# Now patchifying image: /content/train//345264_sat.jpg
# Now patchifying image: /content/train//3452_sat.jpg
# Now patchifying image: /content/train//345705_sat.jpg
# Now patchifying image: /content/train//345999_sat.jpg
# Now patchifying image: /content/train//346049_sat.jpg
# Now patchifying image: /content/train//346187_sat.jpg
# Now patchifying image: /content/train//346387_sat.jpg
# Now patchifying image: /content/train//346471_sat.jpg
# Now patchifying image: /content/train//346520_sat.jpg
# Now patchifying image: /content/train//346556_sat.jpg
# Now patchifying image: /content/train//346739_sat.jpg
# Now patchifying image: /content/train//346939_sat.jpg
# Now patchifying image: /content/train//347200_sat.jpg
# Now patchifying image: /content/train//347354_sat.jpg
# Now patchifying image: /content/train//347400_sat.jpg
# Now patchifying image: /content/train//347421_sat.jpg
# Now patchifying image: /content/train//347433_sat.jpg
# Now patchifying image: /content/train//347474_sat.jpg
# Now patchifying image: /content/train//347485_sat.jpg
# Now patchifying image: /content/train//347561_sat.jpg
# Now patchifying image: /content/train//347591_sat.jpg
# Now patchifying image: /content/train//347596_sat.jpg
# Now patchifying image: /content/train//347722_sat.jpg
# Now patchifying image: /content/train//347737_sat.jpg
# Now patchifying image: /content/train//347742_sat.jpg
# Now patchifying image: /content/train//347776_sat.jpg
# Now patchifying image: /content/train//347985_sat.jpg
# Now patchifying image: /content/train//348069_sat.jpg
# Now patchifying image: /content/train//348118_sat.jpg
# Now patchifying image: /content/train//348453_sat.jpg
# Now patchifying image: /content/train//348659_sat.jpg
# Now patchifying image: /content/train//348674_sat.jpg
# Now patchifying image: /content/train//34885_sat.jpg
# Now patchifying image: /content/train//348890_sat.jpg
# Now patchifying image: /content/train//348983_sat.jpg
# Now patchifying image: /content/train//349238_sat.jpg
# Now patchifying image: /content/train//349510_sat.jpg
# Now patchifying image: /content/train//34973_sat.jpg
# Now patchifying image: /content/train//349767_sat.jpg
# Now patchifying image: /content/train//350071_sat.jpg
# Now patchifying image: /content/train//35029_sat.jpg
# Now patchifying image: /content/train//350684_sat.jpg
# Now patchifying image: /content/train//351151_sat.jpg
# Now patchifying image: /content/train//351358_sat.jpg
# Now patchifying image: /content/train//351420_sat.jpg
# Now patchifying image: /content/train//351590_sat.jpg
# Now patchifying image: /content/train//351686_sat.jpg
# Now patchifying image: /content/train//351766_sat.jpg
# Now patchifying image: /content/train//351829_sat.jpg
# Now patchifying image: /content/train//35189_sat.jpg
# Now patchifying image: /content/train//351913_sat.jpg
# Now patchifying image: /content/train//352028_sat.jpg
# Now patchifying image: /content/train//352363_sat.jpg
# Now patchifying image: /content/train//352622_sat.jpg
# Now patchifying image: /content/train//352630_sat.jpg
# Now patchifying image: /content/train//352793_sat.jpg
# Now patchifying image: /content/train//352991_sat.jpg
# Now patchifying image: /content/train//353070_sat.jpg
# Now patchifying image: /content/train//3530_sat.jpg
# Now patchifying image: /content/train//353416_sat.jpg
# Now patchifying image: /content/train//353807_sat.jpg
# Now patchifying image: /content/train//354066_sat.jpg
# Now patchifying image: /content/train//354220_sat.jpg
# Now patchifying image: /content/train//354244_sat.jpg
# Now patchifying image: /content/train//354263_sat.jpg
# Now patchifying image: /content/train//35432_sat.jpg
# Now patchifying image: /content/train//354423_sat.jpg
# Now patchifying image: /content/train//354477_sat.jpg
# Now patchifying image: /content/train//354633_sat.jpg
# Now patchifying image: /content/train//354649_sat.jpg
# Now patchifying image: /content/train//354691_sat.jpg
# Now patchifying image: /content/train//354704_sat.jpg
# Now patchifying image: /content/train//354754_sat.jpg
# Now patchifying image: /content/train//354791_sat.jpg
# Now patchifying image: /content/train//354829_sat.jpg
# Now patchifying image: /content/train//354968_sat.jpg
# Now patchifying image: /content/train//355638_sat.jpg
# Now patchifying image: /content/train//356039_sat.jpg
# Now patchifying image: /content/train//356160_sat.jpg
# Now patchifying image: /content/train//356431_sat.jpg
# Now patchifying image: /content/train//356917_sat.jpg
# Now patchifying image: /content/train//357219_sat.jpg
# Now patchifying image: /content/train//357288_sat.jpg
# Now patchifying image: /content/train//357302_sat.jpg
# Now patchifying image: /content/train//357382_sat.jpg
# Now patchifying image: /content/train//3573_sat.jpg
# Now patchifying image: /content/train//357420_sat.jpg
# Now patchifying image: /content/train//357428_sat.jpg
# Now patchifying image: /content/train//357720_sat.jpg
# Now patchifying image: /content/train//357722_sat.jpg
# Now patchifying image: /content/train//357846_sat.jpg
# Now patchifying image: /content/train//357961_sat.jpg
# Now patchifying image: /content/train//358017_sat.jpg
# Now patchifying image: /content/train//358082_sat.jpg
# Now patchifying image: /content/train//358122_sat.jpg
# Now patchifying image: /content/train//358199_sat.jpg
# Now patchifying image: /content/train//358453_sat.jpg
# Now patchifying image: /content/train//358518_sat.jpg
# Now patchifying image: /content/train//358554_sat.jpg
# Now patchifying image: /content/train//358588_sat.jpg
# Now patchifying image: /content/train//35892_sat.jpg
# Now patchifying image: /content/train//359049_sat.jpg
# Now patchifying image: /content/train//359166_sat.jpg
# Now patchifying image: /content/train//35917_sat.jpg
# Now patchifying image: /content/train//359304_sat.jpg
# Now patchifying image: /content/train//359472_sat.jpg
# Now patchifying image: /content/train//3594_sat.jpg
# Now patchifying image: /content/train//359514_sat.jpg
# Now patchifying image: /content/train//359554_sat.jpg
# Now patchifying image: /content/train//359621_sat.jpg
# Now patchifying image: /content/train//360003_sat.jpg
# Now patchifying image: /content/train//360096_sat.jpg
# Now patchifying image: /content/train//360221_sat.jpg
# Now patchifying image: /content/train//360298_sat.jpg
# Now patchifying image: /content/train//3602_sat.jpg
# Now patchifying image: /content/train//360368_sat.jpg
# Now patchifying image: /content/train//360450_sat.jpg
# Now patchifying image: /content/train//36057_sat.jpg
# Now patchifying image: /content/train//360580_sat.jpg
# Now patchifying image: /content/train//360726_sat.jpg
# Now patchifying image: /content/train//36082_sat.jpg
# Now patchifying image: /content/train//360847_sat.jpg
# Now patchifying image: /content/train//361007_sat.jpg
# Now patchifying image: /content/train//361076_sat.jpg
# Now patchifying image: /content/train//361334_sat.jpg
# Now patchifying image: /content/train//361504_sat.jpg
# Now patchifying image: /content/train//361860_sat.jpg
# Now patchifying image: /content/train//361962_sat.jpg
# Now patchifying image: /content/train//362004_sat.jpg
# Now patchifying image: /content/train//362138_sat.jpg
# Now patchifying image: /content/train//362228_sat.jpg
# Now patchifying image: /content/train//362406_sat.jpg
# Now patchifying image: /content/train//36243_sat.jpg
# Now patchifying image: /content/train//362460_sat.jpg
# Now patchifying image: /content/train//362967_sat.jpg
# Now patchifying image: /content/train//363054_sat.jpg
# Now patchifying image: /content/train//363067_sat.jpg
# Now patchifying image: /content/train//363269_sat.jpg
# Now patchifying image: /content/train//363388_sat.jpg
# Now patchifying image: /content/train//363400_sat.jpg
# Now patchifying image: /content/train//363434_sat.jpg
# Now patchifying image: /content/train//363544_sat.jpg
# Now patchifying image: /content/train//363960_sat.jpg
# Now patchifying image: /content/train//364140_sat.jpg
# Now patchifying image: /content/train//364184_sat.jpg
# Now patchifying image: /content/train//364453_sat.jpg
# Now patchifying image: /content/train//364680_sat.jpg
# Now patchifying image: /content/train//364744_sat.jpg
# Now patchifying image: /content/train//364982_sat.jpg
# Now patchifying image: /content/train//365028_sat.jpg
# Now patchifying image: /content/train//365134_sat.jpg
# Now patchifying image: /content/train//365590_sat.jpg
# Now patchifying image: /content/train//365725_sat.jpg
# Now patchifying image: /content/train//365973_sat.jpg
# Now patchifying image: /content/train//366050_sat.jpg
# Now patchifying image: /content/train//366059_sat.jpg
# Now patchifying image: /content/train//366084_sat.jpg
# Now patchifying image: /content/train//366103_sat.jpg
# Now patchifying image: /content/train//36626_sat.jpg
# Now patchifying image: /content/train//366458_sat.jpg
# Now patchifying image: /content/train//36646_sat.jpg
# Now patchifying image: /content/train//366622_sat.jpg
# Now patchifying image: /content/train//366702_sat.jpg
# Now patchifying image: /content/train//36684_sat.jpg
# Now patchifying image: /content/train//367166_sat.jpg
# Now patchifying image: /content/train//367206_sat.jpg
# Now patchifying image: /content/train//367269_sat.jpg
# Now patchifying image: /content/train//367276_sat.jpg
# Now patchifying image: /content/train//367358_sat.jpg
# Now patchifying image: /content/train//367384_sat.jpg
# Now patchifying image: /content/train//367457_sat.jpg
# Now patchifying image: /content/train//367591_sat.jpg
# Now patchifying image: /content/train//367933_sat.jpg
# Now patchifying image: /content/train//368124_sat.jpg
# Now patchifying image: /content/train//368442_sat.jpg
# Now patchifying image: /content/train//368807_sat.jpg
# Now patchifying image: /content/train//368952_sat.jpg
# Now patchifying image: /content/train//36900_sat.jpg
# Now patchifying image: /content/train//369061_sat.jpg
# Now patchifying image: /content/train//369352_sat.jpg
# Now patchifying image: /content/train//369432_sat.jpg
# Now patchifying image: /content/train//369605_sat.jpg
# Now patchifying image: /content/train//369819_sat.jpg
# Now patchifying image: /content/train//36988_sat.jpg
# Now patchifying image: /content/train//369916_sat.jpg
# Now patchifying image: /content/train//370251_sat.jpg
# Now patchifying image: /content/train//370328_sat.jpg
# Now patchifying image: /content/train//370418_sat.jpg
# Now patchifying image: /content/train//370520_sat.jpg
# Now patchifying image: /content/train//370547_sat.jpg
# Now patchifying image: /content/train//370642_sat.jpg
# Now patchifying image: /content/train//370972_sat.jpg
# Now patchifying image: /content/train//371242_sat.jpg
# Now patchifying image: /content/train//371353_sat.jpg
# Now patchifying image: /content/train//371502_sat.jpg
# Now patchifying image: /content/train//371829_sat.jpg
# Now patchifying image: /content/train//372063_sat.jpg
# Now patchifying image: /content/train//372169_sat.jpg
# Now patchifying image: /content/train//372171_sat.jpg
# Now patchifying image: /content/train//372422_sat.jpg
# Now patchifying image: /content/train//372482_sat.jpg
# Now patchifying image: /content/train//372496_sat.jpg
# Now patchifying image: /content/train//372555_sat.jpg
# Now patchifying image: /content/train//372803_sat.jpg
# Now patchifying image: /content/train//373103_sat.jpg
# Now patchifying image: /content/train//373268_sat.jpg
# Now patchifying image: /content/train//373548_sat.jpg
# Now patchifying image: /content/train//373567_sat.jpg
# Now patchifying image: /content/train//373608_sat.jpg
# Now patchifying image: /content/train//373615_sat.jpg
# Now patchifying image: /content/train//373623_sat.jpg
# Now patchifying image: /content/train//373640_sat.jpg
# Now patchifying image: /content/train//37370_sat.jpg
# Now patchifying image: /content/train//373943_sat.jpg
# Now patchifying image: /content/train//374028_sat.jpg
# Now patchifying image: /content/train//37426_sat.jpg
# Now patchifying image: /content/train//374296_sat.jpg
# Now patchifying image: /content/train//374374_sat.jpg
# Now patchifying image: /content/train//374383_sat.jpg
# Now patchifying image: /content/train//374575_sat.jpg
# Now patchifying image: /content/train//374583_sat.jpg
# Now patchifying image: /content/train//37493_sat.jpg
# Now patchifying image: /content/train//375229_sat.jpg
# Now patchifying image: /content/train//375428_sat.jpg
# Now patchifying image: /content/train//375461_sat.jpg
# Now patchifying image: /content/train//375508_sat.jpg
# Now patchifying image: /content/train//375532_sat.jpg
# Now patchifying image: /content/train//375732_sat.jpg
# Now patchifying image: /content/train//375799_sat.jpg
# Now patchifying image: /content/train//375903_sat.jpg
# Now patchifying image: /content/train//375965_sat.jpg
# Now patchifying image: /content/train//376178_sat.jpg
# Now patchifying image: /content/train//376233_sat.jpg
# Now patchifying image: /content/train//376257_sat.jpg
# Now patchifying image: /content/train//376720_sat.jpg
# Now patchifying image: /content/train//377472_sat.jpg
# Now patchifying image: /content/train//377740_sat.jpg
# Now patchifying image: /content/train//377745_sat.jpg
# Now patchifying image: /content/train//378019_sat.jpg
# Now patchifying image: /content/train//378071_sat.jpg
# Now patchifying image: /content/train//378114_sat.jpg
# Now patchifying image: /content/train//378149_sat.jpg
# Now patchifying image: /content/train//378296_sat.jpg
# Now patchifying image: /content/train//378334_sat.jpg
# Now patchifying image: /content/train//378347_sat.jpg
# Now patchifying image: /content/train//378778_sat.jpg
# Now patchifying image: /content/train//379003_sat.jpg
# Now patchifying image: /content/train//379021_sat.jpg
# Now patchifying image: /content/train//379173_sat.jpg
# Now patchifying image: /content/train//379221_sat.jpg
# Now patchifying image: /content/train//379226_sat.jpg
# Now patchifying image: /content/train//37924_sat.jpg
# Now patchifying image: /content/train//379294_sat.jpg
# Now patchifying image: /content/train//379373_sat.jpg
# Now patchifying image: /content/train//379548_sat.jpg
# Now patchifying image: /content/train//379698_sat.jpg
# Now patchifying image: /content/train//37982_sat.jpg
# Now patchifying image: /content/train//379877_sat.jpg
# Now patchifying image: /content/train//380184_sat.jpg
# Now patchifying image: /content/train//380270_sat.jpg
# Now patchifying image: /content/train//380317_sat.jpg
# Now patchifying image: /content/train//380471_sat.jpg
# Now patchifying image: /content/train//38072_sat.jpg
# Now patchifying image: /content/train//38093_sat.jpg
# Now patchifying image: /content/train//381074_sat.jpg
# Now patchifying image: /content/train//38122_sat.jpg
# Now patchifying image: /content/train//38128_sat.jpg
# Now patchifying image: /content/train//38144_sat.jpg
# Now patchifying image: /content/train//381461_sat.jpg
# Now patchifying image: /content/train//381525_sat.jpg
# Now patchifying image: /content/train//381744_sat.jpg
# Now patchifying image: /content/train//381926_sat.jpg
# Now patchifying image: /content/train//382065_sat.jpg
# Now patchifying image: /content/train//382329_sat.jpg
# Now patchifying image: /content/train//382842_sat.jpg
# Now patchifying image: /content/train//383210_sat.jpg
# Now patchifying image: /content/train//383456_sat.jpg
# Now patchifying image: /content/train//38353_sat.jpg
# Now patchifying image: /content/train//384296_sat.jpg
# Now patchifying image: /content/train//384422_sat.jpg
# Now patchifying image: /content/train//384454_sat.jpg
# Now patchifying image: /content/train//384535_sat.jpg
# Now patchifying image: /content/train//384693_sat.jpg
# Now patchifying image: /content/train//384735_sat.jpg
# Now patchifying image: /content/train//384753_sat.jpg
# Now patchifying image: /content/train//38479_sat.jpg
# Now patchifying image: /content/train//384950_sat.jpg
# Now patchifying image: /content/train//385085_sat.jpg
# Now patchifying image: /content/train//385105_sat.jpg
# Now patchifying image: /content/train//385247_sat.jpg
# Now patchifying image: /content/train//385268_sat.jpg
# Now patchifying image: /content/train//385402_sat.jpg
# Now patchifying image: /content/train//385679_sat.jpg
# Now patchifying image: /content/train//385783_sat.jpg
# Now patchifying image: /content/train//385863_sat.jpg
# Now patchifying image: /content/train//385890_sat.jpg
# Now patchifying image: /content/train//385965_sat.jpg
# Now patchifying image: /content/train//38615_sat.jpg
# Now patchifying image: /content/train//386323_sat.jpg
# Now patchifying image: /content/train//386497_sat.jpg
# Now patchifying image: /content/train//386600_sat.jpg
# Now patchifying image: /content/train//386604_sat.jpg
# Now patchifying image: /content/train//387181_sat.jpg
# Now patchifying image: /content/train//387186_sat.jpg
# Now patchifying image: /content/train//387383_sat.jpg
# Now patchifying image: /content/train//387942_sat.jpg
# Now patchifying image: /content/train//388071_sat.jpg
# Now patchifying image: /content/train//388122_sat.jpg
# Now patchifying image: /content/train//388859_sat.jpg
# Now patchifying image: /content/train//388957_sat.jpg
# Now patchifying image: /content/train//388_sat.jpg
# Now patchifying image: /content/train//389263_sat.jpg
# Now patchifying image: /content/train//38954_sat.jpg
# Now patchifying image: /content/train//389552_sat.jpg
# Now patchifying image: /content/train//389555_sat.jpg
# Now patchifying image: /content/train//389656_sat.jpg
# Now patchifying image: /content/train//390011_sat.jpg
# Now patchifying image: /content/train//390180_sat.jpg
# Now patchifying image: /content/train//390365_sat.jpg
# Now patchifying image: /content/train//39045_sat.jpg
# Now patchifying image: /content/train//390727_sat.jpg
# Now patchifying image: /content/train//390893_sat.jpg
# Now patchifying image: /content/train//390928_sat.jpg
# Now patchifying image: /content/train//390952_sat.jpg
# Now patchifying image: /content/train//391190_sat.jpg
# Now patchifying image: /content/train//391293_sat.jpg
# Now patchifying image: /content/train//391538_sat.jpg
# Now patchifying image: /content/train//391660_sat.jpg
# Now patchifying image: /content/train//391736_sat.jpg
# Now patchifying image: /content/train//391989_sat.jpg
# Now patchifying image: /content/train//392105_sat.jpg
# Now patchifying image: /content/train//392225_sat.jpg
# Now patchifying image: /content/train//392230_sat.jpg
# Now patchifying image: /content/train//392268_sat.jpg
# Now patchifying image: /content/train//392410_sat.jpg
# Now patchifying image: /content/train//392609_sat.jpg
# Now patchifying image: /content/train//392686_sat.jpg
# Now patchifying image: /content/train//39277_sat.jpg
# Now patchifying image: /content/train//393063_sat.jpg
# Now patchifying image: /content/train//393111_sat.jpg
# Now patchifying image: /content/train//393127_sat.jpg
# Now patchifying image: /content/train//393166_sat.jpg
# Now patchifying image: /content/train//393252_sat.jpg
# Now patchifying image: /content/train//393469_sat.jpg
# Now patchifying image: /content/train//393590_sat.jpg
# Now patchifying image: /content/train//39367_sat.jpg
# Now patchifying image: /content/train//394008_sat.jpg
# Now patchifying image: /content/train//394020_sat.jpg
# Now patchifying image: /content/train//394074_sat.jpg
# Now patchifying image: /content/train//394093_sat.jpg
# Now patchifying image: /content/train//394175_sat.jpg
# Now patchifying image: /content/train//394310_sat.jpg
# Now patchifying image: /content/train//394496_sat.jpg
# Now patchifying image: /content/train//395029_sat.jpg
# Now patchifying image: /content/train//395265_sat.jpg
# Now patchifying image: /content/train//395487_sat.jpg
# Now patchifying image: /content/train//395611_sat.jpg
# Now patchifying image: /content/train//395621_sat.jpg
# Now patchifying image: /content/train//395879_sat.jpg
# Now patchifying image: /content/train//396252_sat.jpg
# Now patchifying image: /content/train//396274_sat.jpg
# Now patchifying image: /content/train//396352_sat.jpg
# Now patchifying image: /content/train//396744_sat.jpg
# Now patchifying image: /content/train//396836_sat.jpg
# Now patchifying image: /content/train//39694_sat.jpg
# Now patchifying image: /content/train//397493_sat.jpg
# Now patchifying image: /content/train//397590_sat.jpg
# Now patchifying image: /content/train//397989_sat.jpg
# Now patchifying image: /content/train//398137_sat.jpg
# Now patchifying image: /content/train//398502_sat.jpg
# Now patchifying image: /content/train//398587_sat.jpg
# Now patchifying image: /content/train//398701_sat.jpg
# Now patchifying image: /content/train//39878_sat.jpg
# Now patchifying image: /content/train//398826_sat.jpg
# Now patchifying image: /content/train//39884_sat.jpg
# Now patchifying image: /content/train//398890_sat.jpg
# Now patchifying image: /content/train//399058_sat.jpg
# Now patchifying image: /content/train//399107_sat.jpg
# Now patchifying image: /content/train//399244_sat.jpg
# Now patchifying image: /content/train//399251_sat.jpg
# Now patchifying image: /content/train//399432_sat.jpg
# Now patchifying image: /content/train//39945_sat.jpg
# Now patchifying image: /content/train//399518_sat.jpg
# Now patchifying image: /content/train//399543_sat.jpg
# Now patchifying image: /content/train//399786_sat.jpg
# Now patchifying image: /content/train//400466_sat.jpg
# Now patchifying image: /content/train//400501_sat.jpg
# Now patchifying image: /content/train//400636_sat.jpg
# Now patchifying image: /content/train//400649_sat.jpg
# Now patchifying image: /content/train//400782_sat.jpg
# Now patchifying image: /content/train//400830_sat.jpg
# Now patchifying image: /content/train//400867_sat.jpg
# Now patchifying image: /content/train//400877_sat.jpg
# Now patchifying image: /content/train//401242_sat.jpg
# Now patchifying image: /content/train//401257_sat.jpg
# Now patchifying image: /content/train//401413_sat.jpg
# Now patchifying image: /content/train//401529_sat.jpg
# Now patchifying image: /content/train//401546_sat.jpg
# Now patchifying image: /content/train//401562_sat.jpg
# Now patchifying image: /content/train//401773_sat.jpg
# Now patchifying image: /content/train//402071_sat.jpg
# ...
# Now patchifying image: /content/train//95245_sat.jpg
# Now patchifying image: /content/train//953074_sat.jpg
# Now patchifying image: /content/train//953175_sat.jpg
# Now patchifying image: /content/train//953228_sat.jpg
# Now patchifying image: /content/train//953426_sat.jpg
# Now patchifying image: /content/train//953495_sat.jpg
# Now patchifying image: /content/train//953595_sat.jpg
# Now patchifying image: /content/train//954085_sat.jpg
# Now patchifying image: /content/train//954214_sat.jpg
# Now patchifying image: /content/train//954319_sat.jpg
# Now patchifying image: /content/train//95440_sat.jpg
# Now patchifying image: /content/train//95471_sat.jpg
# Now patchifying image: /content/train//954725_sat.jpg
# Now patchifying image: /content/train//954744_sat.jpg
# Now patchifying image: /content/train//955344_sat.jpg
# Now patchifying image: /content/train//955401_sat.jpg
# Now patchifying image: /content/train//955526_sat.jpg
# Now patchifying image: /content/train//955634_sat.jpg
# Now patchifying image: /content/train//955699_sat.jpg
# Now patchifying image: /content/train//95571_sat.jpg
# Now patchifying image: /content/train//95573_sat.jpg
# Now patchifying image: /content/train//955948_sat.jpg
# Now patchifying image: /content/train//955978_sat.jpg
# Now patchifying image: /content/train//956106_sat.jpg
# Now patchifying image: /content/train//956757_sat.jpg
# Now patchifying image: /content/train//956924_sat.jpg
# Now patchifying image: /content/train//956979_sat.jpg
# Now patchifying image: /content/train//957208_sat.jpg
# Now patchifying image: /content/train//957367_sat.jpg
# Now patchifying image: /content/train//957508_sat.jpg
# Now patchifying image: /content/train//957650_sat.jpg
# Now patchifying image: /content/train//957715_sat.jpg
# Now patchifying image: /content/train//957825_sat.jpg
# Now patchifying image: /content/train//957898_sat.jpg
# Now patchifying image: /content/train//958471_sat.jpg
# Now patchifying image: /content/train//958571_sat.jpg
# Now patchifying image: /content/train//958932_sat.jpg
# Now patchifying image: /content/train//958998_sat.jpg
# Now patchifying image: /content/train//959032_sat.jpg
# Now patchifying image: /content/train//959091_sat.jpg
# Now patchifying image: /content/train//95932_sat.jpg
# Now patchifying image: /content/train//959424_sat.jpg
# Now patchifying image: /content/train//959435_sat.jpg
# Now patchifying image: /content/train//959496_sat.jpg
# Now patchifying image: /content/train//959529_sat.jpg
# Now patchifying image: /content/train//959705_sat.jpg
# Now patchifying image: /content/train//959925_sat.jpg
# Now patchifying image: /content/train//960162_sat.jpg
# Now patchifying image: /content/train//960287_sat.jpg
# Now patchifying image: /content/train//960291_sat.jpg
# Now patchifying image: /content/train//960372_sat.jpg
# Now patchifying image: /content/train//960471_sat.jpg
# Now patchifying image: /content/train//960631_sat.jpg
# Now patchifying image: /content/train//960793_sat.jpg
# Now patchifying image: /content/train//960845_sat.jpg
# Now patchifying image: /content/train//960918_sat.jpg
# Now patchifying image: /content/train//961077_sat.jpg
# Now patchifying image: /content/train//961236_sat.jpg
# Now patchifying image: /content/train//961336_sat.jpg
# Now patchifying image: /content/train//961425_sat.jpg
# Now patchifying image: /content/train//961487_sat.jpg
# Now patchifying image: /content/train//961531_sat.jpg
# Now patchifying image: /content/train//962072_sat.jpg
# Now patchifying image: /content/train//962829_sat.jpg
# Now patchifying image: /content/train//962887_sat.jpg
# Now patchifying image: /content/train//962988_sat.jpg
# Now patchifying image: /content/train//963225_sat.jpg
# Now patchifying image: /content/train//96326_sat.jpg
# Now patchifying image: /content/train//963389_sat.jpg
# Now patchifying image: /content/train//963426_sat.jpg
# Now patchifying image: /content/train//963805_sat.jpg
# Now patchifying image: /content/train//96399_sat.jpg
# Now patchifying image: /content/train//964261_sat.jpg
# Now patchifying image: /content/train//964308_sat.jpg
# Now patchifying image: /content/train//964555_sat.jpg
# Now patchifying image: /content/train//964566_sat.jpg
# Now patchifying image: /content/train//964590_sat.jpg
# Now patchifying image: /content/train//964793_sat.jpg
# Now patchifying image: /content/train//964926_sat.jpg
# Now patchifying image: /content/train//965147_sat.jpg
# Now patchifying image: /content/train//965322_sat.jpg
# Now patchifying image: /content/train//965349_sat.jpg
# Now patchifying image: /content/train//965378_sat.jpg
# Now patchifying image: /content/train//96543_sat.jpg
# Now patchifying image: /content/train//965750_sat.jpg
# Now patchifying image: /content/train//966260_sat.jpg
# Now patchifying image: /content/train//966295_sat.jpg
# Now patchifying image: /content/train//966308_sat.jpg
# Now patchifying image: /content/train//96635_sat.jpg
# Now patchifying image: /content/train//96639_sat.jpg
# Now patchifying image: /content/train//9663_sat.jpg
# Now patchifying image: /content/train//966419_sat.jpg
# Now patchifying image: /content/train//966525_sat.jpg
# Now patchifying image: /content/train//966535_sat.jpg
# Now patchifying image: /content/train//966712_sat.jpg
# Now patchifying image: /content/train//966775_sat.jpg
# Now patchifying image: /content/train//966786_sat.jpg
# Now patchifying image: /content/train//966836_sat.jpg
# Now patchifying image: /content/train//967447_sat.jpg
# Now patchifying image: /content/train//967643_sat.jpg
# Now patchifying image: /content/train//967951_sat.jpg
# Now patchifying image: /content/train//968022_sat.jpg
# Now patchifying image: /content/train//968202_sat.jpg
# Now patchifying image: /content/train//968546_sat.jpg
# Now patchifying image: /content/train//968690_sat.jpg
# Now patchifying image: /content/train//968835_sat.jpg
# Now patchifying image: /content/train//968959_sat.jpg
# Now patchifying image: /content/train//969001_sat.jpg
# Now patchifying image: /content/train//969029_sat.jpg
# Now patchifying image: /content/train//96905_sat.jpg
# Now patchifying image: /content/train//969112_sat.jpg
# Now patchifying image: /content/train//969507_sat.jpg
# Now patchifying image: /content/train//969794_sat.jpg
# Now patchifying image: /content/train//969845_sat.jpg
# Now patchifying image: /content/train//970229_sat.jpg
# Now patchifying image: /content/train//970400_sat.jpg
# Now patchifying image: /content/train//970706_sat.jpg
# Now patchifying image: /content/train//971038_sat.jpg
# Now patchifying image: /content/train//97115_sat.jpg
# Now patchifying image: /content/train//971177_sat.jpg
# Now patchifying image: /content/train//971228_sat.jpg
# Now patchifying image: /content/train//971299_sat.jpg
# Now patchifying image: /content/train//971922_sat.jpg
# Now patchifying image: /content/train//972206_sat.jpg
# Now patchifying image: /content/train//972254_sat.jpg
# Now patchifying image: /content/train//972546_sat.jpg
# Now patchifying image: /content/train//972689_sat.jpg
# Now patchifying image: /content/train//97272_sat.jpg
# Now patchifying image: /content/train//97279_sat.jpg
# Now patchifying image: /content/train//97287_sat.jpg
# Now patchifying image: /content/train//973063_sat.jpg
# Now patchifying image: /content/train//973094_sat.jpg
# Now patchifying image: /content/train//97321_sat.jpg
# Now patchifying image: /content/train//973434_sat.jpg
# Now patchifying image: /content/train//973490_sat.jpg
# Now patchifying image: /content/train//973890_sat.jpg
# Now patchifying image: /content/train//973982_sat.jpg
# Now patchifying image: /content/train//974158_sat.jpg
# Now patchifying image: /content/train//974250_sat.jpg
# Now patchifying image: /content/train//974256_sat.jpg
# Now patchifying image: /content/train//974637_sat.jpg
# Now patchifying image: /content/train//974696_sat.jpg
# Now patchifying image: /content/train//974725_sat.jpg
# Now patchifying image: /content/train//974773_sat.jpg
# Now patchifying image: /content/train//974843_sat.jpg
# Now patchifying image: /content/train//975274_sat.jpg
# Now patchifying image: /content/train//975973_sat.jpg
# Now patchifying image: /content/train//97627_sat.jpg
# Now patchifying image: /content/train//976309_sat.jpg
# Now patchifying image: /content/train//976327_sat.jpg
# Now patchifying image: /content/train//976438_sat.jpg
# Now patchifying image: /content/train//976451_sat.jpg
# Now patchifying image: /content/train//976537_sat.jpg
# Now patchifying image: /content/train//976759_sat.jpg
# Now patchifying image: /content/train//976894_sat.jpg
# Now patchifying image: /content/train//976914_sat.jpg
# Now patchifying image: /content/train//976970_sat.jpg
# Now patchifying image: /content/train//97748_sat.jpg
# Now patchifying image: /content/train//977848_sat.jpg
# Now patchifying image: /content/train//978037_sat.jpg
# Now patchifying image: /content/train//978104_sat.jpg
# Now patchifying image: /content/train//978201_sat.jpg
# Now patchifying image: /content/train//978339_sat.jpg
# Now patchifying image: /content/train//97837_sat.jpg
# Now patchifying image: /content/train//978406_sat.jpg
# Now patchifying image: /content/train//978495_sat.jpg
# Now patchifying image: /content/train//97852_sat.jpg
# Now patchifying image: /content/train//97854_sat.jpg
# Now patchifying image: /content/train//979028_sat.jpg
# Now patchifying image: /content/train//979149_sat.jpg
# Now patchifying image: /content/train//979246_sat.jpg
# Now patchifying image: /content/train//979506_sat.jpg
# Now patchifying image: /content/train//979605_sat.jpg
# Now patchifying image: /content/train//979669_sat.jpg
# Now patchifying image: /content/train//979688_sat.jpg
# Now patchifying image: /content/train//979812_sat.jpg
# Now patchifying image: /content/train//979854_sat.jpg
# Now patchifying image: /content/train//979932_sat.jpg
# Now patchifying image: /content/train//980030_sat.jpg
# Now patchifying image: /content/train//980164_sat.jpg
# Now patchifying image: /content/train//980177_sat.jpg
# Now patchifying image: /content/train//98029_sat.jpg
# Now patchifying image: /content/train//980683_sat.jpg
# Now patchifying image: /content/train//980712_sat.jpg
# Now patchifying image: /content/train//980975_sat.jpg
# Now patchifying image: /content/train//98157_sat.jpg
# Now patchifying image: /content/train//981645_sat.jpg
# Now patchifying image: /content/train//981956_sat.jpg
# Now patchifying image: /content/train//982013_sat.jpg
# Now patchifying image: /content/train//98225_sat.jpg
# Now patchifying image: /content/train//982331_sat.jpg
# Now patchifying image: /content/train//982396_sat.jpg
# Now patchifying image: /content/train//982721_sat.jpg
# Now patchifying image: /content/train//982866_sat.jpg
# Now patchifying image: /content/train//982907_sat.jpg
# Now patchifying image: /content/train//983744_sat.jpg
# Now patchifying image: /content/train//983851_sat.jpg
# Now patchifying image: /content/train//983884_sat.jpg
# Now patchifying image: /content/train//983887_sat.jpg
# Now patchifying image: /content/train//984363_sat.jpg
# Now patchifying image: /content/train//984438_sat.jpg
# Now patchifying image: /content/train//98477_sat.jpg
# Now patchifying image: /content/train//985064_sat.jpg
# Now patchifying image: /content/train//985216_sat.jpg
# Now patchifying image: /content/train//985595_sat.jpg
# Now patchifying image: /content/train//985661_sat.jpg
# Now patchifying image: /content/train//985731_sat.jpg
# Now patchifying image: /content/train//985902_sat.jpg
# Now patchifying image: /content/train//98599_sat.jpg
# Now patchifying image: /content/train//986182_sat.jpg
# Now patchifying image: /content/train//9872_sat.jpg
# Now patchifying image: /content/train//987330_sat.jpg
# Now patchifying image: /content/train//987408_sat.jpg
# Now patchifying image: /content/train//987623_sat.jpg
# Now patchifying image: /content/train//987822_sat.jpg
# Now patchifying image: /content/train//987823_sat.jpg
# Now patchifying image: /content/train//987840_sat.jpg
# Now patchifying image: /content/train//988341_sat.jpg
# Now patchifying image: /content/train//988559_sat.jpg
# Now patchifying image: /content/train//988774_sat.jpg
# Now patchifying image: /content/train//989146_sat.jpg
# Now patchifying image: /content/train//989174_sat.jpg
# Now patchifying image: /content/train//989343_sat.jpg
# Now patchifying image: /content/train//989398_sat.jpg
# Now patchifying image: /content/train//989455_sat.jpg
# Now patchifying image: /content/train//989480_sat.jpg
# Now patchifying image: /content/train//989763_sat.jpg
# Now patchifying image: /content/train//990020_sat.jpg
# Now patchifying image: /content/train//990140_sat.jpg
# Now patchifying image: /content/train//990181_sat.jpg
# Now patchifying image: /content/train//990478_sat.jpg
# Now patchifying image: /content/train//990503_sat.jpg
# Now patchifying image: /content/train//990561_sat.jpg
# Now patchifying image: /content/train//990851_sat.jpg
# Now patchifying image: /content/train//991243_sat.jpg
# Now patchifying image: /content/train//991347_sat.jpg
# Now patchifying image: /content/train//991373_sat.jpg
# Now patchifying image: /content/train//991392_sat.jpg
# Now patchifying image: /content/train//991461_sat.jpg
# Now patchifying image: /content/train//991845_sat.jpg
# Now patchifying image: /content/train//991988_sat.jpg
# Now patchifying image: /content/train//992083_sat.jpg
# Now patchifying image: /content/train//992317_sat.jpg
# Now patchifying image: /content/train//992343_sat.jpg
# Now patchifying image: /content/train//992526_sat.jpg
# Now patchifying image: /content/train//992768_sat.jpg
# Now patchifying image: /content/train//993012_sat.jpg
# Now patchifying image: /content/train//993226_sat.jpg
# Now patchifying image: /content/train//993412_sat.jpg
# Now patchifying image: /content/train//993483_sat.jpg
# Now patchifying image: /content/train//993491_sat.jpg
# Now patchifying image: /content/train//993512_sat.jpg
# Now patchifying image: /content/train//99367_sat.jpg
# Now patchifying image: /content/train//993763_sat.jpg
# Now patchifying image: /content/train//9937_sat.jpg
# Now patchifying image: /content/train//993822_sat.jpg
# Now patchifying image: /content/train//994121_sat.jpg
# Now patchifying image: /content/train//994363_sat.jpg
# Now patchifying image: /content/train//994421_sat.jpg
# Now patchifying image: /content/train//994850_sat.jpg
# Now patchifying image: /content/train//994957_sat.jpg
# Now patchifying image: /content/train//995287_sat.jpg
# Now patchifying image: /content/train//995305_sat.jpg
# Now patchifying image: /content/train//995558_sat.jpg
# Now patchifying image: /content/train//995739_sat.jpg
# Now patchifying image: /content/train//995758_sat.jpg
# Now patchifying image: /content/train//995848_sat.jpg
# Now patchifying image: /content/train//996088_sat.jpg
# Now patchifying image: /content/train//996111_sat.jpg
# Now patchifying image: /content/train//99639_sat.jpg
# Now patchifying image: /content/train//99665_sat.jpg
# Now patchifying image: /content/train//996759_sat.jpg
# Now patchifying image: /content/train//996898_sat.jpg
# Now patchifying image: /content/train//996964_sat.jpg
# Now patchifying image: /content/train//996972_sat.jpg
# Now patchifying image: /content/train//99706_sat.jpg
# Now patchifying image: /content/train//997140_sat.jpg
# Now patchifying image: /content/train//997687_sat.jpg
# Now patchifying image: /content/train//997706_sat.jpg
# Now patchifying image: /content/train//997777_sat.jpg
# Now patchifying image: /content/train//997873_sat.jpg
# Now patchifying image: /content/train//997980_sat.jpg
# Now patchifying image: /content/train//997999_sat.jpg
# Now patchifying image: /content/train//998069_sat.jpg
# Now patchifying image: /content/train//998098_sat.jpg
# Now patchifying image: /content/train//998129_sat.jpg
# Now patchifying image: /content/train//99816_sat.jpg
# Now patchifying image: /content/train//99884_sat.jpg
# Now patchifying image: /content/train//999130_sat.jpg
# Now patchifying image: /content/train//99913_sat.jpg
# Now patchifying image: /content/train//999233_sat.jpg
# Now patchifying image: /content/train//999248_sat.jpg
# Now patchifying image: /content/train//999431_sat.jpg
# Now patchifying image: /content/train//999531_sat.jpg
# Now patchifying image: /content/train//999667_sat.jpg
# Now patchifying image: /content/train//999764_sat.jpg
# Now patchifying image: /content/train//99995_sat.jpg

# %%
cd '/content/256_patches/masks'
# Out:
# /content/256_patches/masks

# %%
for path, subdirs, files in os.walk(img_dir):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    #print(dirname)
    images = os.listdir(path)
    images = sorted(images)  #List of all image names in this subdirectory
    #print(images)
    for i, image_name in enumerate(sorted(images)):  
        if image_name.endswith(".png"):
            #print(image_name)
            image = cv2.imread(path+"/"+image_name, 1)  #Read each image as BGR
            SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
            SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
            image = Image.fromarray(image)
            image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
            #image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
            image = np.array(image)             
   
            #Extract patches from each image
            print("Now patchifying image:", path+"/"+image_name)
            patches_img = patchify(image, (256, 256, 3), step=256)  #Step=256 for 256 patches means no overlap
    
            for i in range(patches_img.shape[0]):
                for j in range(patches_img.shape[1]):
                    
                    single_patch_img = patches_img[i,j,:,:]
                    #single_patch_img = (single_patch_img.astype('float32')) / 255. #We will preprocess using one of the backbones
                    single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.                               
                    
                    cv2.imwrite(image_name+"patch_"+str(i)+str(j)+".png", single_patch_img)
                    #image_dataset.append(single_patch_img)
# Out:
# Streaming output truncated to the last 5000 lines.
# Now patchifying image: /content/train//279367_mask.png
# Now patchifying image: /content/train//279620_mask.png
# Now patchifying image: /content/train//279807_mask.png
# Now patchifying image: /content/train//279862_mask.png
# Now patchifying image: /content/train//279971_mask.png
# Now patchifying image: /content/train//280022_mask.png
# Now patchifying image: /content/train//280425_mask.png
# Now patchifying image: /content/train//280509_mask.png
# Now patchifying image: /content/train//280694_mask.png
# Now patchifying image: /content/train//280955_mask.png
# Now patchifying image: /content/train//281008_mask.png
# Now patchifying image: /content/train//281122_mask.png
# Now patchifying image: /content/train//281208_mask.png
# Now patchifying image: /content/train//281344_mask.png
# Now patchifying image: /content/train//281355_mask.png
# Now patchifying image: /content/train//281530_mask.png
# Now patchifying image: /content/train//282201_mask.png
# Now patchifying image: /content/train//282386_mask.png
# Now patchifying image: /content/train//282426_mask.png
# Now patchifying image: /content/train//282861_mask.png
# Now patchifying image: /content/train//282949_mask.png
# Now patchifying image: /content/train//282956_mask.png
# Now patchifying image: /content/train//282986_mask.png
# Now patchifying image: /content/train//282992_mask.png
# Now patchifying image: /content/train//283097_mask.png
# Now patchifying image: /content/train//283125_mask.png
# Now patchifying image: /content/train//283271_mask.png
# Now patchifying image: /content/train//28332_mask.png
# Now patchifying image: /content/train//283392_mask.png
# Now patchifying image: /content/train//283581_mask.png
# Now patchifying image: /content/train//283650_mask.png
# Now patchifying image: /content/train//284083_mask.png
# Now patchifying image: /content/train//284094_mask.png
# Now patchifying image: /content/train//284571_mask.png
# Now patchifying image: /content/train//284729_mask.png
# Now patchifying image: /content/train//284874_mask.png
# Now patchifying image: /content/train//285121_mask.png
# Now patchifying image: /content/train//285170_mask.png
# Now patchifying image: /content/train//285194_mask.png
# Now patchifying image: /content/train//285214_mask.png
# Now patchifying image: /content/train//285361_mask.png
# Now patchifying image: /content/train//285518_mask.png
# Now patchifying image: /content/train//285535_mask.png
# Now patchifying image: /content/train//285789_mask.png
# Now patchifying image: /content/train//285810_mask.png
# Now patchifying image: /content/train//285997_mask.png
# Now patchifying image: /content/train//286013_mask.png
# Now patchifying image: /content/train//286038_mask.png
# Now patchifying image: /content/train//28606_mask.png
# Now patchifying image: /content/train//286172_mask.png
# Now patchifying image: /content/train//286300_mask.png
# Now patchifying image: /content/train//286322_mask.png
# Now patchifying image: /content/train//286360_mask.png
# Now patchifying image: /content/train//286361_mask.png
# Now patchifying image: /content/train//286522_mask.png
# Now patchifying image: /content/train//286534_mask.png
# Now patchifying image: /content/train//286647_mask.png
# Now patchifying image: /content/train//286902_mask.png
# Now patchifying image: /content/train//287058_mask.png
# Now patchifying image: /content/train//28727_mask.png
# Now patchifying image: /content/train//287479_mask.png
# Now patchifying image: /content/train//287575_mask.png
# Now patchifying image: /content/train//287766_mask.png
# Now patchifying image: /content/train//287837_mask.png
# Now patchifying image: /content/train//287902_mask.png
# Now patchifying image: /content/train//288328_mask.png
# Now patchifying image: /content/train//288500_mask.png
# Now patchifying image: /content/train//28863_mask.png
# Now patchifying image: /content/train//288657_mask.png
# Now patchifying image: /content/train//288725_mask.png
# Now patchifying image: /content/train//288746_mask.png
# Now patchifying image: /content/train//289032_mask.png
# Now patchifying image: /content/train//28905_mask.png
# Now patchifying image: /content/train//289200_mask.png
# Now patchifying image: /content/train//289212_mask.png
# Now patchifying image: /content/train//289483_mask.png
# Now patchifying image: /content/train//289537_mask.png
# Now patchifying image: /content/train//289571_mask.png
# Now patchifying image: /content/train//289584_mask.png
# Now patchifying image: /content/train//289816_mask.png
# Now patchifying image: /content/train//289860_mask.png
# Now patchifying image: /content/train//289959_mask.png
# Now patchifying image: /content/train//290194_mask.png
# Now patchifying image: /content/train//29019_mask.png
# Now patchifying image: /content/train//290274_mask.png
# Now patchifying image: /content/train//290295_mask.png
# Now patchifying image: /content/train//290444_mask.png
# Now patchifying image: /content/train//290587_mask.png
# Now patchifying image: /content/train//290735_mask.png
# Now patchifying image: /content/train//290907_mask.png
# Now patchifying image: /content/train//291105_mask.png
# Now patchifying image: /content/train//291185_mask.png
# Now patchifying image: /content/train//291379_mask.png
# Now patchifying image: /content/train//291574_mask.png
# Now patchifying image: /content/train//291592_mask.png
# Now patchifying image: /content/train//291871_mask.png
# Now patchifying image: /content/train//29198_mask.png
# Now patchifying image: /content/train//292384_mask.png
# Now patchifying image: /content/train//292623_mask.png
# Now patchifying image: /content/train//292753_mask.png
# Now patchifying image: /content/train//292761_mask.png
# Now patchifying image: /content/train//292950_mask.png
# Now patchifying image: /content/train//293084_mask.png
# Now patchifying image: /content/train//293186_mask.png
# Now patchifying image: /content/train//293544_mask.png
# Now patchifying image: /content/train//293592_mask.png
# Now patchifying image: /content/train//293742_mask.png
# Now patchifying image: /content/train//294143_mask.png
# Now patchifying image: /content/train//294187_mask.png
# Now patchifying image: /content/train//294502_mask.png
# Now patchifying image: /content/train//294701_mask.png
# Now patchifying image: /content/train//294813_mask.png
# Now patchifying image: /content/train//295004_mask.png
# Now patchifying image: /content/train//295066_mask.png
# Now patchifying image: /content/train//295092_mask.png
# Now patchifying image: /content/train//29509_mask.png
# Now patchifying image: /content/train//295135_mask.png
# Now patchifying image: /content/train//295155_mask.png
# Now patchifying image: /content/train//295328_mask.png
# Now patchifying image: /content/train//295372_mask.png
# Now patchifying image: /content/train//295393_mask.png
# Now patchifying image: /content/train//295447_mask.png
# Now patchifying image: /content/train//295482_mask.png
# Now patchifying image: /content/train//295973_mask.png
# Now patchifying image: /content/train//296095_mask.png
# Now patchifying image: /content/train//296271_mask.png
# Now patchifying image: /content/train//296505_mask.png
# Now patchifying image: /content/train//296546_mask.png
# Now patchifying image: /content/train//296629_mask.png
# Now patchifying image: /content/train//296658_mask.png
# Now patchifying image: /content/train//296759_mask.png
# Now patchifying image: /content/train//296866_mask.png
# Now patchifying image: /content/train//296918_mask.png
# Now patchifying image: /content/train//297007_mask.png
# Now patchifying image: /content/train//297017_mask.png
# Now patchifying image: /content/train//297062_mask.png
# Now patchifying image: /content/train//297152_mask.png
# Now patchifying image: /content/train//297409_mask.png
# Now patchifying image: /content/train//297515_mask.png
# Now patchifying image: /content/train//297633_mask.png
# Now patchifying image: /content/train//297834_mask.png
# Now patchifying image: /content/train//297846_mask.png
# Now patchifying image: /content/train//297868_mask.png
# Now patchifying image: /content/train//297896_mask.png
# Now patchifying image: /content/train//297932_mask.png
# Now patchifying image: /content/train//297975_mask.png
# Now patchifying image: /content/train//298351_mask.png
# Now patchifying image: /content/train//298428_mask.png
# Now patchifying image: /content/train//298463_mask.png
# Now patchifying image: /content/train//29846_mask.png
# Now patchifying image: /content/train//298555_mask.png
# Now patchifying image: /content/train//298588_mask.png
# Now patchifying image: /content/train//298613_mask.png
# Now patchifying image: /content/train//29889_mask.png
# Now patchifying image: /content/train//298975_mask.png
# Now patchifying image: /content/train//298999_mask.png
# Now patchifying image: /content/train//299005_mask.png
# Now patchifying image: /content/train//299015_mask.png
# Now patchifying image: /content/train//299051_mask.png
# Now patchifying image: /content/train//299066_mask.png
# Now patchifying image: /content/train//299115_mask.png
# Now patchifying image: /content/train//299142_mask.png
# Now patchifying image: /content/train//299227_mask.png
# Now patchifying image: /content/train//299284_mask.png
# Now patchifying image: /content/train//299410_mask.png
# Now patchifying image: /content/train//299484_mask.png
# Now patchifying image: /content/train//299504_mask.png
# Now patchifying image: /content/train//29952_mask.png
# Now patchifying image: /content/train//299564_mask.png
# Now patchifying image: /content/train//299811_mask.png
# Now patchifying image: /content/train//299828_mask.png
# Now patchifying image: /content/train//299851_mask.png
# Now patchifying image: /content/train//299854_mask.png
# Now patchifying image: /content/train//300246_mask.png
# Now patchifying image: /content/train//300398_mask.png
# Now patchifying image: /content/train//300458_mask.png
# Now patchifying image: /content/train//300560_mask.png
# Now patchifying image: /content/train//300567_mask.png
# Now patchifying image: /content/train//300633_mask.png
# Now patchifying image: /content/train//300643_mask.png
# Now patchifying image: /content/train//30072_mask.png
# Now patchifying image: /content/train//300773_mask.png
# Now patchifying image: /content/train//300983_mask.png
# Now patchifying image: /content/train//301056_mask.png
# Now patchifying image: /content/train//301319_mask.png
# Now patchifying image: /content/train//301373_mask.png
# Now patchifying image: /content/train//30137_mask.png
# Now patchifying image: /content/train//301397_mask.png
# Now patchifying image: /content/train//301468_mask.png
# Now patchifying image: /content/train//301490_mask.png
# Now patchifying image: /content/train//301560_mask.png
# Now patchifying image: /content/train//301568_mask.png
# Now patchifying image: /content/train//301591_mask.png
# Now patchifying image: /content/train//301641_mask.png
# Now patchifying image: /content/train//301644_mask.png
# Now patchifying image: /content/train//302077_mask.png
# Now patchifying image: /content/train//30207_mask.png
# Now patchifying image: /content/train//302342_mask.png
# Now patchifying image: /content/train//302422_mask.png
# Now patchifying image: /content/train//302597_mask.png
# Now patchifying image: /content/train//302663_mask.png
# Now patchifying image: /content/train//302836_mask.png
# Now patchifying image: /content/train//302926_mask.png
# Now patchifying image: /content/train//302976_mask.png
# Now patchifying image: /content/train//303084_mask.png
# Now patchifying image: /content/train//303109_mask.png
# Now patchifying image: /content/train//303190_mask.png
# Now patchifying image: /content/train//303200_mask.png
# Now patchifying image: /content/train//303232_mask.png
# Now patchifying image: /content/train//303268_mask.png
# Now patchifying image: /content/train//303362_mask.png
# Now patchifying image: /content/train//303816_mask.png
# Now patchifying image: /content/train//303879_mask.png
# Now patchifying image: /content/train//303966_mask.png
# Now patchifying image: /content/train//304241_mask.png
# Now patchifying image: /content/train//304480_mask.png
# Now patchifying image: /content/train//304690_mask.png
# Now patchifying image: /content/train//304720_mask.png
# Now patchifying image: /content/train//304805_mask.png
# Now patchifying image: /content/train//304861_mask.png
# Now patchifying image: /content/train//304923_mask.png
# Now patchifying image: /content/train//305094_mask.png
# Now patchifying image: /content/train//305427_mask.png
# Now patchifying image: /content/train//305439_mask.png
# Now patchifying image: /content/train//305441_mask.png
# Now patchifying image: /content/train//305454_mask.png
# Now patchifying image: /content/train//305621_mask.png
# Now patchifying image: /content/train//305664_mask.png
# Now patchifying image: /content/train//305788_mask.png
# Now patchifying image: /content/train//306070_mask.png
# Now patchifying image: /content/train//30635_mask.png
# Now patchifying image: /content/train//306455_mask.png
# Now patchifying image: /content/train//306622_mask.png
# Now patchifying image: /content/train//306632_mask.png
# Now patchifying image: /content/train//306760_mask.png
# Now patchifying image: /content/train//30689_mask.png
# Now patchifying image: /content/train//306987_mask.png
# Now patchifying image: /content/train//307151_mask.png
# Now patchifying image: /content/train//307216_mask.png
# Now patchifying image: /content/train//307293_mask.png
# Now patchifying image: /content/train//307492_mask.png
# Now patchifying image: /content/train//307752_mask.png
# Now patchifying image: /content/train//307908_mask.png
# Now patchifying image: /content/train//308466_mask.png
# Now patchifying image: /content/train//308576_mask.png
# Now patchifying image: /content/train//308581_mask.png
# Now patchifying image: /content/train//308632_mask.png
# Now patchifying image: /content/train//308726_mask.png
# Now patchifying image: /content/train//308856_mask.png
# Now patchifying image: /content/train//308872_mask.png
# Now patchifying image: /content/train//308946_mask.png
# Now patchifying image: /content/train//309222_mask.png
# Now patchifying image: /content/train//30940_mask.png
# Now patchifying image: /content/train//309834_mask.png
# Now patchifying image: /content/train//309959_mask.png
# Now patchifying image: /content/train//309974_mask.png
# Now patchifying image: /content/train//310096_mask.png
# Now patchifying image: /content/train//310260_mask.png
# Now patchifying image: /content/train//310283_mask.png
# Now patchifying image: /content/train//310520_mask.png
# Now patchifying image: /content/train//310668_mask.png
# Now patchifying image: /content/train//310692_mask.png
# Now patchifying image: /content/train//310793_mask.png
# Now patchifying image: /content/train//310935_mask.png
# Now patchifying image: /content/train//311078_mask.png
# Now patchifying image: /content/train//311321_mask.png
# Now patchifying image: /content/train//311390_mask.png
# Now patchifying image: /content/train//311509_mask.png
# Now patchifying image: /content/train//311544_mask.png
# Now patchifying image: /content/train//311644_mask.png
# Now patchifying image: /content/train//312040_mask.png
# Now patchifying image: /content/train//312064_mask.png
# Now patchifying image: /content/train//312192_mask.png
# Now patchifying image: /content/train//312261_mask.png
# Now patchifying image: /content/train//312322_mask.png
# Now patchifying image: /content/train//312407_mask.png
# Now patchifying image: /content/train//312663_mask.png
# Now patchifying image: /content/train//31268_mask.png
# Now patchifying image: /content/train//312784_mask.png
# Now patchifying image: /content/train//31278_mask.png
# Now patchifying image: /content/train//313083_mask.png
# Now patchifying image: /content/train//313113_mask.png
# Now patchifying image: /content/train//313276_mask.png
# Now patchifying image: /content/train//31332_mask.png
# Now patchifying image: /content/train//313498_mask.png
# Now patchifying image: /content/train//314066_mask.png
# Now patchifying image: /content/train//314088_mask.png
# Now patchifying image: /content/train//314129_mask.png
# Now patchifying image: /content/train//314550_mask.png
# Now patchifying image: /content/train//314575_mask.png
# Now patchifying image: /content/train//314867_mask.png
# Now patchifying image: /content/train//315051_mask.png
# Now patchifying image: /content/train//315115_mask.png
# Now patchifying image: /content/train//315179_mask.png
# Now patchifying image: /content/train//315262_mask.png
# Now patchifying image: /content/train//315665_mask.png
# Now patchifying image: /content/train//31578_mask.png
# Now patchifying image: /content/train//31582_mask.png
# Now patchifying image: /content/train//316216_mask.png
# Now patchifying image: /content/train//316248_mask.png
# Now patchifying image: /content/train//316440_mask.png
# Now patchifying image: /content/train//316574_mask.png
# Now patchifying image: /content/train//316677_mask.png
# Now patchifying image: /content/train//316887_mask.png
# Now patchifying image: /content/train//316904_mask.png
# Now patchifying image: /content/train//317060_mask.png
# Now patchifying image: /content/train//317075_mask.png
# Now patchifying image: /content/train//317292_mask.png
# Now patchifying image: /content/train//317514_mask.png
# Now patchifying image: /content/train//317678_mask.png
# Now patchifying image: /content/train//317756_mask.png
# Now patchifying image: /content/train//317824_mask.png
# Now patchifying image: /content/train//317880_mask.png
# Now patchifying image: /content/train//318030_mask.png
# Now patchifying image: /content/train//318304_mask.png
# Now patchifying image: /content/train//318320_mask.png
# Now patchifying image: /content/train//318385_mask.png
# Now patchifying image: /content/train//318395_mask.png
# Now patchifying image: /content/train//318586_mask.png
# Now patchifying image: /content/train//318661_mask.png
# Now patchifying image: /content/train//318886_mask.png
# Now patchifying image: /content/train//318912_mask.png
# Now patchifying image: /content/train//31900_mask.png
# Now patchifying image: /content/train//319229_mask.png
# Now patchifying image: /content/train//319322_mask.png
# Now patchifying image: /content/train//319353_mask.png
# Now patchifying image: /content/train//319391_mask.png
# Now patchifying image: /content/train//319547_mask.png
# Now patchifying image: /content/train//319779_mask.png
# Now patchifying image: /content/train//320163_mask.png
# Now patchifying image: /content/train//320459_mask.png
# Now patchifying image: /content/train//320466_mask.png
# Now patchifying image: /content/train//320503_mask.png
# Now patchifying image: /content/train//320533_mask.png
# Now patchifying image: /content/train//32058_mask.png
# Now patchifying image: /content/train//32073_mask.png
# Now patchifying image: /content/train//321747_mask.png
# Now patchifying image: /content/train//321959_mask.png
# Now patchifying image: /content/train//321997_mask.png
# Now patchifying image: /content/train//322316_mask.png
# Now patchifying image: /content/train//322403_mask.png
# Now patchifying image: /content/train//322428_mask.png
# Now patchifying image: /content/train//322536_mask.png
# Now patchifying image: /content/train//322561_mask.png
# Now patchifying image: /content/train//322654_mask.png
# Now patchifying image: /content/train//322684_mask.png
# Now patchifying image: /content/train//322697_mask.png
# Now patchifying image: /content/train//322781_mask.png
# Now patchifying image: /content/train//323177_mask.png
# Now patchifying image: /content/train//323533_mask.png
# Now patchifying image: /content/train//323579_mask.png
# Now patchifying image: /content/train//323729_mask.png
# Now patchifying image: /content/train//323782_mask.png
# Now patchifying image: /content/train//323909_mask.png
# Now patchifying image: /content/train//323958_mask.png
# Now patchifying image: /content/train//32472_mask.png
# Now patchifying image: /content/train//32501_mask.png
# Now patchifying image: /content/train//325090_mask.png
# Now patchifying image: /content/train//325166_mask.png
# Now patchifying image: /content/train//325242_mask.png
# Now patchifying image: /content/train//325490_mask.png
# Now patchifying image: /content/train//32578_mask.png
# Now patchifying image: /content/train//325890_mask.png
# Now patchifying image: /content/train//325929_mask.png
# Now patchifying image: /content/train//32593_mask.png
# Now patchifying image: /content/train//326742_mask.png
# Now patchifying image: /content/train//327052_mask.png
# Now patchifying image: /content/train//327075_mask.png
# Now patchifying image: /content/train//327244_mask.png
# Now patchifying image: /content/train//327279_mask.png
# Now patchifying image: /content/train//327487_mask.png
# Now patchifying image: /content/train//327652_mask.png
# Now patchifying image: /content/train//327894_mask.png
# Now patchifying image: /content/train//327909_mask.png
# Now patchifying image: /content/train//3280_mask.png
# Now patchifying image: /content/train//328239_mask.png
# Now patchifying image: /content/train//328335_mask.png
# Now patchifying image: /content/train//328350_mask.png
# Now patchifying image: /content/train//328712_mask.png
# Now patchifying image: /content/train//328902_mask.png
# Now patchifying image: /content/train//329147_mask.png
# Now patchifying image: /content/train//329219_mask.png
# Now patchifying image: /content/train//329237_mask.png
# Now patchifying image: /content/train//329397_mask.png
# Now patchifying image: /content/train//329556_mask.png
# Now patchifying image: /content/train//329670_mask.png
# Now patchifying image: /content/train//32972_mask.png
# Now patchifying image: /content/train//329889_mask.png
# Now patchifying image: /content/train//329892_mask.png
# Now patchifying image: /content/train//330017_mask.png
# Now patchifying image: /content/train//330027_mask.png
# Now patchifying image: /content/train//330241_mask.png
# Now patchifying image: /content/train//330562_mask.png
# Now patchifying image: /content/train//330700_mask.png
# Now patchifying image: /content/train//33070_mask.png
# Now patchifying image: /content/train//330776_mask.png
# Now patchifying image: /content/train//331119_mask.png
# Now patchifying image: /content/train//331137_mask.png
# Now patchifying image: /content/train//331266_mask.png
# Now patchifying image: /content/train//331305_mask.png
# Now patchifying image: /content/train//331632_mask.png
# Now patchifying image: /content/train//331675_mask.png
# Now patchifying image: /content/train//332370_mask.png
# Now patchifying image: /content/train//332374_mask.png
# Now patchifying image: /content/train//332482_mask.png
# Now patchifying image: /content/train//332524_mask.png
# Now patchifying image: /content/train//333000_mask.png
# Now patchifying image: /content/train//33305_mask.png
# Now patchifying image: /content/train//33340_mask.png
# Now patchifying image: /content/train//333785_mask.png
# Now patchifying image: /content/train//333857_mask.png
# Now patchifying image: /content/train//33389_mask.png
# Now patchifying image: /content/train//334513_mask.png
# Now patchifying image: /content/train//33463_mask.png
# Now patchifying image: /content/train//334697_mask.png
# Now patchifying image: /content/train//334723_mask.png
# Now patchifying image: /content/train//334908_mask.png
# Now patchifying image: /content/train//335016_mask.png
# Now patchifying image: /content/train//33507_mask.png
# Now patchifying image: /content/train//335112_mask.png
# Now patchifying image: /content/train//335329_mask.png
# Now patchifying image: /content/train//335330_mask.png
# Now patchifying image: /content/train//335445_mask.png
# Now patchifying image: /content/train//335613_mask.png
# Now patchifying image: /content/train//335644_mask.png
# Now patchifying image: /content/train//335676_mask.png
# Now patchifying image: /content/train//336111_mask.png
# Now patchifying image: /content/train//336261_mask.png
# Now patchifying image: /content/train//336420_mask.png
# Now patchifying image: /content/train//336648_mask.png
# Now patchifying image: /content/train//337004_mask.png
# Now patchifying image: /content/train//337231_mask.png
# Now patchifying image: /content/train//337255_mask.png
# Now patchifying image: /content/train//33736_mask.png
# Now patchifying image: /content/train//337461_mask.png
# Now patchifying image: /content/train//337490_mask.png
# Now patchifying image: /content/train//337912_mask.png
# Now patchifying image: /content/train//338002_mask.png
# Now patchifying image: /content/train//338104_mask.png
# Now patchifying image: /content/train//338671_mask.png
# Now patchifying image: /content/train//339034_mask.png
# Now patchifying image: /content/train//339359_mask.png
# Now patchifying image: /content/train//339471_mask.png
# Now patchifying image: /content/train//339741_mask.png
# Now patchifying image: /content/train//339797_mask.png
# Now patchifying image: /content/train//33983_mask.png
# Now patchifying image: /content/train//340116_mask.png
# Now patchifying image: /content/train//340126_mask.png
# Now patchifying image: /content/train//340335_mask.png
# Now patchifying image: /content/train//340354_mask.png
# Now patchifying image: /content/train//340497_mask.png
# Now patchifying image: /content/train//340502_mask.png
# Now patchifying image: /content/train//340732_mask.png
# Now patchifying image: /content/train//340962_mask.png
# Now patchifying image: /content/train//340985_mask.png
# Now patchifying image: /content/train//34100_mask.png
# Now patchifying image: /content/train//341131_mask.png
# Now patchifying image: /content/train//341300_mask.png
# Now patchifying image: /content/train//341439_mask.png
# Now patchifying image: /content/train//341469_mask.png
# Now patchifying image: /content/train//341612_mask.png
# Now patchifying image: /content/train//34170_mask.png
# Now patchifying image: /content/train//341944_mask.png
# Now patchifying image: /content/train//34194_mask.png
# Now patchifying image: /content/train//342201_mask.png
# Now patchifying image: /content/train//34236_mask.png
# Now patchifying image: /content/train//342627_mask.png
# Now patchifying image: /content/train//342960_mask.png
# Now patchifying image: /content/train//343000_mask.png
# Now patchifying image: /content/train//343062_mask.png
# Now patchifying image: /content/train//343286_mask.png
# Now patchifying image: /content/train//34368_mask.png
# Now patchifying image: /content/train//343801_mask.png
# Now patchifying image: /content/train//343850_mask.png
# Now patchifying image: /content/train//343_mask.png
# Now patchifying image: /content/train//344028_mask.png
# Now patchifying image: /content/train//344056_mask.png
# Now patchifying image: /content/train//344123_mask.png
# Now patchifying image: /content/train//344133_mask.png
# Now patchifying image: /content/train//344218_mask.png
# Now patchifying image: /content/train//344261_mask.png
# Now patchifying image: /content/train//344522_mask.png
# Now patchifying image: /content/train//344565_mask.png
# Now patchifying image: /content/train//344627_mask.png
# Now patchifying image: /content/train//345150_mask.png
# Now patchifying image: /content/train//34520_mask.png
# Now patchifying image: /content/train//34523_mask.png
# Now patchifying image: /content/train//34524_mask.png
# Now patchifying image: /content/train//345264_mask.png
# Now patchifying image: /content/train//3452_mask.png
# Now patchifying image: /content/train//345705_mask.png
# Now patchifying image: /content/train//345999_mask.png
# Now patchifying image: /content/train//346049_mask.png
# Now patchifying image: /content/train//346187_mask.png
# Now patchifying image: /content/train//346387_mask.png
# Now patchifying image: /content/train//346471_mask.png
# Now patchifying image: /content/train//346520_mask.png
# Now patchifying image: /content/train//346556_mask.png
# Now patchifying image: /content/train//346739_mask.png
# Now patchifying image: /content/train//346939_mask.png
# Now patchifying image: /content/train//347200_mask.png
# Now patchifying image: /content/train//347354_mask.png
# Now patchifying image: /content/train//347400_mask.png
# Now patchifying image: /content/train//347421_mask.png
# Now patchifying image: /content/train//347433_mask.png
# Now patchifying image: /content/train//347474_mask.png
# Now patchifying image: /content/train//347485_mask.png
# Now patchifying image: /content/train//347561_mask.png
# Now patchifying image: /content/train//347591_mask.png
# Now patchifying image: /content/train//347596_mask.png
# Now patchifying image: /content/train//347722_mask.png
# Now patchifying image: /content/train//347737_mask.png
# Now patchifying image: /content/train//347742_mask.png
# Now patchifying image: /content/train//347776_mask.png
# Now patchifying image: /content/train//347985_mask.png
# Now patchifying image: /content/train//348069_mask.png
# Now patchifying image: /content/train//348118_mask.png
# Now patchifying image: /content/train//348453_mask.png
# Now patchifying image: /content/train//348659_mask.png
# Now patchifying image: /content/train//348674_mask.png
# Now patchifying image: /content/train//34885_mask.png
# Now patchifying image: /content/train//348890_mask.png
# Now patchifying image: /content/train//348983_mask.png
# Now patchifying image: /content/train//349238_mask.png
# Now patchifying image: /content/train//349510_mask.png
# Now patchifying image: /content/train//34973_mask.png
# Now patchifying image: /content/train//349767_mask.png
# Now patchifying image: /content/train//350071_mask.png
# Now patchifying image: /content/train//35029_mask.png
# Now patchifying image: /content/train//350684_mask.png
# Now patchifying image: /content/train//351151_mask.png
# Now patchifying image: /content/train//351358_mask.png
# Now patchifying image: /content/train//351420_mask.png
# Now patchifying image: /content/train//351590_mask.png
# Now patchifying image: /content/train//351686_mask.png
# Now patchifying image: /content/train//351766_mask.png
# Now patchifying image: /content/train//351829_mask.png
# Now patchifying image: /content/train//35189_mask.png
# Now patchifying image: /content/train//351913_mask.png
# Now patchifying image: /content/train//352028_mask.png
# Now patchifying image: /content/train//352363_mask.png
# Now patchifying image: /content/train//352622_mask.png
# Now patchifying image: /content/train//352630_mask.png
# Now patchifying image: /content/train//352793_mask.png
# Now patchifying image: /content/train//352991_mask.png
# Now patchifying image: /content/train//353070_mask.png
# Now patchifying image: /content/train//3530_mask.png
# Now patchifying image: /content/train//353416_mask.png
# Now patchifying image: /content/train//353807_mask.png
# Now patchifying image: /content/train//354066_mask.png
# Now patchifying image: /content/train//354220_mask.png
# Now patchifying image: /content/train//354244_mask.png
# Now patchifying image: /content/train//354263_mask.png
# Now patchifying image: /content/train//35432_mask.png
# Now patchifying image: /content/train//354423_mask.png
# Now patchifying image: /content/train//354477_mask.png
# Now patchifying image: /content/train//354633_mask.png
# Now patchifying image: /content/train//354649_mask.png
# Now patchifying image: /content/train//354691_mask.png
# Now patchifying image: /content/train//354704_mask.png
# Now patchifying image: /content/train//354754_mask.png
# Now patchifying image: /content/train//354791_mask.png
# Now patchifying image: /content/train//354829_mask.png
# Now patchifying image: /content/train//354968_mask.png
# Now patchifying image: /content/train//355638_mask.png
# Now patchifying image: /content/train//356039_mask.png
# Now patchifying image: /content/train//356160_mask.png
# Now patchifying image: /content/train//356431_mask.png
# Now patchifying image: /content/train//356917_mask.png
# Now patchifying image: /content/train//357219_mask.png
# Now patchifying image: /content/train//357288_mask.png
# Now patchifying image: /content/train//357302_mask.png
# Now patchifying image: /content/train//357382_mask.png
# Now patchifying image: /content/train//3573_mask.png
# Now patchifying image: /content/train//357420_mask.png
# Now patchifying image: /content/train//357428_mask.png
# Now patchifying image: /content/train//357720_mask.png
# Now patchifying image: /content/train//357722_mask.png
# Now patchifying image: /content/train//357846_mask.png
# Now patchifying image: /content/train//357961_mask.png
# Now patchifying image: /content/train//358017_mask.png
# Now patchifying image: /content/train//358082_mask.png
# Now patchifying image: /content/train//358122_mask.png
# Now patchifying image: /content/train//358199_mask.png
# Now patchifying image: /content/train//358453_mask.png
# Now patchifying image: /content/train//358518_mask.png
# Now patchifying image: /content/train//358554_mask.png
# Now patchifying image: /content/train//358588_mask.png
# Now patchifying image: /content/train//35892_mask.png
# Now patchifying image: /content/train//359049_mask.png
# Now patchifying image: /content/train//359166_mask.png
# Now patchifying image: /content/train//35917_mask.png
# Now patchifying image: /content/train//359304_mask.png
# Now patchifying image: /content/train//359472_mask.png
# Now patchifying image: /content/train//3594_mask.png
# Now patchifying image: /content/train//359514_mask.png
# Now patchifying image: /content/train//359554_mask.png
# Now patchifying image: /content/train//359621_mask.png
# Now patchifying image: /content/train//360003_mask.png
# Now patchifying image: /content/train//360096_mask.png
# Now patchifying image: /content/train//360221_mask.png
# Now patchifying image: /content/train//360298_mask.png
# Now patchifying image: /content/train//3602_mask.png
# Now patchifying image: /content/train//360368_mask.png
# Now patchifying image: /content/train//360450_mask.png
# Now patchifying image: /content/train//36057_mask.png
# Now patchifying image: /content/train//360580_mask.png
# Now patchifying image: /content/train//360726_mask.png
# Now patchifying image: /content/train//36082_mask.png
# Now patchifying image: /content/train//360847_mask.png
# Now patchifying image: /content/train//361007_mask.png
# Now patchifying image: /content/train//361076_mask.png
# Now patchifying image: /content/train//361334_mask.png
# Now patchifying image: /content/train//361504_mask.png
# Now patchifying image: /content/train//361860_mask.png
# Now patchifying image: /content/train//361962_mask.png
# Now patchifying image: /content/train//362004_mask.png
# Now patchifying image: /content/train//362138_mask.png
# Now patchifying image: /content/train//362228_mask.png
# Now patchifying image: /content/train//362406_mask.png
# Now patchifying image: /content/train//36243_mask.png
# Now patchifying image: /content/train//362460_mask.png
# Now patchifying image: /content/train//362967_mask.png
# Now patchifying image: /content/train//363054_mask.png
# Now patchifying image: /content/train//363067_mask.png
# Now patchifying image: /content/train//363269_mask.png
# Now patchifying image: /content/train//363388_mask.png
# Now patchifying image: /content/train//363400_mask.png
# Now patchifying image: /content/train//363434_mask.png
# Now patchifying image: /content/train//363544_mask.png
# Now patchifying image: /content/train//363960_mask.png
# Now patchifying image: /content/train//364140_mask.png
# Now patchifying image: /content/train//364184_mask.png
# Now patchifying image: /content/train//364453_mask.png
# Now patchifying image: /content/train//364680_mask.png
# Now patchifying image: /content/train//364744_mask.png
# Now patchifying image: /content/train//364982_mask.png
# Now patchifying image: /content/train//365028_mask.png
# Now patchifying image: /content/train//365134_mask.png
# Now patchifying image: /content/train//365590_mask.png
# Now patchifying image: /content/train//365725_mask.png
# Now patchifying image: /content/train//365973_mask.png
# Now patchifying image: /content/train//366050_mask.png
# Now patchifying image: /content/train//366059_mask.png
# Now patchifying image: /content/train//366084_mask.png
# Now patchifying image: /content/train//366103_mask.png
# Now patchifying image: /content/train//36626_mask.png
# Now patchifying image: /content/train//366458_mask.png
# Now patchifying image: /content/train//36646_mask.png
# Now patchifying image: /content/train//366622_mask.png
# Now patchifying image: /content/train//366702_mask.png
# Now patchifying image: /content/train//36684_mask.png
# Now patchifying image: /content/train//367166_mask.png
# Now patchifying image: /content/train//367206_mask.png
# Now patchifying image: /content/train//367269_mask.png
# Now patchifying image: /content/train//367276_mask.png
# Now patchifying image: /content/train//367358_mask.png
# Now patchifying image: /content/train//367384_mask.png
# Now patchifying image: /content/train//367457_mask.png
# Now patchifying image: /content/train//367591_mask.png
# Now patchifying image: /content/train//367933_mask.png
# Now patchifying image: /content/train//368124_mask.png
# Now patchifying image: /content/train//368442_mask.png
# Now patchifying image: /content/train//368807_mask.png
# Now patchifying image: /content/train//368952_mask.png
# Now patchifying image: /content/train//36900_mask.png
# Now patchifying image: /content/train//369061_mask.png
# Now patchifying image: /content/train//369352_mask.png
# Now patchifying image: /content/train//369432_mask.png
# Now patchifying image: /content/train//369605_mask.png
# Now patchifying image: /content/train//369819_mask.png
# Now patchifying image: /content/train//36988_mask.png
# Now patchifying image: /content/train//369916_mask.png
# Now patchifying image: /content/train//370251_mask.png
# Now patchifying image: /content/train//370328_mask.png
# Now patchifying image: /content/train//370418_mask.png
# Now patchifying image: /content/train//370520_mask.png
# Now patchifying image: /content/train//370547_mask.png
# Now patchifying image: /content/train//370642_mask.png
# Now patchifying image: /content/train//370972_mask.png
# Now patchifying image: /content/train//371242_mask.png
# Now patchifying image: /content/train//371353_mask.png
# Now patchifying image: /content/train//371502_mask.png
# Now patchifying image: /content/train//371829_mask.png
# Now patchifying image: /content/train//372063_mask.png
# Now patchifying image: /content/train//372169_mask.png
# Now patchifying image: /content/train//372171_mask.png
# Now patchifying image: /content/train//372422_mask.png
# Now patchifying image: /content/train//372482_mask.png
# Now patchifying image: /content/train//372496_mask.png
# Now patchifying image: /content/train//372555_mask.png
# Now patchifying image: /content/train//372803_mask.png
# Now patchifying image: /content/train//373103_mask.png
# Now patchifying image: /content/train//373268_mask.png
# Now patchifying image: /content/train//373548_mask.png
# Now patchifying image: /content/train//373567_mask.png
# Now patchifying image: /content/train//373608_mask.png
# Now patchifying image: /content/train//373615_mask.png
# Now patchifying image: /content/train//373623_mask.png
# Now patchifying image: /content/train//373640_mask.png
# Now patchifying image: /content/train//37370_mask.png
# Now patchifying image: /content/train//373943_mask.png
# Now patchifying image: /content/train//374028_mask.png
# Now patchifying image: /content/train//37426_mask.png
# Now patchifying image: /content/train//374296_mask.png
# Now patchifying image: /content/train//374374_mask.png
# Now patchifying image: /content/train//374383_mask.png
# Now patchifying image: /content/train//374575_mask.png
# Now patchifying image: /content/train//374583_mask.png
# Now patchifying image: /content/train//37493_mask.png
# Now patchifying image: /content/train//375229_mask.png
# Now patchifying image: /content/train//375428_mask.png
# Now patchifying image: /content/train//375461_mask.png
# Now patchifying image: /content/train//375508_mask.png
# Now patchifying image: /content/train//375532_mask.png
# Now patchifying image: /content/train//375732_mask.png
# Now patchifying image: /content/train//375799_mask.png
# Now patchifying image: /content/train//375903_mask.png
# Now patchifying image: /content/train//375965_mask.png
# Now patchifying image: /content/train//376178_mask.png
# Now patchifying image: /content/train//376233_mask.png
# Now patchifying image: /content/train//376257_mask.png
# Now patchifying image: /content/train//376720_mask.png
# Now patchifying image: /content/train//377472_mask.png
# Now patchifying image: /content/train//377740_mask.png
# Now patchifying image: /content/train//377745_mask.png
# Now patchifying image: /content/train//378019_mask.png
# Now patchifying image: /content/train//378071_mask.png
# Now patchifying image: /content/train//378114_mask.png
# Now patchifying image: /content/train//378149_mask.png
# Now patchifying image: /content/train//378296_mask.png
# Now patchifying image: /content/train//378334_mask.png
# Now patchifying image: /content/train//378347_mask.png
# Now patchifying image: /content/train//378778_mask.png
# Now patchifying image: /content/train//379003_mask.png
# Now patchifying image: /content/train//379021_mask.png
# Now patchifying image: /content/train//379173_mask.png
# Now patchifying image: /content/train//379221_mask.png
# Now patchifying image: /content/train//379226_mask.png
# Now patchifying image: /content/train//37924_mask.png
# Now patchifying image: /content/train//379294_mask.png
# Now patchifying image: /content/train//379373_mask.png
# Now patchifying image: /content/train//379548_mask.png
# Now patchifying image: /content/train//379698_mask.png
# Now patchifying image: /content/train//37982_mask.png
# Now patchifying image: /content/train//379877_mask.png
# Now patchifying image: /content/train//380184_mask.png
# Now patchifying image: /content/train//380270_mask.png
# Now patchifying image: /content/train//380317_mask.png
# Now patchifying image: /content/train//380471_mask.png
# Now patchifying image: /content/train//38072_mask.png
# Now patchifying image: /content/train//38093_mask.png
# Now patchifying image: /content/train//381074_mask.png
# Now patchifying image: /content/train//38122_mask.png
# Now patchifying image: /content/train//38128_mask.png
# Now patchifying image: /content/train//38144_mask.png
# Now patchifying image: /content/train//381461_mask.png
# Now patchifying image: /content/train//381525_mask.png
# Now patchifying image: /content/train//381744_mask.png
# Now patchifying image: /content/train//381926_mask.png
# Now patchifying image: /content/train//382065_mask.png
# Now patchifying image: /content/train//382329_mask.png
# Now patchifying image: /content/train//382842_mask.png
# Now patchifying image: /content/train//383210_mask.png
# Now patchifying image: /content/train//383456_mask.png
# Now patchifying image: /content/train//38353_mask.png
# Now patchifying image: /content/train//384296_mask.png
# Now patchifying image: /content/train//384422_mask.png
# Now patchifying image: /content/train//384454_mask.png
# Now patchifying image: /content/train//384535_mask.png
# Now patchifying image: /content/train//384693_mask.png
# Now patchifying image: /content/train//384735_mask.png
# Now patchifying image: /content/train//384753_mask.png
# Now patchifying image: /content/train//38479_mask.png
# Now patchifying image: /content/train//384950_mask.png
# Now patchifying image: /content/train//385085_mask.png
# Now patchifying image: /content/train//385105_mask.png
# Now patchifying image: /content/train//385247_mask.png
# Now patchifying image: /content/train//385268_mask.png
# Now patchifying image: /content/train//385402_mask.png
# Now patchifying image: /content/train//385679_mask.png
# Now patchifying image: /content/train//385783_mask.png
# Now patchifying image: /content/train//385863_mask.png
# Now patchifying image: /content/train//385890_mask.png
# Now patchifying image: /content/train//385965_mask.png
# Now patchifying image: /content/train//38615_mask.png
# Now patchifying image: /content/train//386323_mask.png
# Now patchifying image: /content/train//386497_mask.png
# Now patchifying image: /content/train//386600_mask.png
# Now patchifying image: /content/train//386604_mask.png
# Now patchifying image: /content/train//387181_mask.png
# Now patchifying image: /content/train//387186_mask.png
# Now patchifying image: /content/train//387383_mask.png
# Now patchifying image: /content/train//387942_mask.png
# Now patchifying image: /content/train//388071_mask.png
# Now patchifying image: /content/train//388122_mask.png
# Now patchifying image: /content/train//388859_mask.png
# Now patchifying image: /content/train//388957_mask.png
# Now patchifying image: /content/train//388_mask.png
# Now patchifying image: /content/train//389263_mask.png
# Now patchifying image: /content/train//38954_mask.png
# Now patchifying image: /content/train//389552_mask.png
# Now patchifying image: /content/train//389555_mask.png
# Now patchifying image: /content/train//389656_mask.png
# Now patchifying image: /content/train//390011_mask.png
# Now patchifying image: /content/train//390180_mask.png
# Now patchifying image: /content/train//390365_mask.png
# Now patchifying image: /content/train//39045_mask.png
# Now patchifying image: /content/train//390727_mask.png
# Now patchifying image: /content/train//390893_mask.png
# Now patchifying image: /content/train//390928_mask.png
# Now patchifying image: /content/train//390952_mask.png
# Now patchifying image: /content/train//391190_mask.png
# Now patchifying image: /content/train//391293_mask.png
# Now patchifying image: /content/train//391538_mask.png
# Now patchifying image: /content/train//391660_mask.png
# Now patchifying image: /content/train//391736_mask.png
# Now patchifying image: /content/train//391989_mask.png
# Now patchifying image: /content/train//392105_mask.png
# Now patchifying image: /content/train//392225_mask.png
# Now patchifying image: /content/train//392230_mask.png
# Now patchifying image: /content/train//392268_mask.png
# Now patchifying image: /content/train//392410_mask.png
# Now patchifying image: /content/train//392609_mask.png
# Now patchifying image: /content/train//392686_mask.png
# Now patchifying image: /content/train//39277_mask.png
# Now patchifying image: /content/train//393063_mask.png
# Now patchifying image: /content/train//393111_mask.png
# Now patchifying image: /content/train//393127_mask.png
# Now patchifying image: /content/train//393166_mask.png
# Now patchifying image: /content/train//393252_mask.png
# Now patchifying image: /content/train//393469_mask.png
# Now patchifying image: /content/train//393590_mask.png
# Now patchifying image: /content/train//39367_mask.png
# Now patchifying image: /content/train//394008_mask.png
# Now patchifying image: /content/train//394020_mask.png
# Now patchifying image: /content/train//394074_mask.png
# Now patchifying image: /content/train//394093_mask.png
# Now patchifying image: /content/train//394175_mask.png
# Now patchifying image: /content/train//394310_mask.png
# Now patchifying image: /content/train//394496_mask.png
# Now patchifying image: /content/train//395029_mask.png
# Now patchifying image: /content/train//395265_mask.png
# Now patchifying image: /content/train//395487_mask.png
# Now patchifying image: /content/train//395611_mask.png
# Now patchifying image: /content/train//395621_mask.png
# Now patchifying image: /content/train//395879_mask.png
# Now patchifying image: /content/train//396252_mask.png
# Now patchifying image: /content/train//396274_mask.png
# Now patchifying image: /content/train//396352_mask.png
# Now patchifying image: /content/train//396744_mask.png
# Now patchifying image: /content/train//396836_mask.png
# Now patchifying image: /content/train//39694_mask.png
# Now patchifying image: /content/train//397493_mask.png
# Now patchifying image: /content/train//397590_mask.png
# Now patchifying image: /content/train//397989_mask.png
# Now patchifying image: /content/train//398137_mask.png
# Now patchifying image: /content/train//398502_mask.png
# Now patchifying image: /content/train//398587_mask.png
# Now patchifying image: /content/train//398701_mask.png
# Now patchifying image: /content/train//39878_mask.png
# Now patchifying image: /content/train//398826_mask.png
# Now patchifying image: /content/train//39884_mask.png
# Now patchifying image: /content/train//398890_mask.png
# Now patchifying image: /content/train//399058_mask.png
# Now patchifying image: /content/train//399107_mask.png
# Now patchifying image: /content/train//399244_mask.png
# Now patchifying image: /content/train//399251_mask.png
# Now patchifying image: /content/train//399432_mask.png
# Now patchifying image: /content/train//39945_mask.png
# Now patchifying image: /content/train//399518_mask.png
# Now patchifying image: /content/train//399543_mask.png
# Now patchifying image: /content/train//399786_mask.png
# ...
# Now patchifying image: /content/train//953595_mask.png
# Now patchifying image: /content/train//954085_mask.png
# Now patchifying image: /content/train//954214_mask.png
# Now patchifying image: /content/train//954319_mask.png
# Now patchifying image: /content/train//95440_mask.png
# Now patchifying image: /content/train//95471_mask.png
# Now patchifying image: /content/train//954725_mask.png
# Now patchifying image: /content/train//954744_mask.png
# Now patchifying image: /content/train//955344_mask.png
# Now patchifying image: /content/train//955401_mask.png
# Now patchifying image: /content/train//955526_mask.png
# Now patchifying image: /content/train//955634_mask.png
# Now patchifying image: /content/train//955699_mask.png
# Now patchifying image: /content/train//95571_mask.png
# Now patchifying image: /content/train//95573_mask.png
# Now patchifying image: /content/train//955948_mask.png
# Now patchifying image: /content/train//955978_mask.png
# Now patchifying image: /content/train//956106_mask.png
# Now patchifying image: /content/train//956757_mask.png
# Now patchifying image: /content/train//956924_mask.png
# Now patchifying image: /content/train//956979_mask.png
# Now patchifying image: /content/train//957208_mask.png
# Now patchifying image: /content/train//957367_mask.png
# Now patchifying image: /content/train//957508_mask.png
# Now patchifying image: /content/train//957650_mask.png
# Now patchifying image: /content/train//957715_mask.png
# Now patchifying image: /content/train//957825_mask.png
# Now patchifying image: /content/train//957898_mask.png
# Now patchifying image: /content/train//958471_mask.png
# Now patchifying image: /content/train//958571_mask.png
# Now patchifying image: /content/train//958932_mask.png
# Now patchifying image: /content/train//958998_mask.png
# Now patchifying image: /content/train//959032_mask.png
# Now patchifying image: /content/train//959091_mask.png
# Now patchifying image: /content/train//95932_mask.png
# Now patchifying image: /content/train//959424_mask.png
# Now patchifying image: /content/train//959435_mask.png
# Now patchifying image: /content/train//959496_mask.png
# Now patchifying image: /content/train//959529_mask.png
# Now patchifying image: /content/train//959705_mask.png
# Now patchifying image: /content/train//959925_mask.png
# Now patchifying image: /content/train//960162_mask.png
# Now patchifying image: /content/train//960287_mask.png
# Now patchifying image: /content/train//960291_mask.png
# Now patchifying image: /content/train//960372_mask.png
# Now patchifying image: /content/train//960471_mask.png
# Now patchifying image: /content/train//960631_mask.png
# Now patchifying image: /content/train//960793_mask.png
# Now patchifying image: /content/train//960845_mask.png
# Now patchifying image: /content/train//960918_mask.png
# Now patchifying image: /content/train//961077_mask.png
# Now patchifying image: /content/train//961236_mask.png
# Now patchifying image: /content/train//961336_mask.png
# Now patchifying image: /content/train//961425_mask.png
# Now patchifying image: /content/train//961487_mask.png
# Now patchifying image: /content/train//961531_mask.png
# Now patchifying image: /content/train//962072_mask.png
# Now patchifying image: /content/train//962829_mask.png
# Now patchifying image: /content/train//962887_mask.png
# Now patchifying image: /content/train//962988_mask.png
# Now patchifying image: /content/train//963225_mask.png
# Now patchifying image: /content/train//96326_mask.png
# Now patchifying image: /content/train//963389_mask.png
# Now patchifying image: /content/train//963426_mask.png
# Now patchifying image: /content/train//963805_mask.png
# Now patchifying image: /content/train//96399_mask.png
# Now patchifying image: /content/train//964261_mask.png
# Now patchifying image: /content/train//964308_mask.png
# Now patchifying image: /content/train//964555_mask.png
# Now patchifying image: /content/train//964566_mask.png
# Now patchifying image: /content/train//964590_mask.png
# Now patchifying image: /content/train//964793_mask.png
# Now patchifying image: /content/train//964926_mask.png
# Now patchifying image: /content/train//965147_mask.png
# Now patchifying image: /content/train//965322_mask.png
# Now patchifying image: /content/train//965349_mask.png
# Now patchifying image: /content/train//965378_mask.png
# Now patchifying image: /content/train//96543_mask.png
# Now patchifying image: /content/train//965750_mask.png
# Now patchifying image: /content/train//966260_mask.png
# Now patchifying image: /content/train//966295_mask.png
# Now patchifying image: /content/train//966308_mask.png
# Now patchifying image: /content/train//96635_mask.png
# Now patchifying image: /content/train//96639_mask.png
# Now patchifying image: /content/train//9663_mask.png
# Now patchifying image: /content/train//966419_mask.png
# Now patchifying image: /content/train//966525_mask.png
# Now patchifying image: /content/train//966535_mask.png
# Now patchifying image: /content/train//966712_mask.png
# Now patchifying image: /content/train//966775_mask.png
# Now patchifying image: /content/train//966786_mask.png
# Now patchifying image: /content/train//966836_mask.png
# Now patchifying image: /content/train//967447_mask.png
# Now patchifying image: /content/train//967643_mask.png
# Now patchifying image: /content/train//967951_mask.png
# Now patchifying image: /content/train//968022_mask.png
# Now patchifying image: /content/train//968202_mask.png
# Now patchifying image: /content/train//968546_mask.png
# Now patchifying image: /content/train//968690_mask.png
# Now patchifying image: /content/train//968835_mask.png
# Now patchifying image: /content/train//968959_mask.png
# Now patchifying image: /content/train//969001_mask.png
# Now patchifying image: /content/train//969029_mask.png
# Now patchifying image: /content/train//96905_mask.png
# Now patchifying image: /content/train//969112_mask.png
# Now patchifying image: /content/train//969507_mask.png
# Now patchifying image: /content/train//969794_mask.png
# Now patchifying image: /content/train//969845_mask.png
# Now patchifying image: /content/train//970229_mask.png
# Now patchifying image: /content/train//970400_mask.png
# Now patchifying image: /content/train//970706_mask.png
# Now patchifying image: /content/train//971038_mask.png
# Now patchifying image: /content/train//97115_mask.png
# Now patchifying image: /content/train//971177_mask.png
# Now patchifying image: /content/train//971228_mask.png
# Now patchifying image: /content/train//971299_mask.png
# Now patchifying image: /content/train//971922_mask.png
# Now patchifying image: /content/train//972206_mask.png
# Now patchifying image: /content/train//972254_mask.png
# Now patchifying image: /content/train//972546_mask.png
# Now patchifying image: /content/train//972689_mask.png
# Now patchifying image: /content/train//97272_mask.png
# Now patchifying image: /content/train//97279_mask.png
# Now patchifying image: /content/train//97287_mask.png
# Now patchifying image: /content/train//973063_mask.png
# Now patchifying image: /content/train//973094_mask.png
# Now patchifying image: /content/train//97321_mask.png
# Now patchifying image: /content/train//973434_mask.png
# Now patchifying image: /content/train//973490_mask.png
# Now patchifying image: /content/train//973890_mask.png
# Now patchifying image: /content/train//973982_mask.png
# Now patchifying image: /content/train//974158_mask.png
# Now patchifying image: /content/train//974250_mask.png
# Now patchifying image: /content/train//974256_mask.png
# Now patchifying image: /content/train//974637_mask.png
# Now patchifying image: /content/train//974696_mask.png
# Now patchifying image: /content/train//974725_mask.png
# Now patchifying image: /content/train//974773_mask.png
# Now patchifying image: /content/train//974843_mask.png
# Now patchifying image: /content/train//975274_mask.png
# Now patchifying image: /content/train//975973_mask.png
# Now patchifying image: /content/train//97627_mask.png
# Now patchifying image: /content/train//976309_mask.png
# Now patchifying image: /content/train//976327_mask.png
# Now patchifying image: /content/train//976438_mask.png
# Now patchifying image: /content/train//976451_mask.png
# Now patchifying image: /content/train//976537_mask.png
# Now patchifying image: /content/train//976759_mask.png
# Now patchifying image: /content/train//976894_mask.png
# Now patchifying image: /content/train//976914_mask.png
# Now patchifying image: /content/train//976970_mask.png
# Now patchifying image: /content/train//97748_mask.png
# Now patchifying image: /content/train//977848_mask.png
# Now patchifying image: /content/train//978037_mask.png
# Now patchifying image: /content/train//978104_mask.png
# Now patchifying image: /content/train//978201_mask.png
# Now patchifying image: /content/train//978339_mask.png
# Now patchifying image: /content/train//97837_mask.png
# Now patchifying image: /content/train//978406_mask.png
# Now patchifying image: /content/train//978495_mask.png
# Now patchifying image: /content/train//97852_mask.png
# Now patchifying image: /content/train//97854_mask.png
# Now patchifying image: /content/train//979028_mask.png
# Now patchifying image: /content/train//979149_mask.png
# Now patchifying image: /content/train//979246_mask.png
# Now patchifying image: /content/train//979506_mask.png
# Now patchifying image: /content/train//979605_mask.png
# Now patchifying image: /content/train//979669_mask.png
# Now patchifying image: /content/train//979688_mask.png
# Now patchifying image: /content/train//979812_mask.png
# Now patchifying image: /content/train//979854_mask.png
# Now patchifying image: /content/train//979932_mask.png
# Now patchifying image: /content/train//980030_mask.png
# Now patchifying image: /content/train//980164_mask.png
# Now patchifying image: /content/train//980177_mask.png
# Now patchifying image: /content/train//98029_mask.png
# Now patchifying image: /content/train//980683_mask.png
# Now patchifying image: /content/train//980712_mask.png
# Now patchifying image: /content/train//980975_mask.png
# Now patchifying image: /content/train//98157_mask.png
# Now patchifying image: /content/train//981645_mask.png
# Now patchifying image: /content/train//981956_mask.png
# Now patchifying image: /content/train//982013_mask.png
# Now patchifying image: /content/train//98225_mask.png
# Now patchifying image: /content/train//982331_mask.png
# Now patchifying image: /content/train//982396_mask.png
# Now patchifying image: /content/train//982721_mask.png
# Now patchifying image: /content/train//982866_mask.png
# Now patchifying image: /content/train//982907_mask.png
# Now patchifying image: /content/train//983744_mask.png
# Now patchifying image: /content/train//983851_mask.png
# Now patchifying image: /content/train//983884_mask.png
# Now patchifying image: /content/train//983887_mask.png
# Now patchifying image: /content/train//984363_mask.png
# Now patchifying image: /content/train//984438_mask.png
# Now patchifying image: /content/train//98477_mask.png
# Now patchifying image: /content/train//985064_mask.png
# Now patchifying image: /content/train//985216_mask.png
# Now patchifying image: /content/train//985595_mask.png
# Now patchifying image: /content/train//985661_mask.png
# Now patchifying image: /content/train//985731_mask.png
# Now patchifying image: /content/train//985902_mask.png
# Now patchifying image: /content/train//98599_mask.png
# Now patchifying image: /content/train//986182_mask.png
# Now patchifying image: /content/train//9872_mask.png
# Now patchifying image: /content/train//987330_mask.png
# Now patchifying image: /content/train//987408_mask.png
# Now patchifying image: /content/train//987623_mask.png
# Now patchifying image: /content/train//987822_mask.png
# Now patchifying image: /content/train//987823_mask.png
# Now patchifying image: /content/train//987840_mask.png
# Now patchifying image: /content/train//988341_mask.png
# Now patchifying image: /content/train//988559_mask.png
# Now patchifying image: /content/train//988774_mask.png
# Now patchifying image: /content/train//989146_mask.png
# Now patchifying image: /content/train//989174_mask.png
# Now patchifying image: /content/train//989343_mask.png
# Now patchifying image: /content/train//989398_mask.png
# Now patchifying image: /content/train//989455_mask.png
# Now patchifying image: /content/train//989480_mask.png
# Now patchifying image: /content/train//989763_mask.png
# Now patchifying image: /content/train//990020_mask.png
# Now patchifying image: /content/train//990140_mask.png
# Now patchifying image: /content/train//990181_mask.png
# Now patchifying image: /content/train//990478_mask.png
# Now patchifying image: /content/train//990503_mask.png
# Now patchifying image: /content/train//990561_mask.png
# Now patchifying image: /content/train//990851_mask.png
# Now patchifying image: /content/train//991243_mask.png
# Now patchifying image: /content/train//991347_mask.png
# Now patchifying image: /content/train//991373_mask.png
# Now patchifying image: /content/train//991392_mask.png
# Now patchifying image: /content/train//991461_mask.png
# Now patchifying image: /content/train//991845_mask.png
# Now patchifying image: /content/train//991988_mask.png
# Now patchifying image: /content/train//992083_mask.png
# Now patchifying image: /content/train//992317_mask.png
# Now patchifying image: /content/train//992343_mask.png
# Now patchifying image: /content/train//992526_mask.png
# Now patchifying image: /content/train//992768_mask.png
# Now patchifying image: /content/train//993012_mask.png
# Now patchifying image: /content/train//993226_mask.png
# Now patchifying image: /content/train//993412_mask.png
# Now patchifying image: /content/train//993483_mask.png
# Now patchifying image: /content/train//993491_mask.png
# Now patchifying image: /content/train//993512_mask.png
# Now patchifying image: /content/train//99367_mask.png
# Now patchifying image: /content/train//993763_mask.png
# Now patchifying image: /content/train//9937_mask.png
# Now patchifying image: /content/train//993822_mask.png
# Now patchifying image: /content/train//994121_mask.png
# Now patchifying image: /content/train//994363_mask.png
# Now patchifying image: /content/train//994421_mask.png
# Now patchifying image: /content/train//994850_mask.png
# Now patchifying image: /content/train//994957_mask.png
# Now patchifying image: /content/train//995287_mask.png
# Now patchifying image: /content/train//995305_mask.png
# Now patchifying image: /content/train//995558_mask.png
# Now patchifying image: /content/train//995739_mask.png
# Now patchifying image: /content/train//995758_mask.png
# Now patchifying image: /content/train//995848_mask.png
# Now patchifying image: /content/train//996088_mask.png
# Now patchifying image: /content/train//996111_mask.png
# Now patchifying image: /content/train//99639_mask.png
# Now patchifying image: /content/train//99665_mask.png
# Now patchifying image: /content/train//996759_mask.png
# Now patchifying image: /content/train//996898_mask.png
# Now patchifying image: /content/train//996964_mask.png
# Now patchifying image: /content/train//996972_mask.png
# Now patchifying image: /content/train//99706_mask.png
# Now patchifying image: /content/train//997140_mask.png
# Now patchifying image: /content/train//997687_mask.png
# Now patchifying image: /content/train//997706_mask.png
# Now patchifying image: /content/train//997777_mask.png
# Now patchifying image: /content/train//997873_mask.png
# Now patchifying image: /content/train//997980_mask.png
# Now patchifying image: /content/train//997999_mask.png
# Now patchifying image: /content/train//998069_mask.png
# Now patchifying image: /content/train//998098_mask.png
# Now patchifying image: /content/train//998129_mask.png
# Now patchifying image: /content/train//99816_mask.png
# Now patchifying image: /content/train//99884_mask.png
# Now patchifying image: /content/train//999130_mask.png
# Now patchifying image: /content/train//99913_mask.png
# Now patchifying image: /content/train//999233_mask.png
# Now patchifying image: /content/train//999248_mask.png
# Now patchifying image: /content/train//999431_mask.png
# Now patchifying image: /content/train//999531_mask.png
# Now patchifying image: /content/train//999667_mask.png
# Now patchifying image: /content/train//999764_mask.png
# Now patchifying image: /content/train//99995_mask.png

# %%
train_img_dir = "/content/256_patches/images/"
train_mask_dir = "/content/256_patches/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

img_list=sorted(img_list)
msk_list=sorted(msk_list)

num_images = len(os.listdir(train_img_dir))


img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
plt.show()

# %%
useless=0  #Useless image counter
useful_images_names=[]
for img in range(len(img_list)):   #Using t1_list as all lists are of same size
    img_name=img_list[img]
    mask_name = msk_list[img]
    print("Now preparing image and masks number: ", img)
      
    temp_image=cv2.imread(train_img_dir+img_list[img], 1)
   
    temp_mask=cv2.imread(train_mask_dir+msk_list[img], 0)
    #temp_mask=temp_mask.astype(np.uint8)
    
    val, counts = np.unique(temp_mask, return_counts=True)
    
    if (1 - (counts[0]/counts.sum())) > 0.05:  #At least 5% useful area with labels that are not 0
        print("Save Me")
        
        cv2.imwrite(os.path.join("/content/256_patches/images_with_useful_info/images", img_name), temp_image)
        
        cv2.imwrite(os.path.join("/content/256_patches/images_with_useful_info/masks", mask_name), temp_mask)
        
    else:
        print("I am useless")   
        useless +=1

print("Total useful images are: ", len(img_list)-useless)  #20,075
print("Total useless images are: ", useless) #21,571
# Out:
# Streaming output truncated to the last 5000 lines.
# Now preparing image and masks number:  97117
# Save Me
# Now preparing image and masks number:  97118
# Save Me
# Now preparing image and masks number:  97119
# Save Me
# Now preparing image and masks number:  97120
# Save Me
# Now preparing image and masks number:  97121
# Save Me
# Now preparing image and masks number:  97122
# Save Me
# Now preparing image and masks number:  97123
# Save Me
# Now preparing image and masks number:  97124
# Save Me
# Now preparing image and masks number:  97125
# Save Me
# Now preparing image and masks number:  97126
# Save Me
# Now preparing image and masks number:  97127
# Save Me
# Now preparing image and masks number:  97128
# I am useless
# Now preparing image and masks number:  97129
# I am useless
# Now preparing image and masks number:  97130
# Save Me
# Now preparing image and masks number:  97131
# I am useless
# Now preparing image and masks number:  97132
# Save Me
# Now preparing image and masks number:  97133
# Save Me
# Now preparing image and masks number:  97134
# Save Me
# Now preparing image and masks number:  97135
# I am useless
# Now preparing image and masks number:  97136
# I am useless
# Now preparing image and masks number:  97137
# I am useless
# Now preparing image and masks number:  97138
# I am useless
# Now preparing image and masks number:  97139
# I am useless
# Now preparing image and masks number:  97140
# I am useless
# Now preparing image and masks number:  97141
# I am useless
# Now preparing image and masks number:  97142
# I am useless
# Now preparing image and masks number:  97143
# I am useless
# Now preparing image and masks number:  97144
# I am useless
# Now preparing image and masks number:  97145
# I am useless
# Now preparing image and masks number:  97146
# I am useless
# Now preparing image and masks number:  97147
# I am useless
# Now preparing image and masks number:  97148
# Save Me
# Now preparing image and masks number:  97149
# I am useless
# Now preparing image and masks number:  97150
# I am useless
# Now preparing image and masks number:  97151
# I am useless
# Now preparing image and masks number:  97152
# I am useless
# Now preparing image and masks number:  97153
# I am useless
# Now preparing image and masks number:  97154
# I am useless
# Now preparing image and masks number:  97155
# I am useless
# Now preparing image and masks number:  97156
# I am useless
# Now preparing image and masks number:  97157
# Save Me
# Now preparing image and masks number:  97158
# I am useless
# Now preparing image and masks number:  97159
# I am useless
# Now preparing image and masks number:  97160
# I am useless
# Now preparing image and masks number:  97161
# Save Me
# Now preparing image and masks number:  97162
# I am useless
# Now preparing image and masks number:  97163
# I am useless
# Now preparing image and masks number:  97164
# I am useless
# Now preparing image and masks number:  97165
# Save Me
# Now preparing image and masks number:  97166
# I am useless
# Now preparing image and masks number:  97167
# I am useless
# Now preparing image and masks number:  97168
# I am useless
# Now preparing image and masks number:  97169
# I am useless
# Now preparing image and masks number:  97170
# Save Me
# Now preparing image and masks number:  97171
# I am useless
# Now preparing image and masks number:  97172
# I am useless
# Now preparing image and masks number:  97173
# Save Me
# Now preparing image and masks number:  97174
# Save Me
# Now preparing image and masks number:  97175
# I am useless
# Now preparing image and masks number:  97176
# I am useless
# Now preparing image and masks number:  97177
# Save Me
# Now preparing image and masks number:  97178
# I am useless
# Now preparing image and masks number:  97179
# I am useless
# Now preparing image and masks number:  97180
# I am useless
# Now preparing image and masks number:  97181
# Save Me
# Now preparing image and masks number:  97182
# I am useless
# Now preparing image and masks number:  97183
# I am useless
# Now preparing image and masks number:  97184
# I am useless
# Now preparing image and masks number:  97185
# I am useless
# Now preparing image and masks number:  97186
# I am useless
# Now preparing image and masks number:  97187
# Save Me
# Now preparing image and masks number:  97188
# Save Me
# Now preparing image and masks number:  97189
# Save Me
# Now preparing image and masks number:  97190
# Save Me
# Now preparing image and masks number:  97191
# I am useless
# Now preparing image and masks number:  97192
# I am useless
# Now preparing image and masks number:  97193
# I am useless
# Now preparing image and masks number:  97194
# I am useless
# Now preparing image and masks number:  97195
# I am useless
# Now preparing image and masks number:  97196
# I am useless
# Now preparing image and masks number:  97197
# I am useless
# Now preparing image and masks number:  97198
# I am useless
# Now preparing image and masks number:  97199
# I am useless
# Now preparing image and masks number:  97200
# I am useless
# Now preparing image and masks number:  97201
# I am useless
# Now preparing image and masks number:  97202
# I am useless
# Now preparing image and masks number:  97203
# Save Me
# Now preparing image and masks number:  97204
# I am useless
# Now preparing image and masks number:  97205
# I am useless
# Now preparing image and masks number:  97206
# I am useless
# Now preparing image and masks number:  97207
# I am useless
# Now preparing image and masks number:  97208
# I am useless
# Now preparing image and masks number:  97209
# I am useless
# Now preparing image and masks number:  97210
# I am useless
# Now preparing image and masks number:  97211
# I am useless
# Now preparing image and masks number:  97212
# I am useless
# Now preparing image and masks number:  97213
# I am useless
# Now preparing image and masks number:  97214
# I am useless
# Now preparing image and masks number:  97215
# I am useless
# Now preparing image and masks number:  97216
# I am useless
# Now preparing image and masks number:  97217
# Save Me
# Now preparing image and masks number:  97218
# I am useless
# Now preparing image and masks number:  97219
# I am useless
# Now preparing image and masks number:  97220
# I am useless
# Now preparing image and masks number:  97221
# Save Me
# Now preparing image and masks number:  97222
# I am useless
# Now preparing image and masks number:  97223
# I am useless
# Now preparing image and masks number:  97224
# I am useless
# Now preparing image and masks number:  97225
# Save Me
# Now preparing image and masks number:  97226
# I am useless
# Now preparing image and masks number:  97227
# I am useless
# Now preparing image and masks number:  97228
# I am useless
# Now preparing image and masks number:  97229
# Save Me
# Now preparing image and masks number:  97230
# I am useless
# Now preparing image and masks number:  97231
# I am useless
# Now preparing image and masks number:  97232
# Save Me
# Now preparing image and masks number:  97233
# I am useless
# Now preparing image and masks number:  97234
# I am useless
# Now preparing image and masks number:  97235
# I am useless
# Now preparing image and masks number:  97236
# Save Me
# Now preparing image and masks number:  97237
# I am useless
# Now preparing image and masks number:  97238
# I am useless
# Now preparing image and masks number:  97239
# I am useless
# Now preparing image and masks number:  97240
# Save Me
# Now preparing image and masks number:  97241
# I am useless
# Now preparing image and masks number:  97242
# Save Me
# Now preparing image and masks number:  97243
# I am useless
# Now preparing image and masks number:  97244
# Save Me
# Now preparing image and masks number:  97245
# Save Me
# Now preparing image and masks number:  97246
# I am useless
# Now preparing image and masks number:  97247
# I am useless
# Now preparing image and masks number:  97248
# I am useless
# Now preparing image and masks number:  97249
# I am useless
# Now preparing image and masks number:  97250
# I am useless
# Now preparing image and masks number:  97251
# I am useless
# Now preparing image and masks number:  97252
# Save Me
# Now preparing image and masks number:  97253
# I am useless
# Now preparing image and masks number:  97254
# I am useless
# Now preparing image and masks number:  97255
# I am useless
# Now preparing image and masks number:  97256
# I am useless
# Now preparing image and masks number:  97257
# I am useless
# Now preparing image and masks number:  97258
# Save Me
# Now preparing image and masks number:  97259
# Save Me
# Now preparing image and masks number:  97260
# I am useless
# Now preparing image and masks number:  97261
# I am useless
# Now preparing image and masks number:  97262
# I am useless
# Now preparing image and masks number:  97263
# Save Me
# Now preparing image and masks number:  97264
# I am useless
# Now preparing image and masks number:  97265
# Save Me
# Now preparing image and masks number:  97266
# I am useless
# Now preparing image and masks number:  97267
# I am useless
# Now preparing image and masks number:  97268
# Save Me
# Now preparing image and masks number:  97269
# I am useless
# Now preparing image and masks number:  97270
# I am useless
# Now preparing image and masks number:  97271
# I am useless
# Now preparing image and masks number:  97272
# I am useless
# Now preparing image and masks number:  97273
# I am useless
# Now preparing image and masks number:  97274
# I am useless
# Now preparing image and masks number:  97275
# I am useless
# Now preparing image and masks number:  97276
# I am useless
# Now preparing image and masks number:  97277
# I am useless
# Now preparing image and masks number:  97278
# I am useless
# Now preparing image and masks number:  97279
# I am useless
# Now preparing image and masks number:  97280
# Save Me
# Now preparing image and masks number:  97281
# Save Me
# Now preparing image and masks number:  97282
# Save Me
# Now preparing image and masks number:  97283
# Save Me
# Now preparing image and masks number:  97284
# I am useless
# Now preparing image and masks number:  97285
# Save Me
# Now preparing image and masks number:  97286
# Save Me
# Now preparing image and masks number:  97287
# Save Me
# Now preparing image and masks number:  97288
# Save Me
# Now preparing image and masks number:  97289
# I am useless
# Now preparing image and masks number:  97290
# I am useless
# Now preparing image and masks number:  97291
# I am useless
# Now preparing image and masks number:  97292
# I am useless
# Now preparing image and masks number:  97293
# I am useless
# Now preparing image and masks number:  97294
# Save Me
# Now preparing image and masks number:  97295
# Save Me
# Now preparing image and masks number:  97296
# Save Me
# Now preparing image and masks number:  97297
# I am useless
# Now preparing image and masks number:  97298
# Save Me
# Now preparing image and masks number:  97299
# Save Me
# Now preparing image and masks number:  97300
# Save Me
# Now preparing image and masks number:  97301
# Save Me
# Now preparing image and masks number:  97302
# Save Me
# Now preparing image and masks number:  97303
# Save Me
# Now preparing image and masks number:  97304
# Save Me
# Now preparing image and masks number:  97305
# Save Me
# Now preparing image and masks number:  97306
# Save Me
# Now preparing image and masks number:  97307
# Save Me
# Now preparing image and masks number:  97308
# I am useless
# Now preparing image and masks number:  97309
# Save Me
# Now preparing image and masks number:  97310
# Save Me
# Now preparing image and masks number:  97311
# Save Me
# Now preparing image and masks number:  97312
# I am useless
# Now preparing image and masks number:  97313
# I am useless
# Now preparing image and masks number:  97314
# I am useless
# Now preparing image and masks number:  97315
# I am useless
# Now preparing image and masks number:  97316
# I am useless
# Now preparing image and masks number:  97317
# I am useless
# Now preparing image and masks number:  97318
# I am useless
# Now preparing image and masks number:  97319
# I am useless
# Now preparing image and masks number:  97320
# I am useless
# Now preparing image and masks number:  97321
# I am useless
# Now preparing image and masks number:  97322
# I am useless
# Now preparing image and masks number:  97323
# I am useless
# Now preparing image and masks number:  97324
# I am useless
# Now preparing image and masks number:  97325
# I am useless
# Now preparing image and masks number:  97326
# I am useless
# Now preparing image and masks number:  97327
# I am useless
# Now preparing image and masks number:  97328
# I am useless
# Now preparing image and masks number:  97329
# I am useless
# Now preparing image and masks number:  97330
# I am useless
# Now preparing image and masks number:  97331
# Save Me
# Now preparing image and masks number:  97332
# Save Me
# Now preparing image and masks number:  97333
# Save Me
# Now preparing image and masks number:  97334
# I am useless
# Now preparing image and masks number:  97335
# I am useless
# Now preparing image and masks number:  97336
# Save Me
# Now preparing image and masks number:  97337
# I am useless
# Now preparing image and masks number:  97338
# I am useless
# Now preparing image and masks number:  97339
# I am useless
# Now preparing image and masks number:  97340
# I am useless
# Now preparing image and masks number:  97341
# I am useless
# Now preparing image and masks number:  97342
# I am useless
# Now preparing image and masks number:  97343
# I am useless
# Now preparing image and masks number:  97344
# Save Me
# Now preparing image and masks number:  97345
# Save Me
# Now preparing image and masks number:  97346
# Save Me
# Now preparing image and masks number:  97347
# Save Me
# Now preparing image and masks number:  97348
# Save Me
# Now preparing image and masks number:  97349
# Save Me
# Now preparing image and masks number:  97350
# Save Me
# Now preparing image and masks number:  97351
# Save Me
# Now preparing image and masks number:  97352
# Save Me
# Now preparing image and masks number:  97353
# Save Me
# Now preparing image and masks number:  97354
# Save Me
# Now preparing image and masks number:  97355
# Save Me
# Now preparing image and masks number:  97356
# Save Me
# Now preparing image and masks number:  97357
# Save Me
# Now preparing image and masks number:  97358
# Save Me
# Now preparing image and masks number:  97359
# Save Me
# Now preparing image and masks number:  97360
# Save Me
# Now preparing image and masks number:  97361
# Save Me
# Now preparing image and masks number:  97362
# Save Me
# Now preparing image and masks number:  97363
# Save Me
# Now preparing image and masks number:  97364
# Save Me
# Now preparing image and masks number:  97365
# Save Me
# Now preparing image and masks number:  97366
# Save Me
# Now preparing image and masks number:  97367
# Save Me
# Now preparing image and masks number:  97368
# Save Me
# Now preparing image and masks number:  97369
# Save Me
# Now preparing image and masks number:  97370
# Save Me
# Now preparing image and masks number:  97371
# Save Me
# Now preparing image and masks number:  97372
# Save Me
# Now preparing image and masks number:  97373
# Save Me
# Now preparing image and masks number:  97374
# Save Me
# Now preparing image and masks number:  97375
# Save Me
# Now preparing image and masks number:  97376
# I am useless
# Now preparing image and masks number:  97377
# I am useless
# Now preparing image and masks number:  97378
# I am useless
# Now preparing image and masks number:  97379
# I am useless
# Now preparing image and masks number:  97380
# I am useless
# Now preparing image and masks number:  97381
# I am useless
# Now preparing image and masks number:  97382
# I am useless
# Now preparing image and masks number:  97383
# I am useless
# Now preparing image and masks number:  97384
# I am useless
# Now preparing image and masks number:  97385
# I am useless
# Now preparing image and masks number:  97386
# I am useless
# Now preparing image and masks number:  97387
# I am useless
# Now preparing image and masks number:  97388
# I am useless
# Now preparing image and masks number:  97389
# I am useless
# Now preparing image and masks number:  97390
# I am useless
# Now preparing image and masks number:  97391
# I am useless
# Now preparing image and masks number:  97392
# I am useless
# Now preparing image and masks number:  97393
# I am useless
# Now preparing image and masks number:  97394
# I am useless
# Now preparing image and masks number:  97395
# I am useless
# Now preparing image and masks number:  97396
# I am useless
# Now preparing image and masks number:  97397
# I am useless
# Now preparing image and masks number:  97398
# I am useless
# Now preparing image and masks number:  97399
# I am useless
# Now preparing image and masks number:  97400
# I am useless
# Now preparing image and masks number:  97401
# I am useless
# Now preparing image and masks number:  97402
# I am useless
# Now preparing image and masks number:  97403
# I am useless
# Now preparing image and masks number:  97404
# I am useless
# Now preparing image and masks number:  97405
# I am useless
# Now preparing image and masks number:  97406
# Save Me
# Now preparing image and masks number:  97407
# I am useless
# Now preparing image and masks number:  97408
# Save Me
# Now preparing image and masks number:  97409
# Save Me
# Now preparing image and masks number:  97410
# I am useless
# Now preparing image and masks number:  97411
# Save Me
# Now preparing image and masks number:  97412
# I am useless
# Now preparing image and masks number:  97413
# Save Me
# Now preparing image and masks number:  97414
# Save Me
# Now preparing image and masks number:  97415
# I am useless
# Now preparing image and masks number:  97416
# Save Me
# Now preparing image and masks number:  97417
# Save Me
# Now preparing image and masks number:  97418
# I am useless
# Now preparing image and masks number:  97419
# I am useless
# Now preparing image and masks number:  97420
# Save Me
# Now preparing image and masks number:  97421
# Save Me
# Now preparing image and masks number:  97422
# I am useless
# Now preparing image and masks number:  97423
# Save Me
# Now preparing image and masks number:  97424
# I am useless
# Now preparing image and masks number:  97425
# I am useless
# Now preparing image and masks number:  97426
# I am useless
# Now preparing image and masks number:  97427
# I am useless
# Now preparing image and masks number:  97428
# I am useless
# Now preparing image and masks number:  97429
# Save Me
# Now preparing image and masks number:  97430
# Save Me
# Now preparing image and masks number:  97431
# Save Me
# Now preparing image and masks number:  97432
# Save Me
# Now preparing image and masks number:  97433
# I am useless
# Now preparing image and masks number:  97434
# Save Me
# Now preparing image and masks number:  97435
# Save Me
# Now preparing image and masks number:  97436
# Save Me
# Now preparing image and masks number:  97437
# Save Me
# Now preparing image and masks number:  97438
# Save Me
# Now preparing image and masks number:  97439
# I am useless
# Now preparing image and masks number:  97440
# Save Me
# Now preparing image and masks number:  97441
# I am useless
# Now preparing image and masks number:  97442
# I am useless
# Now preparing image and masks number:  97443
# I am useless
# Now preparing image and masks number:  97444
# Save Me
# Now preparing image and masks number:  97445
# I am useless
# Now preparing image and masks number:  97446
# I am useless
# Now preparing image and masks number:  97447
# I am useless
# Now preparing image and masks number:  97448
# Save Me
# Now preparing image and masks number:  97449
# I am useless
# Now preparing image and masks number:  97450
# I am useless
# Now preparing image and masks number:  97451
# Save Me
# Now preparing image and masks number:  97452
# Save Me
# Now preparing image and masks number:  97453
# I am useless
# Now preparing image and masks number:  97454
# Save Me
# Now preparing image and masks number:  97455
# Save Me
# Now preparing image and masks number:  97456
# I am useless
# Now preparing image and masks number:  97457
# I am useless
# Now preparing image and masks number:  97458
# I am useless
# Now preparing image and masks number:  97459
# I am useless
# Now preparing image and masks number:  97460
# I am useless
# Now preparing image and masks number:  97461
# I am useless
# Now preparing image and masks number:  97462
# I am useless
# Now preparing image and masks number:  97463
# I am useless
# Now preparing image and masks number:  97464
# Save Me
# Now preparing image and masks number:  97465
# I am useless
# Now preparing image and masks number:  97466
# I am useless
# Now preparing image and masks number:  97467
# I am useless
# Now preparing image and masks number:  97468
# I am useless
# Now preparing image and masks number:  97469
# I am useless
# Now preparing image and masks number:  97470
# Save Me
# Now preparing image and masks number:  97471
# I am useless
# Now preparing image and masks number:  97472
# Save Me
# Now preparing image and masks number:  97473
# I am useless
# Now preparing image and masks number:  97474
# Save Me
# Now preparing image and masks number:  97475
# Save Me
# Now preparing image and masks number:  97476
# Save Me
# Now preparing image and masks number:  97477
# Save Me
# Now preparing image and masks number:  97478
# Save Me
# Now preparing image and masks number:  97479
# Save Me
# Now preparing image and masks number:  97480
# Save Me
# Now preparing image and masks number:  97481
# Save Me
# Now preparing image and masks number:  97482
# Save Me
# Now preparing image and masks number:  97483
# Save Me
# Now preparing image and masks number:  97484
# Save Me
# Now preparing image and masks number:  97485
# Save Me
# Now preparing image and masks number:  97486
# Save Me
# Now preparing image and masks number:  97487
# I am useless
# Now preparing image and masks number:  97488
# I am useless
# Now preparing image and masks number:  97489
# I am useless
# Now preparing image and masks number:  97490
# I am useless
# Now preparing image and masks number:  97491
# I am useless
# Now preparing image and masks number:  97492
# I am useless
# Now preparing image and masks number:  97493
# I am useless
# Now preparing image and masks number:  97494
# I am useless
# Now preparing image and masks number:  97495
# I am useless
# Now preparing image and masks number:  97496
# I am useless
# Now preparing image and masks number:  97497
# I am useless
# Now preparing image and masks number:  97498
# I am useless
# Now preparing image and masks number:  97499
# I am useless
# Now preparing image and masks number:  97500
# I am useless
# Now preparing image and masks number:  97501
# I am useless
# Now preparing image and masks number:  97502
# I am useless
# Now preparing image and masks number:  97503
# I am useless
# Now preparing image and masks number:  97504
# I am useless
# Now preparing image and masks number:  97505
# Save Me
# Now preparing image and masks number:  97506
# Save Me
# Now preparing image and masks number:  97507
# I am useless
# Now preparing image and masks number:  97508
# I am useless
# Now preparing image and masks number:  97509
# Save Me
# Now preparing image and masks number:  97510
# Save Me
# Now preparing image and masks number:  97511
# I am useless
# Now preparing image and masks number:  97512
# I am useless
# Now preparing image and masks number:  97513
# Save Me
# Now preparing image and masks number:  97514
# Save Me
# Now preparing image and masks number:  97515
# Save Me
# Now preparing image and masks number:  97516
# I am useless
# Now preparing image and masks number:  97517
# I am useless
# Now preparing image and masks number:  97518
# Save Me
# Now preparing image and masks number:  97519
# Save Me
# Now preparing image and masks number:  97520
# I am useless
# Now preparing image and masks number:  97521
# I am useless
# Now preparing image and masks number:  97522
# I am useless
# Now preparing image and masks number:  97523
# I am useless
# Now preparing image and masks number:  97524
# I am useless
# Now preparing image and masks number:  97525
# I am useless
# Now preparing image and masks number:  97526
# I am useless
# Now preparing image and masks number:  97527
# I am useless
# Now preparing image and masks number:  97528
# I am useless
# Now preparing image and masks number:  97529
# I am useless
# Now preparing image and masks number:  97530
# I am useless
# Now preparing image and masks number:  97531
# I am useless
# Now preparing image and masks number:  97532
# I am useless
# Now preparing image and masks number:  97533
# I am useless
# Now preparing image and masks number:  97534
# I am useless
# Now preparing image and masks number:  97535
# I am useless
# Now preparing image and masks number:  97536
# Save Me
# Now preparing image and masks number:  97537
# I am useless
# Now preparing image and masks number:  97538
# Save Me
# Now preparing image and masks number:  97539
# Save Me
# Now preparing image and masks number:  97540
# I am useless
# Now preparing image and masks number:  97541
# Save Me
# Now preparing image and masks number:  97542
# I am useless
# Now preparing image and masks number:  97543
# I am useless
# Now preparing image and masks number:  97544
# I am useless
# Now preparing image and masks number:  97545
# I am useless
# Now preparing image and masks number:  97546
# I am useless
# Now preparing image and masks number:  97547
# I am useless
# Now preparing image and masks number:  97548
# I am useless
# Now preparing image and masks number:  97549
# I am useless
# Now preparing image and masks number:  97550
# I am useless
# Now preparing image and masks number:  97551
# I am useless
# Now preparing image and masks number:  97552
# I am useless
# Now preparing image and masks number:  97553
# Save Me
# Now preparing image and masks number:  97554
# I am useless
# Now preparing image and masks number:  97555
# I am useless
# Now preparing image and masks number:  97556
# Save Me
# Now preparing image and masks number:  97557
# I am useless
# Now preparing image and masks number:  97558
# I am useless
# Now preparing image and masks number:  97559
# I am useless
# Now preparing image and masks number:  97560
# I am useless
# Now preparing image and masks number:  97561
# I am useless
# Now preparing image and masks number:  97562
# I am useless
# Now preparing image and masks number:  97563
# I am useless
# Now preparing image and masks number:  97564
# I am useless
# Now preparing image and masks number:  97565
# I am useless
# Now preparing image and masks number:  97566
# I am useless
# Now preparing image and masks number:  97567
# I am useless
# Now preparing image and masks number:  97568
# I am useless
# Now preparing image and masks number:  97569
# I am useless
# Now preparing image and masks number:  97570
# I am useless
# Now preparing image and masks number:  97571
# Save Me
# Now preparing image and masks number:  97572
# Save Me
# Now preparing image and masks number:  97573
# Save Me
# Now preparing image and masks number:  97574
# Save Me
# Now preparing image and masks number:  97575
# I am useless
# Now preparing image and masks number:  97576
# Save Me
# Now preparing image and masks number:  97577
# Save Me
# Now preparing image and masks number:  97578
# I am useless
# Now preparing image and masks number:  97579
# I am useless
# Now preparing image and masks number:  97580
# I am useless
# Now preparing image and masks number:  97581
# I am useless
# Now preparing image and masks number:  97582
# I am useless
# Now preparing image and masks number:  97583
# I am useless
# Now preparing image and masks number:  97584
# I am useless
# Now preparing image and masks number:  97585
# I am useless
# Now preparing image and masks number:  97586
# I am useless
# Now preparing image and masks number:  97587
# I am useless
# Now preparing image and masks number:  97588
# I am useless
# Now preparing image and masks number:  97589
# I am useless
# Now preparing image and masks number:  97590
# I am useless
# Now preparing image and masks number:  97591
# I am useless
# Now preparing image and masks number:  97592
# I am useless
# Now preparing image and masks number:  97593
# I am useless
# Now preparing image and masks number:  97594
# I am useless
# Now preparing image and masks number:  97595
# I am useless
# Now preparing image and masks number:  97596
# I am useless
# Now preparing image and masks number:  97597
# I am useless
# Now preparing image and masks number:  97598
# I am useless
# Now preparing image and masks number:  97599
# I am useless
# Now preparing image and masks number:  97600
# I am useless
# Now preparing image and masks number:  97601
# I am useless
# Now preparing image and masks number:  97602
# I am useless
# Now preparing image and masks number:  97603
# I am useless
# Now preparing image and masks number:  97604
# I am useless
# Now preparing image and masks number:  97605
# I am useless
# Now preparing image and masks number:  97606
# I am useless
# Now preparing image and masks number:  97607
# I am useless
# Now preparing image and masks number:  97608
# I am useless
# Now preparing image and masks number:  97609
# I am useless
# Now preparing image and masks number:  97610
# I am useless
# Now preparing image and masks number:  97611
# I am useless
# Now preparing image and masks number:  97612
# I am useless
# Now preparing image and masks number:  97613
# I am useless
# Now preparing image and masks number:  97614
# I am useless
# Now preparing image and masks number:  97615
# I am useless
# Now preparing image and masks number:  97616
# I am useless
# Now preparing image and masks number:  97617
# I am useless
# Now preparing image and masks number:  97618
# I am useless
# Now preparing image and masks number:  97619
# I am useless
# Now preparing image and masks number:  97620
# I am useless
# Now preparing image and masks number:  97621
# I am useless
# Now preparing image and masks number:  97622
# I am useless
# Now preparing image and masks number:  97623
# I am useless
# Now preparing image and masks number:  97624
# I am useless
# Now preparing image and masks number:  97625
# I am useless
# Now preparing image and masks number:  97626
# I am useless
# Now preparing image and masks number:  97627
# I am useless
# Now preparing image and masks number:  97628
# I am useless
# Now preparing image and masks number:  97629
# I am useless
# Now preparing image and masks number:  97630
# I am useless
# Now preparing image and masks number:  97631
# I am useless
# Now preparing image and masks number:  97632
# I am useless
# Now preparing image and masks number:  97633
# I am useless
# Now preparing image and masks number:  97634
# I am useless
# Now preparing image and masks number:  97635
# Save Me
# Now preparing image and masks number:  97636
# Save Me
# Now preparing image and masks number:  97637
# I am useless
# Now preparing image and masks number:  97638
# I am useless
# Now preparing image and masks number:  97639
# Save Me
# Now preparing image and masks number:  97640
# I am useless
# Now preparing image and masks number:  97641
# I am useless
# Now preparing image and masks number:  97642
# Save Me
# Now preparing image and masks number:  97643
# Save Me
# Now preparing image and masks number:  97644
# I am useless
# Now preparing image and masks number:  97645
# Save Me
# Now preparing image and masks number:  97646
# Save Me
# Now preparing image and masks number:  97647
# Save Me
# Now preparing image and masks number:  97648
# I am useless
# Now preparing image and masks number:  97649
# I am useless
# Now preparing image and masks number:  97650
# Save Me
# Now preparing image and masks number:  97651
# Save Me
# Now preparing image and masks number:  97652
# I am useless
# Now preparing image and masks number:  97653
# I am useless
# Now preparing image and masks number:  97654
# Save Me
# Now preparing image and masks number:  97655
# Save Me
# Now preparing image and masks number:  97656
# I am useless
# Now preparing image and masks number:  97657
# I am useless
# Now preparing image and masks number:  97658
# Save Me
# Now preparing image and masks number:  97659
# Save Me
# Now preparing image and masks number:  97660
# I am useless
# Now preparing image and masks number:  97661
# I am useless
# Now preparing image and masks number:  97662
# Save Me
# Now preparing image and masks number:  97663
# I am useless
# Now preparing image and masks number:  97664
# Save Me
# Now preparing image and masks number:  97665
# Save Me
# Now preparing image and masks number:  97666
# Save Me
# Now preparing image and masks number:  97667
# Save Me
# Now preparing image and masks number:  97668
# Save Me
# Now preparing image and masks number:  97669
# I am useless
# Now preparing image and masks number:  97670
# Save Me
# Now preparing image and masks number:  97671
# Save Me
# Now preparing image and masks number:  97672
# Save Me
# Now preparing image and masks number:  97673
# Save Me
# Now preparing image and masks number:  97674
# Save Me
# Now preparing image and masks number:  97675
# Save Me
# Now preparing image and masks number:  97676
# Save Me
# Now preparing image and masks number:  97677
# Save Me
# Now preparing image and masks number:  97678
# Save Me
# Now preparing image and masks number:  97679
# Save Me
# Now preparing image and masks number:  97680
# Save Me
# Now preparing image and masks number:  97681
# Save Me
# Now preparing image and masks number:  97682
# Save Me
# Now preparing image and masks number:  97683
# Save Me
# Now preparing image and masks number:  97684
# Save Me
# Now preparing image and masks number:  97685
# Save Me
# Now preparing image and masks number:  97686
# Save Me
# Now preparing image and masks number:  97687
# Save Me
# Now preparing image and masks number:  97688
# Save Me
# Now preparing image and masks number:  97689
# Save Me
# Now preparing image and masks number:  97690
# Save Me
# Now preparing image and masks number:  97691
# Save Me
# Now preparing image and masks number:  97692
# Save Me
# Now preparing image and masks number:  97693
# Save Me
# Now preparing image and masks number:  97694
# Save Me
# Now preparing image and masks number:  97695
# Save Me
# Now preparing image and masks number:  97696
# I am useless
# Now preparing image and masks number:  97697
# I am useless
# Now preparing image and masks number:  97698
# Save Me
# Now preparing image and masks number:  97699
# I am useless
# Now preparing image and masks number:  97700
# Save Me
# Now preparing image and masks number:  97701
# Save Me
# Now preparing image and masks number:  97702
# I am useless
# Now preparing image and masks number:  97703
# I am useless
# Now preparing image and masks number:  97704
# I am useless
# Now preparing image and masks number:  97705
# I am useless
# Now preparing image and masks number:  97706
# I am useless
# Now preparing image and masks number:  97707
# I am useless
# Now preparing image and masks number:  97708
# I am useless
# Now preparing image and masks number:  97709
# I am useless
# Now preparing image and masks number:  97710
# I am useless
# Now preparing image and masks number:  97711
# I am useless
# Now preparing image and masks number:  97712
# I am useless
# Now preparing image and masks number:  97713
# Save Me
# Now preparing image and masks number:  97714
# Save Me
# Now preparing image and masks number:  97715
# Save Me
# Now preparing image and masks number:  97716
# I am useless
# Now preparing image and masks number:  97717
# Save Me
# Now preparing image and masks number:  97718
# Save Me
# Now preparing image and masks number:  97719
# Save Me
# Now preparing image and masks number:  97720
# Save Me
# Now preparing image and masks number:  97721
# I am useless
# Now preparing image and masks number:  97722
# I am useless
# Now preparing image and masks number:  97723
# Save Me
# Now preparing image and masks number:  97724
# Save Me
# Now preparing image and masks number:  97725
# Save Me
# Now preparing image and masks number:  97726
# Save Me
# Now preparing image and masks number:  97727
# Save Me
# Now preparing image and masks number:  97728
# I am useless
# Now preparing image and masks number:  97729
# I am useless
# Now preparing image and masks number:  97730
# I am useless
# Now preparing image and masks number:  97731
# I am useless
# Now preparing image and masks number:  97732
# I am useless
# Now preparing image and masks number:  97733
# I am useless
# Now preparing image and masks number:  97734
# I am useless
# Now preparing image and masks number:  97735
# I am useless
# Now preparing image and masks number:  97736
# I am useless
# Now preparing image and masks number:  97737
# Save Me
# Now preparing image and masks number:  97738
# I am useless
# Now preparing image and masks number:  97739
# I am useless
# Now preparing image and masks number:  97740
# Save Me
# Now preparing image and masks number:  97741
# I am useless
# Now preparing image and masks number:  97742
# I am useless
# Now preparing image and masks number:  97743
# I am useless
# Now preparing image and masks number:  97744
# I am useless
# Now preparing image and masks number:  97745
# Save Me
# Now preparing image and masks number:  97746
# Save Me
# Now preparing image and masks number:  97747
# Save Me
# Now preparing image and masks number:  97748
# Save Me
# Now preparing image and masks number:  97749
# I am useless
# Now preparing image and masks number:  97750
# Save Me
# Now preparing image and masks number:  97751
# Save Me
# Now preparing image and masks number:  97752
# Save Me
# Now preparing image and masks number:  97753
# Save Me
# Now preparing image and masks number:  97754
# Save Me
# Now preparing image and masks number:  97755
# Save Me
# Now preparing image and masks number:  97756
# Save Me
# Now preparing image and masks number:  97757
# Save Me
# Now preparing image and masks number:  97758
# Save Me
# Now preparing image and masks number:  97759
# Save Me
# Now preparing image and masks number:  97760
# I am useless
# Now preparing image and masks number:  97761
# I am useless
# Now preparing image and masks number:  97762
# I am useless
# Now preparing image and masks number:  97763
# Save Me
# Now preparing image and masks number:  97764
# I am useless
# Now preparing image and masks number:  97765
# I am useless
# Now preparing image and masks number:  97766
# Save Me
# Now preparing image and masks number:  97767
# Save Me
# Now preparing image and masks number:  97768
# I am useless
# Now preparing image and masks number:  97769
# I am useless
# Now preparing image and masks number:  97770
# I am useless
# Now preparing image and masks number:  97771
# I am useless
# Now preparing image and masks number:  97772
# I am useless
# Now preparing image and masks number:  97773
# I am useless
# Now preparing image and masks number:  97774
# I am useless
# Now preparing image and masks number:  97775
# I am useless
# Now preparing image and masks number:  97776
# Save Me
# Now preparing image and masks number:  97777
# Save Me
# Now preparing image and masks number:  97778
# I am useless
# Now preparing image and masks number:  97779
# I am useless
# Now preparing image and masks number:  97780
# I am useless
# Now preparing image and masks number:  97781
# I am useless
# Now preparing image and masks number:  97782
# Save Me
# Now preparing image and masks number:  97783
# I am useless
# Now preparing image and masks number:  97784
# I am useless
# Now preparing image and masks number:  97785
# I am useless
# Now preparing image and masks number:  97786
# I am useless
# Now preparing image and masks number:  97787
# Save Me
# Now preparing image and masks number:  97788
# I am useless
# Now preparing image and masks number:  97789
# I am useless
# Now preparing image and masks number:  97790
# I am useless
# Now preparing image and masks number:  97791
# I am useless
# Now preparing image and masks number:  97792
# I am useless
# Now preparing image and masks number:  97793
# Save Me
# Now preparing image and masks number:  97794
# I am useless
# Now preparing image and masks number:  97795
# I am useless
# Now preparing image and masks number:  97796
# Save Me
# Now preparing image and masks number:  97797
# Save Me
# Now preparing image and masks number:  97798
# I am useless
# Now preparing image and masks number:  97799
# I am useless
# Now preparing image and masks number:  97800
# Save Me
# Now preparing image and masks number:  97801
# Save Me
# Now preparing image and masks number:  97802
# Save Me
# Now preparing image and masks number:  97803
# I am useless
# Now preparing image and masks number:  97804
# I am useless
# Now preparing image and masks number:  97805
# Save Me
# Now preparing image and masks number:  97806
# I am useless
# Now preparing image and masks number:  97807
# I am useless
# Now preparing image and masks number:  97808
# I am useless
# Now preparing image and masks number:  97809
# I am useless
# Now preparing image and masks number:  97810
# I am useless
# Now preparing image and masks number:  97811
# I am useless
# Now preparing image and masks number:  97812
# I am useless
# Now preparing image and masks number:  97813
# I am useless
# Now preparing image and masks number:  97814
# I am useless
# Now preparing image and masks number:  97815
# I am useless
# Now preparing image and masks number:  97816
# I am useless
# Now preparing image and masks number:  97817
# I am useless
# Now preparing image and masks number:  97818
# I am useless
# Now preparing image and masks number:  97819
# I am useless
# Now preparing image and masks number:  97820
# I am useless
# Now preparing image and masks number:  97821
# I am useless
# Now preparing image and masks number:  97822
# I am useless
# Now preparing image and masks number:  97823
# I am useless
# Now preparing image and masks number:  97824
# Save Me
# Now preparing image and masks number:  97825
# Save Me
# Now preparing image and masks number:  97826
# Save Me
# Now preparing image and masks number:  97827
# Save Me
# Now preparing image and masks number:  97828
# I am useless
# Now preparing image and masks number:  97829
# Save Me
# Now preparing image and masks number:  97830
# Save Me
# Now preparing image and masks number:  97831
# I am useless
# Now preparing image and masks number:  97832
# Save Me
# Now preparing image and masks number:  97833
# Save Me
# Now preparing image and masks number:  97834
# Save Me
# Now preparing image and masks number:  97835
# Save Me
# Now preparing image and masks number:  97836
# Save Me
# Now preparing image and masks number:  97837
# Save Me
# Now preparing image and masks number:  97838
# Save Me
# Now preparing image and masks number:  97839
# Save Me
# Now preparing image and masks number:  97840
# Save Me
# Now preparing image and masks number:  97841
# I am useless
# Now preparing image and masks number:  97842
# I am useless
# Now preparing image and masks number:  97843
# I am useless
# Now preparing image and masks number:  97844
# Save Me
# Now preparing image and masks number:  97845
# I am useless
# Now preparing image and masks number:  97846
# I am useless
# Now preparing image and masks number:  97847
# I am useless
# Now preparing image and masks number:  97848
# Save Me
# Now preparing image and masks number:  97849
# I am useless
# Now preparing image and masks number:  97850
# Save Me
# Now preparing image and masks number:  97851
# I am useless
# Now preparing image and masks number:  97852
# Save Me
# Now preparing image and masks number:  97853
# I am useless
# Now preparing image and masks number:  97854
# I am useless
# Now preparing image and masks number:  97855
# I am useless
# Now preparing image and masks number:  97856
# Save Me
# Now preparing image and masks number:  97857
# Save Me
# Now preparing image and masks number:  97858
# I am useless
# Now preparing image and masks number:  97859
# I am useless
# Now preparing image and masks number:  97860
# Save Me
# Now preparing image and masks number:  97861
# I am useless
# Now preparing image and masks number:  97862
# I am useless
# Now preparing image and masks number:  97863
# I am useless
# Now preparing image and masks number:  97864
# I am useless
# Now preparing image and masks number:  97865
# I am useless
# Now preparing image and masks number:  97866
# I am useless
# Now preparing image and masks number:  97867
# I am useless
# Now preparing image and masks number:  97868
# Save Me
# Now preparing image and masks number:  97869
# I am useless
# Now preparing image and masks number:  97870
# I am useless
# Now preparing image and masks number:  97871
# I am useless
# Now preparing image and masks number:  97872
# I am useless
# Now preparing image and masks number:  97873
# I am useless
# Now preparing image and masks number:  97874
# Save Me
# Now preparing image and masks number:  97875
# I am useless
# Now preparing image and masks number:  97876
# I am useless
# Now preparing image and masks number:  97877
# I am useless
# Now preparing image and masks number:  97878
# I am useless
# Now preparing image and masks number:  97879
# I am useless
# Now preparing image and masks number:  97880
# I am useless
# Now preparing image and masks number:  97881
# I am useless
# Now preparing image and masks number:  97882
# I am useless
# Now preparing image and masks number:  97883
# I am useless
# Now preparing image and masks number:  97884
# I am useless
# Now preparing image and masks number:  97885
# I am useless
# Now preparing image and masks number:  97886
# I am useless
# Now preparing image and masks number:  97887
# I am useless
# Now preparing image and masks number:  97888
# I am useless
# Now preparing image and masks number:  97889
# Save Me
# Now preparing image and masks number:  97890
# I am useless
# Now preparing image and masks number:  97891
# I am useless
# Now preparing image and masks number:  97892
# I am useless
# Now preparing image and masks number:  97893
# Save Me
# Now preparing image and masks number:  97894
# I am useless
# Now preparing image and masks number:  97895
# I am useless
# Now preparing image and masks number:  97896
# I am useless
# Now preparing image and masks number:  97897
# Save Me
# Now preparing image and masks number:  97898
# I am useless
# Now preparing image and masks number:  97899
# I am useless
# Now preparing image and masks number:  97900
# I am useless
# Now preparing image and masks number:  97901
# Save Me
# Now preparing image and masks number:  97902
# I am useless
# Now preparing image and masks number:  97903
# I am useless
# Now preparing image and masks number:  97904
# I am useless
# Now preparing image and masks number:  97905
# Save Me
# Now preparing image and masks number:  97906
# I am useless
# Now preparing image and masks number:  97907
# Save Me
# Now preparing image and masks number:  97908
# I am useless
# Now preparing image and masks number:  97909
# Save Me
# Now preparing image and masks number:  97910
# Save Me
# Now preparing image and masks number:  97911
# Save Me
# Now preparing image and masks number:  97912
# Save Me
# Now preparing image and masks number:  97913
# I am useless
# Now preparing image and masks number:  97914
# I am useless
# Now preparing image and masks number:  97915
# Save Me
# Now preparing image and masks number:  97916
# I am useless
# Now preparing image and masks number:  97917
# I am useless
# Now preparing image and masks number:  97918
# I am useless
# Now preparing image and masks number:  97919
# Save Me
# Now preparing image and masks number:  97920
# I am useless
# Now preparing image and masks number:  97921
# Save Me
# Now preparing image and masks number:  97922
# I am useless
# Now preparing image and masks number:  97923
# I am useless
# Now preparing image and masks number:  97924
# I am useless
# Now preparing image and masks number:  97925
# Save Me
# Now preparing image and masks number:  97926
# I am useless
# Now preparing image and masks number:  97927
# I am useless
# Now preparing image and masks number:  97928
# I am useless
# Now preparing image and masks number:  97929
# Save Me
# Now preparing image and masks number:  97930
# I am useless
# Now preparing image and masks number:  97931
# I am useless
# Now preparing image and masks number:  97932
# I am useless
# Now preparing image and masks number:  97933
# I am useless
# Now preparing image and masks number:  97934
# I am useless
# Now preparing image and masks number:  97935
# I am useless
# Now preparing image and masks number:  97936
# I am useless
# Now preparing image and masks number:  97937
# I am useless
# Now preparing image and masks number:  97938
# I am useless
# Now preparing image and masks number:  97939
# I am useless
# Now preparing image and masks number:  97940
# I am useless
# Now preparing image and masks number:  97941
# I am useless
# Now preparing image and masks number:  97942
# I am useless
# Now preparing image and masks number:  97943
# I am useless
# Now preparing image and masks number:  97944
# Save Me
# Now preparing image and masks number:  97945
# Save Me
# Now preparing image and masks number:  97946
# Save Me
# Now preparing image and masks number:  97947
# Save Me
# Now preparing image and masks number:  97948
# Save Me
# Now preparing image and masks number:  97949
# Save Me
# Now preparing image and masks number:  97950
# Save Me
# Now preparing image and masks number:  97951
# Save Me
# Now preparing image and masks number:  97952
# I am useless
# Now preparing image and masks number:  97953
# I am useless
# Now preparing image and masks number:  97954
# I am useless
# Now preparing image and masks number:  97955
# I am useless
# Now preparing image and masks number:  97956
# I am useless
# Now preparing image and masks number:  97957
# I am useless
# Now preparing image and masks number:  97958
# I am useless
# Now preparing image and masks number:  97959
# I am useless
# Now preparing image and masks number:  97960
# I am useless
# Now preparing image and masks number:  97961
# I am useless
# Now preparing image and masks number:  97962
# I am useless
# Now preparing image and masks number:  97963
# Save Me
# Now preparing image and masks number:  97964
# I am useless
# Now preparing image and masks number:  97965
# I am useless
# Now preparing image and masks number:  97966
# I am useless
# Now preparing image and masks number:  97967
# Save Me
# Now preparing image and masks number:  97968
# I am useless
# Now preparing image and masks number:  97969
# I am useless
# ...
# Save Me
# Now preparing image and masks number:  99334
# Save Me
# Now preparing image and masks number:  99335
# Save Me
# Now preparing image and masks number:  99336
# I am useless
# Now preparing image and masks number:  99337
# I am useless
# Now preparing image and masks number:  99338
# I am useless
# Now preparing image and masks number:  99339
# Save Me
# Now preparing image and masks number:  99340
# Save Me
# Now preparing image and masks number:  99341
# I am useless
# Now preparing image and masks number:  99342
# I am useless
# Now preparing image and masks number:  99343
# Save Me
# Now preparing image and masks number:  99344
# I am useless
# Now preparing image and masks number:  99345
# I am useless
# Now preparing image and masks number:  99346
# I am useless
# Now preparing image and masks number:  99347
# I am useless
# Now preparing image and masks number:  99348
# I am useless
# Now preparing image and masks number:  99349
# I am useless
# Now preparing image and masks number:  99350
# I am useless
# Now preparing image and masks number:  99351
# I am useless
# Now preparing image and masks number:  99352
# I am useless
# Now preparing image and masks number:  99353
# I am useless
# Now preparing image and masks number:  99354
# I am useless
# Now preparing image and masks number:  99355
# I am useless
# Now preparing image and masks number:  99356
# I am useless
# Now preparing image and masks number:  99357
# I am useless
# Now preparing image and masks number:  99358
# I am useless
# Now preparing image and masks number:  99359
# I am useless
# Now preparing image and masks number:  99360
# Save Me
# Now preparing image and masks number:  99361
# I am useless
# Now preparing image and masks number:  99362
# I am useless
# Now preparing image and masks number:  99363
# I am useless
# Now preparing image and masks number:  99364
# Save Me
# Now preparing image and masks number:  99365
# I am useless
# Now preparing image and masks number:  99366
# I am useless
# Now preparing image and masks number:  99367
# I am useless
# Now preparing image and masks number:  99368
# I am useless
# Now preparing image and masks number:  99369
# I am useless
# Now preparing image and masks number:  99370
# I am useless
# Now preparing image and masks number:  99371
# I am useless
# Now preparing image and masks number:  99372
# I am useless
# Now preparing image and masks number:  99373
# I am useless
# Now preparing image and masks number:  99374
# I am useless
# Now preparing image and masks number:  99375
# I am useless
# Now preparing image and masks number:  99376
# Save Me
# Now preparing image and masks number:  99377
# Save Me
# Now preparing image and masks number:  99378
# Save Me
# Now preparing image and masks number:  99379
# I am useless
# Now preparing image and masks number:  99380
# Save Me
# Now preparing image and masks number:  99381
# Save Me
# Now preparing image and masks number:  99382
# Save Me
# Now preparing image and masks number:  99383
# I am useless
# Now preparing image and masks number:  99384
# Save Me
# Now preparing image and masks number:  99385
# I am useless
# Now preparing image and masks number:  99386
# I am useless
# Now preparing image and masks number:  99387
# I am useless
# Now preparing image and masks number:  99388
# Save Me
# Now preparing image and masks number:  99389
# Save Me
# Now preparing image and masks number:  99390
# I am useless
# Now preparing image and masks number:  99391
# I am useless
# Now preparing image and masks number:  99392
# I am useless
# Now preparing image and masks number:  99393
# I am useless
# Now preparing image and masks number:  99394
# I am useless
# Now preparing image and masks number:  99395
# I am useless
# Now preparing image and masks number:  99396
# Save Me
# Now preparing image and masks number:  99397
# I am useless
# Now preparing image and masks number:  99398
# I am useless
# Now preparing image and masks number:  99399
# I am useless
# Now preparing image and masks number:  99400
# I am useless
# Now preparing image and masks number:  99401
# I am useless
# Now preparing image and masks number:  99402
# I am useless
# Now preparing image and masks number:  99403
# I am useless
# Now preparing image and masks number:  99404
# I am useless
# Now preparing image and masks number:  99405
# I am useless
# Now preparing image and masks number:  99406
# I am useless
# Now preparing image and masks number:  99407
# I am useless
# Now preparing image and masks number:  99408
# I am useless
# Now preparing image and masks number:  99409
# Save Me
# Now preparing image and masks number:  99410
# Save Me
# Now preparing image and masks number:  99411
# I am useless
# Now preparing image and masks number:  99412
# Save Me
# Now preparing image and masks number:  99413
# Save Me
# Now preparing image and masks number:  99414
# I am useless
# Now preparing image and masks number:  99415
# Save Me
# Now preparing image and masks number:  99416
# Save Me
# Now preparing image and masks number:  99417
# Save Me
# Now preparing image and masks number:  99418
# Save Me
# Now preparing image and masks number:  99419
# Save Me
# Now preparing image and masks number:  99420
# Save Me
# Now preparing image and masks number:  99421
# I am useless
# Now preparing image and masks number:  99422
# Save Me
# Now preparing image and masks number:  99423
# Save Me
# Now preparing image and masks number:  99424
# I am useless
# Now preparing image and masks number:  99425
# I am useless
# Now preparing image and masks number:  99426
# I am useless
# Now preparing image and masks number:  99427
# I am useless
# Now preparing image and masks number:  99428
# I am useless
# Now preparing image and masks number:  99429
# I am useless
# Now preparing image and masks number:  99430
# I am useless
# Now preparing image and masks number:  99431
# I am useless
# Now preparing image and masks number:  99432
# I am useless
# Now preparing image and masks number:  99433
# I am useless
# Now preparing image and masks number:  99434
# I am useless
# Now preparing image and masks number:  99435
# I am useless
# Now preparing image and masks number:  99436
# I am useless
# Now preparing image and masks number:  99437
# I am useless
# Now preparing image and masks number:  99438
# I am useless
# Now preparing image and masks number:  99439
# I am useless
# Now preparing image and masks number:  99440
# Save Me
# Now preparing image and masks number:  99441
# Save Me
# Now preparing image and masks number:  99442
# Save Me
# Now preparing image and masks number:  99443
# Save Me
# Now preparing image and masks number:  99444
# Save Me
# Now preparing image and masks number:  99445
# Save Me
# Now preparing image and masks number:  99446
# Save Me
# Now preparing image and masks number:  99447
# Save Me
# Now preparing image and masks number:  99448
# Save Me
# Now preparing image and masks number:  99449
# Save Me
# Now preparing image and masks number:  99450
# Save Me
# Now preparing image and masks number:  99451
# Save Me
# Now preparing image and masks number:  99452
# I am useless
# Now preparing image and masks number:  99453
# Save Me
# Now preparing image and masks number:  99454
# Save Me
# Now preparing image and masks number:  99455
# I am useless
# Now preparing image and masks number:  99456
# I am useless
# Now preparing image and masks number:  99457
# I am useless
# Now preparing image and masks number:  99458
# Save Me
# Now preparing image and masks number:  99459
# I am useless
# Now preparing image and masks number:  99460
# I am useless
# Now preparing image and masks number:  99461
# I am useless
# Now preparing image and masks number:  99462
# Save Me
# Now preparing image and masks number:  99463
# I am useless
# Now preparing image and masks number:  99464
# I am useless
# Now preparing image and masks number:  99465
# I am useless
# Now preparing image and masks number:  99466
# Save Me
# Now preparing image and masks number:  99467
# I am useless
# Now preparing image and masks number:  99468
# I am useless
# Now preparing image and masks number:  99469
# I am useless
# Now preparing image and masks number:  99470
# I am useless
# Now preparing image and masks number:  99471
# Save Me
# Now preparing image and masks number:  99472
# I am useless
# Now preparing image and masks number:  99473
# I am useless
# Now preparing image and masks number:  99474
# Save Me
# Now preparing image and masks number:  99475
# I am useless
# Now preparing image and masks number:  99476
# I am useless
# Now preparing image and masks number:  99477
# I am useless
# Now preparing image and masks number:  99478
# I am useless
# Now preparing image and masks number:  99479
# I am useless
# Now preparing image and masks number:  99480
# I am useless
# Now preparing image and masks number:  99481
# I am useless
# Now preparing image and masks number:  99482
# I am useless
# Now preparing image and masks number:  99483
# I am useless
# Now preparing image and masks number:  99484
# I am useless
# Now preparing image and masks number:  99485
# I am useless
# Now preparing image and masks number:  99486
# I am useless
# Now preparing image and masks number:  99487
# I am useless
# Now preparing image and masks number:  99488
# Save Me
# Now preparing image and masks number:  99489
# Save Me
# Now preparing image and masks number:  99490
# I am useless
# Now preparing image and masks number:  99491
# Save Me
# Now preparing image and masks number:  99492
# Save Me
# Now preparing image and masks number:  99493
# Save Me
# Now preparing image and masks number:  99494
# Save Me
# Now preparing image and masks number:  99495
# Save Me
# Now preparing image and masks number:  99496
# Save Me
# Now preparing image and masks number:  99497
# Save Me
# Now preparing image and masks number:  99498
# I am useless
# Now preparing image and masks number:  99499
# Save Me
# Now preparing image and masks number:  99500
# Save Me
# Now preparing image and masks number:  99501
# I am useless
# Now preparing image and masks number:  99502
# I am useless
# Now preparing image and masks number:  99503
# Save Me
# Now preparing image and masks number:  99504
# I am useless
# Now preparing image and masks number:  99505
# I am useless
# Now preparing image and masks number:  99506
# I am useless
# Now preparing image and masks number:  99507
# I am useless
# Now preparing image and masks number:  99508
# I am useless
# Now preparing image and masks number:  99509
# Save Me
# Now preparing image and masks number:  99510
# Save Me
# Now preparing image and masks number:  99511
# Save Me
# Now preparing image and masks number:  99512
# Save Me
# Now preparing image and masks number:  99513
# I am useless
# Now preparing image and masks number:  99514
# I am useless
# Now preparing image and masks number:  99515
# Save Me
# Now preparing image and masks number:  99516
# Save Me
# Now preparing image and masks number:  99517
# I am useless
# Now preparing image and masks number:  99518
# I am useless
# Now preparing image and masks number:  99519
# Save Me
# Now preparing image and masks number:  99520
# I am useless
# Now preparing image and masks number:  99521
# I am useless
# Now preparing image and masks number:  99522
# I am useless
# Now preparing image and masks number:  99523
# I am useless
# Now preparing image and masks number:  99524
# I am useless
# Now preparing image and masks number:  99525
# I am useless
# Now preparing image and masks number:  99526
# I am useless
# Now preparing image and masks number:  99527
# I am useless
# Now preparing image and masks number:  99528
# I am useless
# Now preparing image and masks number:  99529
# I am useless
# Now preparing image and masks number:  99530
# I am useless
# Now preparing image and masks number:  99531
# I am useless
# Now preparing image and masks number:  99532
# I am useless
# Now preparing image and masks number:  99533
# I am useless
# Now preparing image and masks number:  99534
# I am useless
# Now preparing image and masks number:  99535
# I am useless
# Now preparing image and masks number:  99536
# I am useless
# Now preparing image and masks number:  99537
# I am useless
# Now preparing image and masks number:  99538
# I am useless
# Now preparing image and masks number:  99539
# I am useless
# Now preparing image and masks number:  99540
# I am useless
# Now preparing image and masks number:  99541
# I am useless
# Now preparing image and masks number:  99542
# I am useless
# Now preparing image and masks number:  99543
# I am useless
# Now preparing image and masks number:  99544
# I am useless
# Now preparing image and masks number:  99545
# I am useless
# Now preparing image and masks number:  99546
# I am useless
# Now preparing image and masks number:  99547
# I am useless
# Now preparing image and masks number:  99548
# I am useless
# Now preparing image and masks number:  99549
# I am useless
# Now preparing image and masks number:  99550
# I am useless
# Now preparing image and masks number:  99551
# I am useless
# Now preparing image and masks number:  99552
# I am useless
# Now preparing image and masks number:  99553
# I am useless
# Now preparing image and masks number:  99554
# I am useless
# Now preparing image and masks number:  99555
# I am useless
# Now preparing image and masks number:  99556
# I am useless
# Now preparing image and masks number:  99557
# I am useless
# Now preparing image and masks number:  99558
# I am useless
# Now preparing image and masks number:  99559
# I am useless
# Now preparing image and masks number:  99560
# I am useless
# Now preparing image and masks number:  99561
# I am useless
# Now preparing image and masks number:  99562
# I am useless
# Now preparing image and masks number:  99563
# I am useless
# Now preparing image and masks number:  99564
# I am useless
# Now preparing image and masks number:  99565
# I am useless
# Now preparing image and masks number:  99566
# I am useless
# Now preparing image and masks number:  99567
# I am useless
# Now preparing image and masks number:  99568
# Save Me
# Now preparing image and masks number:  99569
# Save Me
# Now preparing image and masks number:  99570
# I am useless
# Now preparing image and masks number:  99571
# I am useless
# Now preparing image and masks number:  99572
# I am useless
# Now preparing image and masks number:  99573
# Save Me
# Now preparing image and masks number:  99574
# I am useless
# Now preparing image and masks number:  99575
# Save Me
# Now preparing image and masks number:  99576
# I am useless
# Now preparing image and masks number:  99577
# Save Me
# Now preparing image and masks number:  99578
# Save Me
# Now preparing image and masks number:  99579
# I am useless
# Now preparing image and masks number:  99580
# I am useless
# Now preparing image and masks number:  99581
# I am useless
# Now preparing image and masks number:  99582
# I am useless
# Now preparing image and masks number:  99583
# Save Me
# Now preparing image and masks number:  99584
# Save Me
# Now preparing image and masks number:  99585
# Save Me
# Now preparing image and masks number:  99586
# Save Me
# Now preparing image and masks number:  99587
# Save Me
# Now preparing image and masks number:  99588
# Save Me
# Now preparing image and masks number:  99589
# Save Me
# Now preparing image and masks number:  99590
# Save Me
# Now preparing image and masks number:  99591
# Save Me
# Now preparing image and masks number:  99592
# I am useless
# Now preparing image and masks number:  99593
# I am useless
# Now preparing image and masks number:  99594
# Save Me
# Now preparing image and masks number:  99595
# Save Me
# Now preparing image and masks number:  99596
# Save Me
# Now preparing image and masks number:  99597
# I am useless
# Now preparing image and masks number:  99598
# Save Me
# Now preparing image and masks number:  99599
# I am useless
# Now preparing image and masks number:  99600
# I am useless
# Now preparing image and masks number:  99601
# I am useless
# Now preparing image and masks number:  99602
# I am useless
# Now preparing image and masks number:  99603
# I am useless
# Now preparing image and masks number:  99604
# Save Me
# Now preparing image and masks number:  99605
# Save Me
# Now preparing image and masks number:  99606
# I am useless
# Now preparing image and masks number:  99607
# I am useless
# Now preparing image and masks number:  99608
# Save Me
# Now preparing image and masks number:  99609
# I am useless
# Now preparing image and masks number:  99610
# I am useless
# Now preparing image and masks number:  99611
# I am useless
# Now preparing image and masks number:  99612
# Save Me
# Now preparing image and masks number:  99613
# I am useless
# Now preparing image and masks number:  99614
# I am useless
# Now preparing image and masks number:  99615
# I am useless
# Total useful images are:  30850
# Total useless images are:  68766

# %%
cd '/content'
# Out:
# /content

# %%
# !mkdir data_for_training_and_testing

# %%
# !pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders  # or import split_folders

input_folder = '/content/256_patches/images_with_useful_info/'
output_folder = '/content/data_for_training_and_testing/'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.85, .15), group_prefix=None) # default values
# Out:
# Copying files: 61700 files [00:32, 1889.74 files/s]

# %%
cd '/content'
# Out:
# /content

# %%
# !mkdir data_for_keras_aug

# %%
cd '/content/data_for_keras_aug'
# Out:
# /content/data_for_keras_aug

# %%
# !mkdir train_images train_masks val_images val_masks

# %%
cd '/content/data_for_keras_aug/train_images'
# Out:
# /content/data_for_keras_aug/train_images

# %%
mv '/content/data_for_training_and_testing/train/images' train

# %%
cd '/content/data_for_keras_aug/train_masks'
# Out:
# /content/data_for_keras_aug/train_masks

# %%
mv '/content/data_for_training_and_testing/train/masks' train

# %%
cd '/content/data_for_keras_aug/val_masks'
# Out:
# /content/data_for_keras_aug/val_masks

# %%
mv '/content/data_for_training_and_testing/val/masks' val

# %%
cd '/content/data_for_keras_aug/val_images'
# Out:
# /content/data_for_keras_aug/val_images

# %%
mv '/content/data_for_training_and_testing/val/images' val

# %%
train_img_dir = "/content/data_for_keras_aug/train_images/train/"
train_mask_dir = "/content/data_for_keras_aug/train_masks/train/"
val_img_dir = "/content/data_for_keras_aug/val_images/val/"
val_mask_dir = "/content/data_for_keras_aug/val_masks/val/"

train_img_path = "/content/data_for_keras_aug/train_images/"
train_mask_path = "/content/data_for_keras_aug/train_masks/"
val_img_path = "/content/data_for_keras_aug/val_images/"
val_mask_path = "/content/data_for_keras_aug/val_masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

img_list = sorted(img_list)
msk_list = sorted(msk_list)

num_images = len(os.listdir(train_img_dir))


img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
plt.show()

# %%
from tensorflow.keras.metrics import MeanIoU
import random

# %%
seed=24
batch_size= 8
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_data_gen_args = dict(rescale = 1/255.,
                         rotation_range=90,
                      width_shift_range=0.3,
                      height_shift_range=0.3,
                      shear_range=0.5,
                      zoom_range=0.3,
                      horizontal_flip=True,
                      vertical_flip=True,
                      fill_mode='reflect')

mask_data_gen_args = dict(rescale = 1/255.,  #Original pixel values are 0 and 255. So rescaling to 0 to 1
                        rotation_range=90,
                      width_shift_range=0.3,
                      height_shift_range=0.3,
                      shear_range=0.5,
                      zoom_range=0.3,
                      horizontal_flip=True,
                      vertical_flip=True,
                      fill_mode='reflect',
                      preprocessing_function = lambda x: np.where(x>0, 1, 0).astype(x.dtype)) #Binarize the output again. 

#If You need to resize images then add this to the flow_from_directory parameters 
#target_size=(150, 150), #Or whatever the size is for your network

image_data_generator = ImageDataGenerator(**img_data_gen_args)
image_generator = image_data_generator.flow_from_directory(train_img_path, 
                                                           seed=seed, 
                                                           batch_size=batch_size,
                                                           class_mode=None)  #Very important to set this otherwise it returns multiple numpy arrays 
                                                                            #thinking class mode is binary.

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
mask_generator = mask_data_generator.flow_from_directory(train_mask_path, 
                                                         seed=seed, 
                                                         batch_size=batch_size,
                                                         color_mode = 'grayscale',   #Read masks in grayscale
                                                         class_mode=None)


valid_img_generator = image_data_generator.flow_from_directory(val_img_path, 
                                                               seed=seed, 
                                                               batch_size=batch_size, 
                                                               class_mode=None) #Default batch size 32, if not specified here
valid_mask_generator = mask_data_generator.flow_from_directory(val_mask_path, 
                                                               seed=seed, 
                                                               batch_size=batch_size, 
                                                               color_mode = 'grayscale',   #Read masks in grayscale
                                                               class_mode=None)  #Default batch size 32, if not specified here


train_generator = zip(image_generator, mask_generator)
val_generator = zip(valid_img_generator, valid_mask_generator)
# Out:
# Found 26222 images belonging to 1 classes.
# Found 26222 images belonging to 1 classes.
# Found 4628 images belonging to 1 classes.
# Found 4628 images belonging to 1 classes.

# %%
x = image_generator.next()
y = mask_generator.next()
for i in range(0,1):
    image = x[i]
    mask = y[i]
    plt.subplot(1,2,1)
    plt.imshow(image[:,:,0], cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(mask[:,:,0])
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K



'''
A few useful metrics and losses
'''

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)


def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


##############################################################
'''
Useful blocks to build Unet
conv - BN - Activation - conv - BN - Activation - Dropout (if enabled)
'''


def conv_block(x, filter_size, size, dropout, batch_norm=False):
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv


def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape 
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)


def res_conv_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    Two variants....
    Either put activation function before the addition with shortcut
    or after the addition (which would be as proposed in the original resNet).
    
    1. conv - BN - Activation - conv - BN - Activation 
                                          - shortcut  - BN - shortcut+BN
                                          
    2. conv - BN - Activation - conv - BN   
                                     - shortcut  - BN - shortcut+BN - Activation                                     
    
    Check fig 4 in https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
    '''

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn




def UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    UNet, 
    
    '''
    # network structure
    FILTER_NUM = 64 # number of filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    

    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
   
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, conv_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, conv_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, conv_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
   
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, conv_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
   
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model 
    model = models.Model(inputs, conv_final, name="UNet")
    print(model.summary())
    return model

def Attention_UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Attention UNet, 
    
    '''
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    
    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = models.Model(inputs, conv_final, name="Attention_UNet")
    return model

def Attention_ResUNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Rsidual UNet, with attention 
    
    '''
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    # input data
    # dimension of the image depth
    inputs = layers.Input(input_shape, dtype=tf.float32)
    axis = 3

    # Downsampling layers
    # DownRes 1, double residual convolution + pooling
    conv_128 = res_conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = res_conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = res_conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = res_conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = res_conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=axis)
    up_conv_16 = res_conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=axis)
    up_conv_32 = res_conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=axis)
    up_conv_64 = res_conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=axis)
    up_conv_128 = res_conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=axis)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = models.Model(inputs, conv_final, name="AttentionResUNet")
    return model

# %%
IMG_HEIGHT = x.shape[1]
IMG_WIDTH  = x.shape[2]
IMG_CHANNELS = x.shape[3]


input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
num_labels = 1  #Binary

# %%
cd "/content"
# Out:
# /content

# %%
pip install focal-loss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: focal-loss in /usr/local/lib/python3.9/dist-packages (0.0.7)
# Requirement already satisfied: tensorflow>=2.2 in /usr/local/lib/python3.9/dist-packages (from focal-loss) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (4.5.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (16.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (2.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (23.3.3)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (1.22.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (1.53.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (2.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (67.6.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (3.20.3)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (0.4.7)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (3.3.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (2.12.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (23.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (0.32.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2->focal-loss) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=2.2->focal-loss) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=2.2->focal-loss) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=2.2->focal-loss) (0.0.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (2.17.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (6.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal-loss) (3.2.2)

# %%
from datetime import datetime 
from keras import backend, optimizers
from tensorflow.keras.optimizers import Adam
from focal_loss import BinaryFocalLoss

# %%
num_train_imgs = len(os.listdir('/content/data_for_keras_aug/train_images/train/'))
num_val_images = len(os.listdir('/content/data_for_keras_aug/val_images/val/'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
# !pip install transunet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transunet
#   Downloading transunet-1.0.3-py3-none-any.whl (11 kB)
# Collecting validators
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (from transunet) (2.12.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (0.4.7)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (0.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (16.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (4.5.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (2.12.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (23.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (67.6.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (1.22.4)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (2.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (1.53.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (3.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (23.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (2.12.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (3.20.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->transunet) (1.16.0)
# Collecting typeguard>=2.7
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators->transunet) (4.4.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow->transunet) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow->transunet) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow->transunet) (0.0.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->transunet) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->transunet) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->transunet) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->transunet) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->transunet) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->transunet) (2.17.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->transunet) (1.0.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons->transunet) (6.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->transunet) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->transunet) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->transunet) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->transunet) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->typeguard>=2.7->tensorflow-addons->transunet) (3.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->transunet) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->transunet) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->transunet) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->transunet) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->transunet) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->transunet) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->transunet) (3.2.2)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=b3403ba54808fada424804aa2178ba5c0c4456a471febacab71fc1cddcfd76c2
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: validators, typeguard, tensorflow-addons, transunet
# Successfully installed tensorflow-addons-0.19.0 transunet-1.0.3 typeguard-3.0.2 validators-0.20.0

# %%
from transunet import TransUNet
model = TransUNet(image_size=256, pretrain=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/vit_models/imagenet21k/R50+ViT-B_16.npz
# 461217452/461217452 [==============================] - 18s 0us/step
# /usr/local/lib/python3.9/dist-packages/transunet/utils.py:82: UserWarning: Resizing position embeddings from 14 to 16
#   warnings.warn(

# %%
model.compile(optimizer=Adam(learning_rate = 1e-2), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coef])


print(model.summary())
start2 = datetime.now() 
att_unet_history = model.fit(train_generator,  
                    steps_per_epoch=steps_per_epoch, 
                    epochs=15)
stop2 = datetime.now()
#Execution time of the model 
execution_time_Att_Unet = stop2-start2
print("Attention UNet execution time is: ", execution_time_Att_Unet)

model.save('mitochondria_Attention_UNet_50epochs_B_focal.hdf5')
# Out:
# Model: "TransUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 262, 262, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 128, 128, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 130, 130, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 64, 64, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 64, 64, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 66, 66, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 64, 64, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 64, 64, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 64, 64, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 66, 66, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 64, 64, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 64, 64, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 64, 64, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 66, 66, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 32, 32, 256)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 32, 32, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 32, 32, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 16, 16, 512)  0           ['max_pooling2d_5[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 16, 16, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 16, 16, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  embedding (Conv2D)             (None, 16, 16, 768)  787200      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  reshape (Reshape)              (None, 256, 768)     0           ['embedding[0][0]']
#
#  Transformer/posembed_input (Ad  (None, 256, 768)    196608      ['reshape[0][0]']
#  dPositionEmbs)
#
#  dropout (Dropout)              (None, 256, 768)     0           ['Transformer/posembed_input[0][0
#                                                                  ]']
#
#  Transformer/encoderblock_0 (Tr  ((None, 256, 768),  7087872     ['dropout[0][0]']
#  ansformerBlock)                 (None, 12, None, N
#                                 one))
#
#  Transformer/encoderblock_1 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_0[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_2 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_1[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_3 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_2[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_4 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_3[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_5 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_4[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_6 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_5[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_7 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_6[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_8 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_7[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_9 (Tr  ((None, 256, 768),  7087872     ['Transformer/encoderblock_8[0][0
#  ansformerBlock)                 (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_10 (T  ((None, 256, 768),  7087872     ['Transformer/encoderblock_9[0][0
#  ransformerBlock)                (None, 12, None, N              ]']
#                                 one))
#
#  Transformer/encoderblock_11 (T  ((None, 256, 768),  7087872     ['Transformer/encoderblock_10[0][
#  ransformerBlock)                (None, 12, None, N              0]']
#                                 one))
#
#  Transformer/encoder_norm (Laye  (None, 256, 768)    1536        ['Transformer/encoderblock_11[0][
#  rNormalization)                                                 0]']
#
#  reshape_1 (Reshape)            (None, 16, 16, 768)  0           ['Transformer/encoder_norm[0][0]'
#                                                                  ]
#
#  decoder_cup (DecoderCup)       (None, 256, 256, 16  7390080     ['reshape_1[0][0]',
#                                 )                                 'conv3_block4_preact_relu[0][0]'
#                                                                  , 'conv2_block3_preact_relu[0][0]
#                                                                  ',
#                                                                   'conv1_conv[0][0]']
#
#  seg_head (SegmentationHead)    (None, 256, 256, 3)  51          ['decoder_cup[0][0]']
#
# ==================================================================================================
# Total params: 100,886,195
# Trainable params: 93,427,059
# Non-trainable params: 7,459,136
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-38-3b8b80458f23> in <cell line: 7>()
#       5 print(model.summary())
#       6 start2 = datetime.now()
# ----> 7 att_unet_history = model.fit(train_generator,
#       8                     steps_per_epoch=steps_per_epoch,
#       9                     epochs=15)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'mul_1' defined at (most recent call last):
#     File "/usr/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/usr/local/lib/python3.9/dist-packages/ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "/usr/local/lib/python3.9/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/usr/local/lib/python3.9/dist-packages/ipykernel/kernelapp.py", line 619, in start
#       self.io_loop.start()
#     File "/usr/local/lib/python3.9/dist-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/usr/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/usr/local/lib/python3.9/dist-packages/tornado/ioloop.py", line 687, in <lambda>
#       lambda f: self._run_callback(functools.partial(callback, future))
#     File "/usr/local/lib/python3.9/dist-packages/tornado/ioloop.py", line 740, in _run_callback
#       ret = callback()
#     File "/usr/local/lib/python3.9/dist-packages/tornado/gen.py", line 821, in inner
#       self.ctx_run(self.run)
#     File "/usr/local/lib/python3.9/dist-packages/tornado/gen.py", line 782, in run
#       yielded = self.gen.send(value)
#     File "/usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#       yield gen.maybe_future(dispatch(*args))
#     File "/usr/local/lib/python3.9/dist-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#       yield gen.maybe_future(handler(stream, idents, msg))
#     File "/usr/local/lib/python3.9/dist-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#       self.do_execute(
#     File "/usr/local/lib/python3.9/dist-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/usr/local/lib/python3.9/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#       return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#       result = self._run_cell(
#     File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#       return runner(coro)
#     File "/usr/local/lib/python3.9/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "<ipython-input-38-3b8b80458f23>", line 7, in <cell line: 7>
#       att_unet_history = model.fit(train_generator,
#     File "/usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1055, in train_step
#       return self.compute_metrics(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1149, in compute_metrics
#       self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/compile_utils.py", line 605, in update_state
#       metric_obj.update_state(y_t, y_p, sample_weight=mask)
#     File "/usr/local/lib/python3.9/dist-packages/keras/utils/metrics_utils.py", line 77, in decorated
#       update_op = update_state_fn(*args, **kwargs)
#     File "/usr/local/lib/python3.9/dist-packages/keras/metrics/base_metric.py", line 140, in update_state_fn
#       return ag_update_state(*args, **kwargs)
#     File "/usr/local/lib/python3.9/dist-packages/keras/metrics/base_metric.py", line 691, in update_state
#       matches = ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "<ipython-input-19-3e973a673240>", line 21, in jacard_coef
#       intersection = K.sum(y_true_f * y_pred_f)
# Node: 'mul_1'
# required broadcastable shapes
# 	 [[{{node mul_1}}]] [Op:__inference_train_function_118149]

# %%
att_unet_model = Attention_UNet(input_shape)

att_unet_model.compile(optimizer=Adam(learning_rate = 1e-2), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coef])


print(att_unet_model.summary())
start2 = datetime.now() 
att_unet_history = att_unet_model.fit(train_generator,  
                    steps_per_epoch=steps_per_epoch, 
                    epochs=15)
stop2 = datetime.now()
#Execution time of the model 
execution_time_Att_Unet = stop2-start2
print("Attention UNet execution time is: ", execution_time_Att_Unet)

att_unet_model.save('mitochondria_Attention_UNet_50epochs_B_focal.hdf5')
# Out:
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  524800      ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 512)  262656      ['activation_10[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2359808    ['conv2d_12[0][0]']
#  ose)
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  1049088     ['activation_7[0][0]']
#
#  add (Add)                      (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  activation_11 (Activation)     (None, 16, 16, 512)  0           ['add[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 1)    513         ['activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 16, 16, 1)    0           ['conv2d_13[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 1)    0           ['activation_12[0][0]']
#
#  lambda (Lambda)                (None, 32, 32, 512)  0           ['up_sampling2d[0][0]']
#
#  multiply (Multiply)            (None, 32, 32, 512)  0           ['lambda[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 512)  262656      ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1024  0          ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  concatenate (Concatenate)      (None, 32, 32, 1536  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 256)  131328      ['activation_14[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_15[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  590080     ['conv2d_19[0][0]']
#  spose)
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 256)  262400      ['activation_5[0][0]']
#
#  add_1 (Add)                    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 256)  0           ['add_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 1)    257         ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 1)    0           ['conv2d_20[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_17[0][0]']
#
#  lambda_1 (Lambda)              (None, 64, 64, 256)  0           ['up_sampling2d_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 256)  0           ['lambda_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 256)  65792       ['multiply_1[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 512)  0          ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d_3[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 256)  1769728     ['concatenate_1[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  32896       ['activation_19[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_20[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  147584     ['conv2d_26[0][0]']
#  spose)
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  65664       ['activation_3[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  activation_21 (Activation)     (None, 64, 64, 128)  0           ['add_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 1)    129         ['activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 64, 64, 1)    0           ['conv2d_27[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_22[0][0]']
#
#  lambda_2 (Lambda)              (None, 128, 128, 12  0           ['up_sampling2d_4[0][0]']
#                                 8)
#
#  multiply_2 (Multiply)          (None, 128, 128, 12  0           ['lambda_2[0][0]',
#                                 8)                                'activation_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 12  16512       ['multiply_2[0][0]']
#                                 8)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 25  0          ['activation_19[0][0]']
#                                 6)
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 12  512        ['conv2d_28[0][0]']
#  ormalization)                  8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_5[0][0]',
#                                 4)                                'batch_normalization_19[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 12  512        ['conv2d_29[0][0]']
#  ormalization)                  8)
#
#  activation_23 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 12  147584      ['activation_23[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 12  512        ['conv2d_30[0][0]']
#  ormalization)                  8)
#
#  activation_24 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 64  8256        ['activation_24[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 64  256        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 64  4160        ['activation_25[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  36928      ['conv2d_33[0][0]']
#  spose)                         )
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 64  16448       ['activation_1[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_32[0][0]']
#
#  activation_26 (Activation)     (None, 128, 128, 64  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 1)  65          ['activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 128, 128, 1)  0           ['conv2d_34[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_27[0][0]']
#
#  lambda_3 (Lambda)              (None, 256, 256, 64  0           ['up_sampling2d_6[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 256, 256, 64  0           ['lambda_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 64  4160        ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 12  0          ['activation_24[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 256, 256, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_7[0][0]',
#                                 2)                                'batch_normalization_23[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 256, 256, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 64  36928       ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 256, 256, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  activation_29 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 1)  65          ['activation_29[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 256, 256, 1)  4          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 256, 256, 1)  0           ['batch_normalization_26[0][0]']
#
# ==================================================================================================
# Total params: 37,334,665
# Trainable params: 37,319,047
# Non-trainable params: 15,618
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# 3277/3277 [==============================] - 2367s 703ms/step - loss: 0.0817 - accuracy: 0.8661 - jacard_coef: 6.5920e-04
# Epoch 2/15
# 3277/3277 [==============================] - 2293s 700ms/step - loss: 0.0544 - accuracy: 0.8550 - jacard_coef: 9.9541e-04
# Epoch 3/15
# 3277/3277 [==============================] - 2292s 699ms/step - loss: 0.0494 - accuracy: 0.8558 - jacard_coef: 0.0011
# Epoch 4/15
#  275/3277 [=>............................] - ETA: 34:51 - loss: 0.0479 - accuracy: 0.8579 - jacard_coef: 0.0011
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-2fd4490e8ad6> in <cell line: 9>()
#       7 print(att_unet_model.summary())
#       8 start2 = datetime.now()
# ----> 9 att_unet_history = att_unet_model.fit(train_generator,
#      10                     steps_per_epoch=steps_per_epoch,
#      11                     epochs=15)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1689                             logs = tmp_logs
#    1690                             end_step = step + data_handler.step_increment
# -> 1691                             callbacks.on_train_batch_end(end_step, logs)
#    1692                             if self.stop_training:
#    1693                                 break
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     678         return t.item() if np.ndim(t) == 0 else t
#     679
# --> 680     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     681
#     682
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     671         # Don't turn ragged or sparse tensors to NumPy.
#     672         if isinstance(t, tf.Tensor):
# --> 673             t = t.numpy()
#     674         # Strings, ragged and sparse tensors don't have .item(). Return them
#     675         # as-is.
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1158     """
#    1159     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1160     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1161     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1162
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1124   def _numpy(self):
#    1125     try:
# -> 1126       return self._numpy_internal()
#    1127     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1128       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
att_unet_history_df = pd.DataFrame(att_unet_history.history)
with open('att_unet_history_df.csv', mode='w') as f:
    att_unet_history_df.to_csv(f)

# %%
history = att_unet_history
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['jacard_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_jacard_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Jacard')
plt.plot(epochs, val_acc, 'r', label='Validation Jacard')
plt.title('Training and validation Jacard')
plt.xlabel('Epochs')
plt.ylabel('Jacard')
plt.legend()
plt.show()
